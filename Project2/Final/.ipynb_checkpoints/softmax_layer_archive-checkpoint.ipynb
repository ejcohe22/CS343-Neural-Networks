# %% [markdown]
# **Sawyer Strong & Erik Cohen**
#
# Fall 2019
#
# CS 343: Neural Networks
#
# Project 2: Multi-layer Perceptrons
#
# **Draft due 11:59pm Thurs Sept 26**
#
#
# Summary of files in this project:
# - `softmax_layer.ipynb`
# - `single_layer_net.py`
# - `preprocess_data.py`
# - `mlp.ipynb`
# - `mlp.py`
#
# **REMINDER**: Submit rubric on Google Classroom

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

# for obtaining the STL-dataset
import load_stl10_dataset

# for preprocessing dataset
import preprocess_data

# Set the color style so that Professor Layton can see your plots
plt.style.use(['seaborn-colorblind', 'seaborn-darkgrid'])
# Make the font size larger
plt.rcParams.update({'font.size': 20})

# Turn off scientific notation when printing
np.set_printoptions(suppress=True, precision=3)

# Automatically reload external modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Overview
#
# In this project, you will implement Multilayer Perception (MLP) networks that classify image data belonging to one of 10 classes from the STL-10 dataset.
#
# You will create two networks that use the softmax activation function and cross-entropy loss:
#
# - One without a hidden layer (**Task 2**; this notebook) and
# - One with a hidden layer (**Task 3**; ``mlp.ipynb``)
#
# Before implementing the MLP with hidden layer, we will create a simpler single layer network (similar architecture to ADALINE) to test your loss and activation function code.
#
# Focus areas in this project are:
# - Working with a large dataset
# - Batch vs stochastic training
# - Regularization
# - Multi-class data classification
# - Network weight visualization

# %% [markdown]
# ## Task 1) Download and preprocess datasets

# %% [markdown]
# ### a. STL-10
#
# More info: https://cs.stanford.edu/~acoates/stl10/
#
# **Properties:**
# - 10 classes of images: airplane, bird, car, cat, deer, dog, horse, monkey, ship, truck
# - 5000 images.
# - 96x96 resolution (we will work with them converted to 32x32 for rapid development and debugging purposes)

# %% [markdown]
# #### (i) Download the STL-10 dataset, convert to 32x32 images
#
# This data acquistion script should "just work". You're welcome to take a peek at the script to see where the data is going, but you shouldn't need to tinker with it. It needs to download the dataset from the internet, which might take a few minutes. I set up the script so that it caches the dataset locally in your project folder, so you should only need to download it once. There is a progress percentage indicator.
#
# You should see the following output:
#
# `Images are: (5000, 96, 96, 3)
# Labels are: (5000,)
# Resizing 5000 images to 32x32...Done!
# `

# %%
# Download the dataset from the internet, convert it to Numpy ndarray, resize to 32x32
# cache it locally on your computer for faster loading next time.
stl_imgs, stl_labels = load_stl10_dataset.load()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-f72b57951b38> in <module>
#       1 # Download the dataset from the internet, convert it to Numpy ndarray, resize to 32x32
#       2 # cache it locally on your computer for faster loading next time.
# ----> 3 stl_imgs, stl_labels = load_stl10_dataset.load()
#
# /Volumes/Courses/CS343/dajosh21/Private/Project2/Final/load_stl10_dataset.py in load(save_imgs_to_disk, cache_binaries_to_disk)
#     201
#     202     # Read in the whole dataset and labels
# --> 203     images = read_all_images(DATA_PATH)
#     204     labels = read_labels(LABEL_PATH)
#     205
#
# /Volumes/Courses/CS343/dajosh21/Private/Project2/Final/load_stl10_dataset.py in read_all_images(path_to_data)
#      41     """
#      42
# ---> 43     with open(path_to_data, 'rb') as f:
#      44         # read whole file in uint8 chunks
#      45         everything = np.fromfile(f, dtype=np.uint8)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/stl10_binary/train_X.bin'

# %% [markdown]
# #### (ii) Take a look at a sample of the images in the dataset
#
# Let's take a look at the image categories that we want the neural network to learn

# %%
# Load in the string names for each class
classes = np.loadtxt(os.path.join('data', 'stl10_binary', 'class_names.txt'), dtype=str)

# %%
plt.figure(figsize=(10, 12))
plt.subplot
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    randInd = random.randint(0, len(stl_imgs)-1)
    plt.imshow(stl_imgs[randInd])
    plt.xlabel(classes[stl_labels[randInd]-1])
plt.show()

# %% [markdown]
# #### (iii) Preprocess the data
#
# Preprocessing data is an important part of working with neural networks.
#
# **TODO**: Fill in the function `preprocess_stl` in `preprocess_data.py`, implementing the 4 listed goals, to get the desired print out below.

# %%
# Preprocess image pixel values for the MLP net
stl_imgs, stl_labels = preprocess_data.preprocess_stl(stl_imgs, stl_labels)

print(f'stl_imgs dtype is {stl_imgs.dtype} and it should be float64')
print(f'stl_imgs max is {np.max(stl_imgs[:, 1:]):.3f} and it should be 0.668')
print(f'stl_imgs shape is {stl_imgs.shape} and it should be (5000, 3072)')
print(f'stl_labels span {stl_labels.min()}->{stl_labels.max()} and it should be 0->9')
# Out:
# stl_imgs dtype is float64 and it should be float64
# stl_imgs max is 0.668 and it should be 0.668
# stl_imgs shape is (5000, 3072) and it should be (5000, 3072)
# stl_labels span 0->9 and it should be 0->9

# %% [markdown]
# #### (iii) Create train, validation, test, and dev splits
#
# **TODO**: Complete the `create_splits` function in `preprocess_data.py` to divvy up the dataset into train/test/validation/development subsets, following the two main goals lists. You should obtain a printout as follows:
#
# `Train data shape:  (3500, 3072)
# Train labels shape:  (3500,)
# Test data shape:  (500, 3072)
# Test labels shape:  (500,)
# Validation data shape:  (500, 3072)
# Validation labels shape:  (500,)
# dev data shape:  (500, 3072)
# dev labels shape:  (500,)
# `

# %%
x_train, y_train, x_test, y_test, x_val, y_val, x_dev, y_dev = preprocess_data.create_splits(stl_imgs, stl_labels)  

print ('Train data shape: ', x_train.shape)
print ('Train labels shape: ', y_train.shape)
print ('Test data shape: ', x_test.shape)
print ('Test labels shape: ', y_test.shape)
print ('Validation data shape: ', x_val.shape)
print ('Validation labels shape: ', y_val.shape)
print ('dev data shape: ', x_dev.shape)
print ('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (3500, 3072)
# Train labels shape:  (3500,)
# Test data shape:  (500, 3072)
# Test labels shape:  (500,)
# Validation data shape:  (500, 3072)
# Validation labels shape:  (500,)
# dev data shape:  (500, 3072)
# dev labels shape:  (500,)

# %% [markdown]
# ## Task 2) Implement single layer network to test softmax activation and cross-entropy loss
#
# You will first implement and test out the softmax activation and cross-entropy loss in a single layer net before embedding it in a more complex multiple layer network.

# %% [markdown]
# ### a. Implement the following functions
#
# In `single_layer_net.py`, implement the following methods in the base class `SingleLayerNet`:
#
# - `fit`
# - `net_in`
# - `predict`
# - `one_hot`
# - `accuracy`
#
#
# In the child class `SingleLayerNetSoftmax` implement the following methods:
#
# - `activation` (softmax) $f(x_i) = \frac{e^{x_i}}{\sum_{j=1}^C e^{x_j}}$ where $x_i$ are the "net in" values and there are $C$ output neurons (one per input class). $f(x_i)$ is the activation values of each output neuron $i$. Since this is softmax, it is the probability that a given input belongs to the class $i$ coded by the output neuron.
# - `loss` (cross-entropy) $L(x_m) = -\frac{1}{B}\sum_{b=1}^B{Log \left (\frac{e^{x_m}}{\sum_{n=1}^C e^{x_n}}\right )}$. $m$ is the correct class for the $b^{th}$ input. $x_m$ is the output neuron activation for the correct class, $x_n$ is the output neuron activation for all of the classes (in the sum). The batch size is $B$, so the loss is averaged over each mini-batch of inputs. The expression in the $Log$ is just the softmax.
# - `gradient` (for softmax/cross-entropy)
#
# You're welcome to work in any order, but I recommend starting with `fit` because as you work though it, you should recognize why we need most of the other methods. You can finish `fit` or branch off as you need the other methods.

# %% [markdown]
# ### b. Test key functions

# %%
from single_layer_net import SingleLayerNetSoftmax

# %%
# Let's generate some small Gaussian weights equal to the length of an image feature vector
np.random.seed(0)
randWts = np.random.normal(loc=0, scale=0.01, size=(x_dev.shape[1], 10))
b = 1
softmaxNet = SingleLayerNetSoftmax()
randWts.shape

# for test code purposes, use the last 15 images/labels
test_imgs, test_labels = stl_imgs[-15:], stl_labels[-15:]

# %% [markdown]
# #### Test the `onehot` function

# %%
not_y_test = np.array([2, 2, 0, 1])
c_test = 4
y_one_hot = softmaxNet.one_hot(not_y_test, c_test)
print(f'Your one hot vectors:\n{y_one_hot}')
# Out:
# Your one hot vectors:
# [[0. 0. 1. 0.]
#  [0. 0. 1. 0.]
#  [1. 0. 0. 0.]
#  [0. 1. 0. 0.]]

# %% [markdown]
# Your one hot vectors should look like:
#
#     [[0. 0. 1. 0.]
#      [0. 0. 1. 0.]
#      [1. 0. 0. 0.]
#      [0. 1. 0. 0.]]

# %% [markdown]
# #### Test the `loss`,  `net_in`, softmax `activation` functions

# %%
lossNoReg, lossReg = softmaxNet.test_loss(randWts, b, test_imgs, test_labels)
print(f'The loss (without regularization) is {lossNoReg:.2f} and it should approx be 2.28')
print(f'The loss (with 0.5 regularization) is {lossReg:.2f} and it should approx be 3.04')
# Out:
# net in shape=(15, 10), min=0.6586955718394151, max=1.4084436090585781
# Should be
# net in shape=(15, 10), min=0.6586955718394152, max=1.4084436090585783
#
# net act shape=(15, 10), min=0.07413774498031761, max=0.1416742376747235
# Should be
# net act shape=(15, 10), min=0.07413774498031761, max=0.14167423767472354
#
# The loss (without regularization) is 2.28 and it should approx be 2.28
# The loss (with 0.5 regularization) is 3.04 and it should approx be 3.04

# %% [markdown]
# #### Test the `gradient` function

# %%
grad_wts, grad_b = softmaxNet.test_gradient(randWts, b, test_imgs, test_labels, 10)
print(f'1st few Wt gradient values are {grad_wts[:4,0]}\nand should be                  [0.01  0.015 0.014 0.007] ')
print(f'1st few Wt bias values are {grad_b[:4]}\nand should be              [ 0.103 -0.099  0.101 -0.026]')
# Out:
# net in: (15, 10), 0.6586955718394151, 1.4084436090585781
# y one hot: (15, 10), sum is 15.0
# 1st few Wt gradient values are [0.01  0.015 0.014 0.007]
# and should be                  [0.01  0.015 0.014 0.007]
# 1st few Wt bias values are [ 0.103 -0.099  0.101 -0.026]
# and should be              [ 0.103 -0.099  0.101 -0.026]

# %% [markdown]
# #### Test `fit` function

# %%
softmaxNet = SingleLayerNetSoftmax()
loss_history = softmaxNet.fit(x_dev, y_dev, n_epochs=600, mini_batch_sz=250)
# Out:
# Starting to train network...There will be 600 epochs and 1200 iterations total, 2 iter/epoch.
#   Completed iter 0/1200. Training loss: 2.31.
#   Completed iter 100/1200. Training loss: 2.32.
#   Completed iter 200/1200. Training loss: 2.29.
#   Completed iter 300/1200. Training loss: 2.26.
#   Completed iter 400/1200. Training loss: 2.24.
#   Completed iter 500/1200. Training loss: 2.23.
#   Completed iter 600/1200. Training loss: 2.23.
#   Completed iter 700/1200. Training loss: 2.24.
#   Completed iter 800/1200. Training loss: 2.19.
#   Completed iter 900/1200. Training loss: 2.21.
#   Completed iter 1000/1200. Training loss: 2.17.
#   Completed iter 1100/1200. Training loss: 2.18.
# Finished training!

# %% [markdown]
# Given the random mini-batch sampling process, you should get different specific numbers, but the loss should decrease with iterations. You should get something like this:
#
#     Starting to train network...There will be 600 epochs and 1200 iterations total, 2 iter/epoch.
#       Completed iter 0/1200. Training loss: 2.29.
#       Completed iter 100/1200. Training loss: 2.30.
#       Completed iter 200/1200. Training loss: 2.27.
#       Completed iter 300/1200. Training loss: 2.29.
#       Completed iter 400/1200. Training loss: 2.27.
#       Completed iter 500/1200. Training loss: 2.23.
#       Completed iter 600/1200. Training loss: 2.23.
#       Completed iter 700/1200. Training loss: 2.23.
#       Completed iter 800/1200. Training loss: 2.21.
#       Completed iter 900/1200. Training loss: 2.20.
#       Completed iter 1000/1200. Training loss: 2.20.
#       Completed iter 1100/1200. Training loss: 2.17.
#     Finished training!

# %% [markdown]
# ##### Plot the loss.
#
# It should look noisy, but on average be decreasing and look roughly linear.

# %%
def plot_cross_entropy_loss(loss_history):
    plt.plot(loss_history)
    plt.xlabel('Training iteration')
    plt.ylabel('loss (cross-entropy)')
    plt.show()
    
plot_cross_entropy_loss(loss_history)

# %% [markdown]
# **Question 1**: What do you think the linear drop in loss over the epochs tells us about the state of the training process? How is current training going? What's the future potential like?

# %% [markdown]
# **Answer:** The linear drop suggests that training is currently incomplete. We could increase the accuracy of the model by training for more epochs, or speed up training with a slightly larger learning rate.

# %% [markdown]
# #### Test regularization with training. The loss should hover around 17-18 for `reg=10`
#
# **Question 2**: Play around with the regularization parameter. You can drastically change the magnitude, but it should remain positive. How does this affect the training loss and why?

# %% [markdown]
# **Answer:** Increasing the regularization parameter can drastically increase loss, while reducing the regularization parameter decreases the loss, asymptotically approaching a minimum value. This is because the regularization term is an additive one.

# %%
softmaxNet = SingleLayerNetSoftmax()
loss_history = softmaxNet.fit(x_dev, y_dev, reg=10, n_epochs=500)
plot_cross_entropy_loss(loss_history)
# Out:
# Starting to train network...There will be 500 epochs and 500 iterations total, 1 iter/epoch.
#   Completed iter 0/500. Training loss: 17.77.
#   Completed iter 100/500. Training loss: 14.94.
#   Completed iter 200/500. Training loss: 12.64.
#   Completed iter 300/500. Training loss: 10.76.
#   Completed iter 400/500. Training loss: 9.21.
# Finished training!

# %% [markdown]
# #### Test training batch size
#
# **Question 3**: Play around with the batch size parameter. **How does this affect the training loss and why?** (Think about the error gradient and how the weights change)

# %% [markdown]
# **Answer:** The bigger the batch size, the less oscilation that we can see in the loss function. This is a result of the model not making changes based on smaller sets of images and then finding different changes to make on other sets of images. This is why, as we increase the batch size, we see a siginificantly smoother loss curve over iterations.

# %%
softmaxNet = SingleLayerNetSoftmax()
loss_history = softmaxNet.fit(x_dev, y_dev, mini_batch_sz=100, n_epochs=10, verbose=0);
plot_cross_entropy_loss(loss_history)

# %% [markdown]
# ### c. Train and optimize STL-10 dataset performance, plot results
#
# #### (i) Grid search
#
# As you've surely noticed, hyperparameters can drastically affect learning!
#
#
# **TODO:** Implement a grid search for the best hyperparameters
#
# - learning rate,
# - regularization
# - batch size
#
# The grid search process should:
#
# 1. Fit the model with specific values of hyperparameters that we're testing (using the training set).
# 2. Compute the accuracy on the training set.
# 3. Compute the accuracy on the validation set.
# 4. Print out and record the best parameter combination as you go (that improves the **validation set accuracy**).
# 5. Wipe the weights clean (reinitialize them) every time you try new parameters. It's easiest just to create a new net object on each run.
#
#
# This can take quite a bit of simulation time!
#
# I suggest implementing the coarse-to-fine search strategy. First try varying parameters over many orders of magnitude. Use the "new best" print outs to refine the ranges that you test. Abort simulations prematurely if you feel there aren't productive (no reason to wait!). This can take however long or short that you want to dedicate. Remember, you are printing out the best parameter values on each run, so you can just proceed with those.
#
# You should be able to achieve ~35% accuracy without too much effort (10% is chance performance).
#
# Your grade won't depend on the accuracy that you achieve, but if you get roughly the above accuracy, the payoff will be cooler visualizations in 2d!
#
# ##### Guidelines
# - Learning rates above 1e-1 don't really make sense.
# - Your mini-batch sizes should be <= N and >= 1

# %%
np.random.seed(0)

#Store the best values
best_val_acc = 0
best_lr = 0
best_reg = 0
best_batch = 0

#Set the initial values for the hyperparams
init_lr = 0.0501
init_reg = 50
init_batch = 501

#Set the values for the intervals at we'll search across, for each hyperparam
#These will be halved every time the search gets finer
lr_interval = 0.005
reg_interval = 5
batch_interval = 50

#Implement coarse-to-fine search for each hyperparameter
#An outer for loop in which we adjust the intervals and initial values for each search
#An inner triple-for-loop in which we search using the given intervals and inital values

for i in range(3):
    
    best_acc = 0
    
    #Search across learning rate
    for j in range(-10,11,2):
        lr = init_lr+(lr_interval*j)
        
        #Search across batch_size
        for k in range(-8,9,2):
            batch = max(10,int(init_batch+(batch_interval*k)))
            
            #Search across reg val
            for l in range(-10,11,2):
                reg = init_reg+(reg_interval*l)
                                
                #Train
                softmaxNet = SingleLayerNetSoftmax()
                softmaxNet.fit(x_train, y_train, 10, lr, batch, reg, 0)

                #Compute accuracy
                train_pred = softmaxNet.predict(x_train)
                val_pred = softmaxNet.predict(x_val)
                train_acc = softmaxNet.accuracy(y_train,train_pred)
                val_acc = softmaxNet.accuracy(y_val,val_pred)
                
                print(f"Zoom Level: {i+1}\tLr: {lr:5f}\tReg: {reg:5f}\tBatch: {batch}\tAcc: {val_acc:5f}")
                
                

                #Update best if needed
                if val_acc > best_acc:                    
                    best_acc = val_acc
                    best_lr = lr
                    best_reg = reg
                    best_batch = batch

    init_lr = best_lr
    lr_interval = lr_interval/2
    init_reg = best_reg
    reg_interval = reg_interval/2
    init_batch = best_batch
    batch_interval = batch_interval/2

print(f"The best learning rate was {best_lr}")
print(f"The best batch-size was {best_batch}")
print(f"The best regularization value was {best_reg}")
# Out:
# Zoom Level: 1	Lr: 0.000100	Reg: 0.000000	Batch: 101	Acc: 0.210000
# Zoom Level: 1	Lr: 0.000100	Reg: 10.000000	Batch: 101	Acc: 0.182000
# Zoom Level: 1	Lr: 0.000100	Reg: 20.000000	Batch: 101	Acc: 0.184000
# Zoom Level: 1	Lr: 0.000100	Reg: 30.000000	Batch: 101	Acc: 0.168000
# Zoom Level: 1	Lr: 0.000100	Reg: 40.000000	Batch: 101	Acc: 0.194000
# Zoom Level: 1	Lr: 0.000100	Reg: 50.000000	Batch: 101	Acc: 0.222000
# Zoom Level: 1	Lr: 0.000100	Reg: 60.000000	Batch: 101	Acc: 0.226000
# Zoom Level: 1	Lr: 0.000100	Reg: 70.000000	Batch: 101	Acc: 0.242000
# Zoom Level: 1	Lr: 0.000100	Reg: 80.000000	Batch: 101	Acc: 0.220000
# Zoom Level: 1	Lr: 0.000100	Reg: 90.000000	Batch: 101	Acc: 0.260000
# Zoom Level: 1	Lr: 0.000100	Reg: 100.000000	Batch: 101	Acc: 0.248000
# Zoom Level: 1	Lr: 0.000100	Reg: 0.000000	Batch: 201	Acc: 0.166000
# Zoom Level: 1	Lr: 0.000100	Reg: 10.000000	Batch: 201	Acc: 0.170000
# Zoom Level: 1	Lr: 0.000100	Reg: 20.000000	Batch: 201	Acc: 0.154000
# Zoom Level: 1	Lr: 0.000100	Reg: 30.000000	Batch: 201	Acc: 0.180000
# Zoom Level: 1	Lr: 0.000100	Reg: 40.000000	Batch: 201	Acc: 0.146000
# Zoom Level: 1	Lr: 0.000100	Reg: 50.000000	Batch: 201	Acc: 0.162000
# Zoom Level: 1	Lr: 0.000100	Reg: 60.000000	Batch: 201	Acc: 0.184000
# Zoom Level: 1	Lr: 0.000100	Reg: 70.000000	Batch: 201	Acc: 0.178000
# Zoom Level: 1	Lr: 0.000100	Reg: 80.000000	Batch: 201	Acc: 0.120000
# Zoom Level: 1	Lr: 0.000100	Reg: 90.000000	Batch: 201	Acc: 0.178000
# Zoom Level: 1	Lr: 0.000100	Reg: 100.000000	Batch: 201	Acc: 0.182000
# Zoom Level: 1	Lr: 0.000100	Reg: 0.000000	Batch: 301	Acc: 0.110000
# Zoom Level: 1	Lr: 0.000100	Reg: 10.000000	Batch: 301	Acc: 0.112000
# Zoom Level: 1	Lr: 0.000100	Reg: 20.000000	Batch: 301	Acc: 0.096000
# Zoom Level: 1	Lr: 0.000100	Reg: 30.000000	Batch: 301	Acc: 0.130000
# Zoom Level: 1	Lr: 0.000100	Reg: 40.000000	Batch: 301	Acc: 0.126000
# Zoom Level: 1	Lr: 0.000100	Reg: 50.000000	Batch: 301	Acc: 0.152000
# Zoom Level: 1	Lr: 0.000100	Reg: 60.000000	Batch: 301	Acc: 0.124000
# Zoom Level: 1	Lr: 0.000100	Reg: 70.000000	Batch: 301	Acc: 0.120000
# Zoom Level: 1	Lr: 0.000100	Reg: 80.000000	Batch: 301	Acc: 0.158000
# Zoom Level: 1	Lr: 0.000100	Reg: 90.000000	Batch: 301	Acc: 0.116000
# Zoom Level: 1	Lr: 0.000100	Reg: 100.000000	Batch: 301	Acc: 0.138000
# Zoom Level: 1	Lr: 0.000100	Reg: 0.000000	Batch: 401	Acc: 0.100000
# Zoom Level: 1	Lr: 0.000100	Reg: 10.000000	Batch: 401	Acc: 0.096000
# Zoom Level: 1	Lr: 0.000100	Reg: 20.000000	Batch: 401	Acc: 0.174000
# Zoom Level: 1	Lr: 0.000100	Reg: 30.000000	Batch: 401	Acc: 0.102000
# Zoom Level: 1	Lr: 0.000100	Reg: 40.000000	Batch: 401	Acc: 0.120000
# Zoom Level: 1	Lr: 0.000100	Reg: 50.000000	Batch: 401	Acc: 0.104000
# Zoom Level: 1	Lr: 0.000100	Reg: 60.000000	Batch: 401	Acc: 0.088000
# Zoom Level: 1	Lr: 0.000100	Reg: 70.000000	Batch: 401	Acc: 0.132000
# Zoom Level: 1	Lr: 0.000100	Reg: 80.000000	Batch: 401	Acc: 0.128000
# Zoom Level: 1	Lr: 0.000100	Reg: 90.000000	Batch: 401	Acc: 0.144000
# Zoom Level: 1	Lr: 0.000100	Reg: 100.000000	Batch: 401	Acc: 0.134000
# Zoom Level: 1	Lr: 0.000100	Reg: 0.000000	Batch: 501	Acc: 0.096000
# Zoom Level: 1	Lr: 0.000100	Reg: 10.000000	Batch: 501	Acc: 0.118000
# Zoom Level: 1	Lr: 0.000100	Reg: 20.000000	Batch: 501	Acc: 0.128000
# Zoom Level: 1	Lr: 0.000100	Reg: 30.000000	Batch: 501	Acc: 0.118000
# Zoom Level: 1	Lr: 0.000100	Reg: 40.000000	Batch: 501	Acc: 0.072000
# Zoom Level: 1	Lr: 0.000100	Reg: 50.000000	Batch: 501	Acc: 0.102000
# Zoom Level: 1	Lr: 0.000100	Reg: 60.000000	Batch: 501	Acc: 0.092000
# Zoom Level: 1	Lr: 0.000100	Reg: 70.000000	Batch: 501	Acc: 0.114000
# Zoom Level: 1	Lr: 0.000100	Reg: 80.000000	Batch: 501	Acc: 0.112000
# Zoom Level: 1	Lr: 0.000100	Reg: 90.000000	Batch: 501	Acc: 0.098000
# Zoom Level: 1	Lr: 0.000100	Reg: 100.000000	Batch: 501	Acc: 0.112000
# Zoom Level: 1	Lr: 0.000100	Reg: 0.000000	Batch: 601	Acc: 0.136000
# Zoom Level: 1	Lr: 0.000100	Reg: 10.000000	Batch: 601	Acc: 0.088000
# Zoom Level: 1	Lr: 0.000100	Reg: 20.000000	Batch: 601	Acc: 0.100000
# Zoom Level: 1	Lr: 0.000100	Reg: 30.000000	Batch: 601	Acc: 0.092000
# Zoom Level: 1	Lr: 0.000100	Reg: 40.000000	Batch: 601	Acc: 0.094000
# Zoom Level: 1	Lr: 0.000100	Reg: 50.000000	Batch: 601	Acc: 0.132000
# Zoom Level: 1	Lr: 0.000100	Reg: 60.000000	Batch: 601	Acc: 0.084000
# Zoom Level: 1	Lr: 0.000100	Reg: 70.000000	Batch: 601	Acc: 0.116000
# Zoom Level: 1	Lr: 0.000100	Reg: 80.000000	Batch: 601	Acc: 0.110000
# Zoom Level: 1	Lr: 0.000100	Reg: 90.000000	Batch: 601	Acc: 0.150000
# Zoom Level: 1	Lr: 0.000100	Reg: 100.000000	Batch: 601	Acc: 0.160000
# Zoom Level: 1	Lr: 0.000100	Reg: 0.000000	Batch: 701	Acc: 0.074000
# Zoom Level: 1	Lr: 0.000100	Reg: 10.000000	Batch: 701	Acc: 0.100000
# Zoom Level: 1	Lr: 0.000100	Reg: 20.000000	Batch: 701	Acc: 0.108000
# Zoom Level: 1	Lr: 0.000100	Reg: 30.000000	Batch: 701	Acc: 0.106000
# Zoom Level: 1	Lr: 0.000100	Reg: 40.000000	Batch: 701	Acc: 0.050000
# Zoom Level: 1	Lr: 0.000100	Reg: 50.000000	Batch: 701	Acc: 0.116000
# Zoom Level: 1	Lr: 0.000100	Reg: 60.000000	Batch: 701	Acc: 0.096000
# Zoom Level: 1	Lr: 0.000100	Reg: 70.000000	Batch: 701	Acc: 0.104000
# Zoom Level: 1	Lr: 0.000100	Reg: 80.000000	Batch: 701	Acc: 0.074000
# Zoom Level: 1	Lr: 0.000100	Reg: 90.000000	Batch: 701	Acc: 0.100000
# Zoom Level: 1	Lr: 0.000100	Reg: 100.000000	Batch: 701	Acc: 0.092000
# Zoom Level: 1	Lr: 0.000100	Reg: 0.000000	Batch: 801	Acc: 0.088000
# Zoom Level: 1	Lr: 0.000100	Reg: 10.000000	Batch: 801	Acc: 0.124000
# Zoom Level: 1	Lr: 0.000100	Reg: 20.000000	Batch: 801	Acc: 0.096000
# Zoom Level: 1	Lr: 0.000100	Reg: 30.000000	Batch: 801	Acc: 0.104000
# Zoom Level: 1	Lr: 0.000100	Reg: 40.000000	Batch: 801	Acc: 0.104000
# Zoom Level: 1	Lr: 0.000100	Reg: 50.000000	Batch: 801	Acc: 0.130000
# Zoom Level: 1	Lr: 0.000100	Reg: 60.000000	Batch: 801	Acc: 0.100000
# Zoom Level: 1	Lr: 0.000100	Reg: 70.000000	Batch: 801	Acc: 0.088000
# Zoom Level: 1	Lr: 0.000100	Reg: 80.000000	Batch: 801	Acc: 0.088000
# Zoom Level: 1	Lr: 0.000100	Reg: 90.000000	Batch: 801	Acc: 0.104000
# Zoom Level: 1	Lr: 0.000100	Reg: 100.000000	Batch: 801	Acc: 0.098000
# Zoom Level: 1	Lr: 0.000100	Reg: 0.000000	Batch: 901	Acc: 0.124000
# Zoom Level: 1	Lr: 0.000100	Reg: 10.000000	Batch: 901	Acc: 0.116000
# Zoom Level: 1	Lr: 0.000100	Reg: 20.000000	Batch: 901	Acc: 0.114000
# Zoom Level: 1	Lr: 0.000100	Reg: 30.000000	Batch: 901	Acc: 0.122000
# Zoom Level: 1	Lr: 0.000100	Reg: 40.000000	Batch: 901	Acc: 0.130000
# Zoom Level: 1	Lr: 0.000100	Reg: 50.000000	Batch: 901	Acc: 0.124000
# Zoom Level: 1	Lr: 0.000100	Reg: 60.000000	Batch: 901	Acc: 0.102000
# Zoom Level: 1	Lr: 0.000100	Reg: 70.000000	Batch: 901	Acc: 0.144000
# Zoom Level: 1	Lr: 0.000100	Reg: 80.000000	Batch: 901	Acc: 0.090000
# Zoom Level: 1	Lr: 0.000100	Reg: 90.000000	Batch: 901	Acc: 0.168000
# Zoom Level: 1	Lr: 0.000100	Reg: 100.000000	Batch: 901	Acc: 0.092000
# Zoom Level: 1	Lr: 0.010100	Reg: 0.000000	Batch: 101	Acc: 0.372000
# Zoom Level: 1	Lr: 0.010100	Reg: 10.000000	Batch: 101	Acc: 0.280000
# Zoom Level: 1	Lr: 0.010100	Reg: 20.000000	Batch: 101	Acc: 0.284000
# Zoom Level: 1	Lr: 0.010100	Reg: 30.000000	Batch: 101	Acc: 0.244000
# Zoom Level: 1	Lr: 0.010100	Reg: 40.000000	Batch: 101	Acc: 0.284000
# Zoom Level: 1	Lr: 0.010100	Reg: 50.000000	Batch: 101	Acc: 0.226000
# Zoom Level: 1	Lr: 0.010100	Reg: 60.000000	Batch: 101	Acc: 0.214000
# Zoom Level: 1	Lr: 0.010100	Reg: 70.000000	Batch: 101	Acc: 0.224000
# Zoom Level: 1	Lr: 0.010100	Reg: 80.000000	Batch: 101	Acc: 0.218000
# Zoom Level: 1	Lr: 0.010100	Reg: 90.000000	Batch: 101	Acc: 0.224000
# Zoom Level: 1	Lr: 0.010100	Reg: 100.000000	Batch: 101	Acc: 0.258000
# Zoom Level: 1	Lr: 0.010100	Reg: 0.000000	Batch: 201	Acc: 0.330000
# Zoom Level: 1	Lr: 0.010100	Reg: 10.000000	Batch: 201	Acc: 0.284000
# Zoom Level: 1	Lr: 0.010100	Reg: 20.000000	Batch: 201	Acc: 0.270000
# Zoom Level: 1	Lr: 0.010100	Reg: 30.000000	Batch: 201	Acc: 0.254000
# Zoom Level: 1	Lr: 0.010100	Reg: 40.000000	Batch: 201	Acc: 0.272000
# Zoom Level: 1	Lr: 0.010100	Reg: 50.000000	Batch: 201	Acc: 0.248000
# Zoom Level: 1	Lr: 0.010100	Reg: 60.000000	Batch: 201	Acc: 0.270000
# Zoom Level: 1	Lr: 0.010100	Reg: 70.000000	Batch: 201	Acc: 0.232000
# Zoom Level: 1	Lr: 0.010100	Reg: 80.000000	Batch: 201	Acc: 0.272000
# Zoom Level: 1	Lr: 0.010100	Reg: 90.000000	Batch: 201	Acc: 0.220000
# Zoom Level: 1	Lr: 0.010100	Reg: 100.000000	Batch: 201	Acc: 0.208000
# Zoom Level: 1	Lr: 0.010100	Reg: 0.000000	Batch: 301	Acc: 0.356000
# Zoom Level: 1	Lr: 0.010100	Reg: 10.000000	Batch: 301	Acc: 0.284000
# Zoom Level: 1	Lr: 0.010100	Reg: 20.000000	Batch: 301	Acc: 0.264000
# Zoom Level: 1	Lr: 0.010100	Reg: 30.000000	Batch: 301	Acc: 0.256000
# Zoom Level: 1	Lr: 0.010100	Reg: 40.000000	Batch: 301	Acc: 0.268000
# Zoom Level: 1	Lr: 0.010100	Reg: 50.000000	Batch: 301	Acc: 0.266000
# Zoom Level: 1	Lr: 0.010100	Reg: 60.000000	Batch: 301	Acc: 0.224000
# Zoom Level: 1	Lr: 0.010100	Reg: 70.000000	Batch: 301	Acc: 0.268000
# Zoom Level: 1	Lr: 0.010100	Reg: 80.000000	Batch: 301	Acc: 0.230000
# Zoom Level: 1	Lr: 0.010100	Reg: 90.000000	Batch: 301	Acc: 0.246000
# Zoom Level: 1	Lr: 0.010100	Reg: 100.000000	Batch: 301	Acc: 0.228000
# Zoom Level: 1	Lr: 0.010100	Reg: 0.000000	Batch: 401	Acc: 0.316000
# Zoom Level: 1	Lr: 0.010100	Reg: 10.000000	Batch: 401	Acc: 0.258000
# Zoom Level: 1	Lr: 0.010100	Reg: 20.000000	Batch: 401	Acc: 0.268000
# Zoom Level: 1	Lr: 0.010100	Reg: 30.000000	Batch: 401	Acc: 0.270000
# Zoom Level: 1	Lr: 0.010100	Reg: 40.000000	Batch: 401	Acc: 0.272000
# Zoom Level: 1	Lr: 0.010100	Reg: 50.000000	Batch: 401	Acc: 0.256000
# Zoom Level: 1	Lr: 0.010100	Reg: 60.000000	Batch: 401	Acc: 0.232000
# Zoom Level: 1	Lr: 0.010100	Reg: 70.000000	Batch: 401	Acc: 0.236000
# Zoom Level: 1	Lr: 0.010100	Reg: 80.000000	Batch: 401	Acc: 0.232000
# Zoom Level: 1	Lr: 0.010100	Reg: 90.000000	Batch: 401	Acc: 0.252000
# Zoom Level: 1	Lr: 0.010100	Reg: 100.000000	Batch: 401	Acc: 0.200000
# Zoom Level: 1	Lr: 0.010100	Reg: 0.000000	Batch: 501	Acc: 0.294000
# Zoom Level: 1	Lr: 0.010100	Reg: 10.000000	Batch: 501	Acc: 0.284000
# Zoom Level: 1	Lr: 0.010100	Reg: 20.000000	Batch: 501	Acc: 0.294000
# Zoom Level: 1	Lr: 0.010100	Reg: 30.000000	Batch: 501	Acc: 0.244000
# Zoom Level: 1	Lr: 0.010100	Reg: 40.000000	Batch: 501	Acc: 0.242000
# Zoom Level: 1	Lr: 0.010100	Reg: 50.000000	Batch: 501	Acc: 0.268000
# Zoom Level: 1	Lr: 0.010100	Reg: 60.000000	Batch: 501	Acc: 0.266000
# Zoom Level: 1	Lr: 0.010100	Reg: 70.000000	Batch: 501	Acc: 0.264000
# Zoom Level: 1	Lr: 0.010100	Reg: 80.000000	Batch: 501	Acc: 0.234000
# Zoom Level: 1	Lr: 0.010100	Reg: 90.000000	Batch: 501	Acc: 0.246000
# Zoom Level: 1	Lr: 0.010100	Reg: 100.000000	Batch: 501	Acc: 0.236000
# Zoom Level: 1	Lr: 0.010100	Reg: 0.000000	Batch: 601	Acc: 0.290000
# Zoom Level: 1	Lr: 0.010100	Reg: 10.000000	Batch: 601	Acc: 0.288000
# Zoom Level: 1	Lr: 0.010100	Reg: 20.000000	Batch: 601	Acc: 0.284000
# Zoom Level: 1	Lr: 0.010100	Reg: 30.000000	Batch: 601	Acc: 0.264000
# Zoom Level: 1	Lr: 0.010100	Reg: 40.000000	Batch: 601	Acc: 0.246000
# Zoom Level: 1	Lr: 0.010100	Reg: 50.000000	Batch: 601	Acc: 0.268000
# Zoom Level: 1	Lr: 0.010100	Reg: 60.000000	Batch: 601	Acc: 0.282000
# Zoom Level: 1	Lr: 0.010100	Reg: 70.000000	Batch: 601	Acc: 0.214000
# Zoom Level: 1	Lr: 0.010100	Reg: 80.000000	Batch: 601	Acc: 0.238000
# Zoom Level: 1	Lr: 0.010100	Reg: 90.000000	Batch: 601	Acc: 0.254000
# Zoom Level: 1	Lr: 0.010100	Reg: 100.000000	Batch: 601	Acc: 0.212000
# Zoom Level: 1	Lr: 0.010100	Reg: 0.000000	Batch: 701	Acc: 0.296000
# Zoom Level: 1	Lr: 0.010100	Reg: 10.000000	Batch: 701	Acc: 0.290000
# Zoom Level: 1	Lr: 0.010100	Reg: 20.000000	Batch: 701	Acc: 0.278000
# Zoom Level: 1	Lr: 0.010100	Reg: 30.000000	Batch: 701	Acc: 0.242000
# Zoom Level: 1	Lr: 0.010100	Reg: 40.000000	Batch: 701	Acc: 0.244000
# Zoom Level: 1	Lr: 0.010100	Reg: 50.000000	Batch: 701	Acc: 0.262000
# Zoom Level: 1	Lr: 0.010100	Reg: 60.000000	Batch: 701	Acc: 0.246000
# Zoom Level: 1	Lr: 0.010100	Reg: 70.000000	Batch: 701	Acc: 0.244000
# Zoom Level: 1	Lr: 0.010100	Reg: 80.000000	Batch: 701	Acc: 0.234000
# Zoom Level: 1	Lr: 0.010100	Reg: 90.000000	Batch: 701	Acc: 0.210000
# Zoom Level: 1	Lr: 0.010100	Reg: 100.000000	Batch: 701	Acc: 0.236000
# Zoom Level: 1	Lr: 0.010100	Reg: 0.000000	Batch: 801	Acc: 0.284000
# Zoom Level: 1	Lr: 0.010100	Reg: 10.000000	Batch: 801	Acc: 0.282000
# Zoom Level: 1	Lr: 0.010100	Reg: 20.000000	Batch: 801	Acc: 0.256000
# Zoom Level: 1	Lr: 0.010100	Reg: 30.000000	Batch: 801	Acc: 0.290000
# Zoom Level: 1	Lr: 0.010100	Reg: 40.000000	Batch: 801	Acc: 0.246000
# Zoom Level: 1	Lr: 0.010100	Reg: 50.000000	Batch: 801	Acc: 0.250000
# Zoom Level: 1	Lr: 0.010100	Reg: 60.000000	Batch: 801	Acc: 0.272000
# Zoom Level: 1	Lr: 0.010100	Reg: 70.000000	Batch: 801	Acc: 0.244000
# Zoom Level: 1	Lr: 0.010100	Reg: 80.000000	Batch: 801	Acc: 0.246000
# Zoom Level: 1	Lr: 0.010100	Reg: 90.000000	Batch: 801	Acc: 0.264000
# Zoom Level: 1	Lr: 0.010100	Reg: 100.000000	Batch: 801	Acc: 0.228000
# Zoom Level: 1	Lr: 0.010100	Reg: 0.000000	Batch: 901	Acc: 0.258000
# Zoom Level: 1	Lr: 0.010100	Reg: 10.000000	Batch: 901	Acc: 0.256000
# Zoom Level: 1	Lr: 0.010100	Reg: 20.000000	Batch: 901	Acc: 0.286000
# Zoom Level: 1	Lr: 0.010100	Reg: 30.000000	Batch: 901	Acc: 0.276000
# Zoom Level: 1	Lr: 0.010100	Reg: 40.000000	Batch: 901	Acc: 0.260000
# Zoom Level: 1	Lr: 0.010100	Reg: 50.000000	Batch: 901	Acc: 0.252000
# Zoom Level: 1	Lr: 0.010100	Reg: 60.000000	Batch: 901	Acc: 0.276000
# Zoom Level: 1	Lr: 0.010100	Reg: 70.000000	Batch: 901	Acc: 0.270000
# Zoom Level: 1	Lr: 0.010100	Reg: 80.000000	Batch: 901	Acc: 0.250000
# Zoom Level: 1	Lr: 0.010100	Reg: 90.000000	Batch: 901	Acc: 0.258000
# Zoom Level: 1	Lr: 0.010100	Reg: 100.000000	Batch: 901	Acc: 0.262000
# Zoom Level: 1	Lr: 0.020100	Reg: 0.000000	Batch: 101	Acc: 0.354000
# Zoom Level: 1	Lr: 0.020100	Reg: 10.000000	Batch: 101	Acc: 0.258000
# Zoom Level: 1	Lr: 0.020100	Reg: 20.000000	Batch: 101	Acc: 0.220000
# Zoom Level: 1	Lr: 0.020100	Reg: 30.000000	Batch: 101	Acc: 0.246000
# Zoom Level: 1	Lr: 0.020100	Reg: 40.000000	Batch: 101	Acc: 0.246000
# Zoom Level: 1	Lr: 0.020100	Reg: 50.000000	Batch: 101	Acc: 0.220000
# Zoom Level: 1	Lr: 0.020100	Reg: 60.000000	Batch: 101	Acc: 0.210000
# Zoom Level: 1	Lr: 0.020100	Reg: 70.000000	Batch: 101	Acc: 0.170000
# Zoom Level: 1	Lr: 0.020100	Reg: 80.000000	Batch: 101	Acc: 0.160000
# Zoom Level: 1	Lr: 0.020100	Reg: 90.000000	Batch: 101	Acc: 0.166000
# /Users/dhruv/Documents/All Documents Backup/School/2019 Fall/CS343/cs343projects/project2/single_layer_net.py:279: RuntimeWarning: divide by zero encountered in log
#   log_act = np.log(self.activation(net_in))
# Zoom Level: 1	Lr: 0.020100	Reg: 100.000000	Batch: 101	Acc: 0.082000
# Zoom Level: 1	Lr: 0.020100	Reg: 0.000000	Batch: 201	Acc: 0.352000
# Zoom Level: 1	Lr: 0.020100	Reg: 10.000000	Batch: 201	Acc: 0.286000
# Zoom Level: 1	Lr: 0.020100	Reg: 20.000000	Batch: 201	Acc: 0.258000
# Zoom Level: 1	Lr: 0.020100	Reg: 30.000000	Batch: 201	Acc: 0.240000
# Zoom Level: 1	Lr: 0.020100	Reg: 40.000000	Batch: 201	Acc: 0.254000
# Zoom Level: 1	Lr: 0.020100	Reg: 50.000000	Batch: 201	Acc: 0.246000
# Zoom Level: 1	Lr: 0.020100	Reg: 60.000000	Batch: 201	Acc: 0.218000
# Zoom Level: 1	Lr: 0.020100	Reg: 70.000000	Batch: 201	Acc: 0.204000
# Zoom Level: 1	Lr: 0.020100	Reg: 80.000000	Batch: 201	Acc: 0.224000
# Zoom Level: 1	Lr: 0.020100	Reg: 90.000000	Batch: 201	Acc: 0.124000
# Zoom Level: 1	Lr: 0.020100	Reg: 100.000000	Batch: 201	Acc: 0.072000
# Zoom Level: 1	Lr: 0.020100	Reg: 0.000000	Batch: 301	Acc: 0.334000
# Zoom Level: 1	Lr: 0.020100	Reg: 10.000000	Batch: 301	Acc: 0.268000
# Zoom Level: 1	Lr: 0.020100	Reg: 20.000000	Batch: 301	Acc: 0.274000
# Zoom Level: 1	Lr: 0.020100	Reg: 30.000000	Batch: 301	Acc: 0.222000
# Zoom Level: 1	Lr: 0.020100	Reg: 40.000000	Batch: 301	Acc: 0.236000
# Zoom Level: 1	Lr: 0.020100	Reg: 50.000000	Batch: 301	Acc: 0.232000
# Zoom Level: 1	Lr: 0.020100	Reg: 60.000000	Batch: 301	Acc: 0.254000
# Zoom Level: 1	Lr: 0.020100	Reg: 70.000000	Batch: 301	Acc: 0.220000
# Zoom Level: 1	Lr: 0.020100	Reg: 80.000000	Batch: 301	Acc: 0.242000
# Zoom Level: 1	Lr: 0.020100	Reg: 90.000000	Batch: 301	Acc: 0.202000
# Zoom Level: 1	Lr: 0.020100	Reg: 100.000000	Batch: 301	Acc: 0.122000
# Zoom Level: 1	Lr: 0.020100	Reg: 0.000000	Batch: 401	Acc: 0.336000
# Zoom Level: 1	Lr: 0.020100	Reg: 10.000000	Batch: 401	Acc: 0.284000
# Zoom Level: 1	Lr: 0.020100	Reg: 20.000000	Batch: 401	Acc: 0.256000
# Zoom Level: 1	Lr: 0.020100	Reg: 30.000000	Batch: 401	Acc: 0.246000
# Zoom Level: 1	Lr: 0.020100	Reg: 40.000000	Batch: 401	Acc: 0.246000
# Zoom Level: 1	Lr: 0.020100	Reg: 50.000000	Batch: 401	Acc: 0.192000
# Zoom Level: 1	Lr: 0.020100	Reg: 60.000000	Batch: 401	Acc: 0.228000
# Zoom Level: 1	Lr: 0.020100	Reg: 70.000000	Batch: 401	Acc: 0.238000
# Zoom Level: 1	Lr: 0.020100	Reg: 80.000000	Batch: 401	Acc: 0.234000
# Zoom Level: 1	Lr: 0.020100	Reg: 90.000000	Batch: 401	Acc: 0.164000
# Zoom Level: 1	Lr: 0.020100	Reg: 100.000000	Batch: 401	Acc: 0.046000
# Zoom Level: 1	Lr: 0.020100	Reg: 0.000000	Batch: 501	Acc: 0.350000
# Zoom Level: 1	Lr: 0.020100	Reg: 10.000000	Batch: 501	Acc: 0.304000
# Zoom Level: 1	Lr: 0.020100	Reg: 20.000000	Batch: 501	Acc: 0.248000
# Zoom Level: 1	Lr: 0.020100	Reg: 30.000000	Batch: 501	Acc: 0.258000
# Zoom Level: 1	Lr: 0.020100	Reg: 40.000000	Batch: 501	Acc: 0.242000
# Zoom Level: 1	Lr: 0.020100	Reg: 50.000000	Batch: 501	Acc: 0.262000
# Zoom Level: 1	Lr: 0.020100	Reg: 60.000000	Batch: 501	Acc: 0.242000
# Zoom Level: 1	Lr: 0.020100	Reg: 70.000000	Batch: 501	Acc: 0.218000
# Zoom Level: 1	Lr: 0.020100	Reg: 80.000000	Batch: 501	Acc: 0.180000
# Zoom Level: 1	Lr: 0.020100	Reg: 90.000000	Batch: 501	Acc: 0.142000
# Zoom Level: 1	Lr: 0.020100	Reg: 100.000000	Batch: 501	Acc: 0.086000
# Zoom Level: 1	Lr: 0.020100	Reg: 0.000000	Batch: 601	Acc: 0.338000
# Zoom Level: 1	Lr: 0.020100	Reg: 10.000000	Batch: 601	Acc: 0.288000
# Zoom Level: 1	Lr: 0.020100	Reg: 20.000000	Batch: 601	Acc: 0.268000
# Zoom Level: 1	Lr: 0.020100	Reg: 30.000000	Batch: 601	Acc: 0.274000
# Zoom Level: 1	Lr: 0.020100	Reg: 40.000000	Batch: 601	Acc: 0.240000
# Zoom Level: 1	Lr: 0.020100	Reg: 50.000000	Batch: 601	Acc: 0.220000
# Zoom Level: 1	Lr: 0.020100	Reg: 60.000000	Batch: 601	Acc: 0.242000
# Zoom Level: 1	Lr: 0.020100	Reg: 70.000000	Batch: 601	Acc: 0.230000
# Zoom Level: 1	Lr: 0.020100	Reg: 80.000000	Batch: 601	Acc: 0.214000
# Zoom Level: 1	Lr: 0.020100	Reg: 90.000000	Batch: 601	Acc: 0.228000
# Zoom Level: 1	Lr: 0.020100	Reg: 100.000000	Batch: 601	Acc: 0.066000
# Zoom Level: 1	Lr: 0.020100	Reg: 0.000000	Batch: 701	Acc: 0.304000
# Zoom Level: 1	Lr: 0.020100	Reg: 10.000000	Batch: 701	Acc: 0.268000
# Zoom Level: 1	Lr: 0.020100	Reg: 20.000000	Batch: 701	Acc: 0.276000
# Zoom Level: 1	Lr: 0.020100	Reg: 30.000000	Batch: 701	Acc: 0.276000
# Zoom Level: 1	Lr: 0.020100	Reg: 40.000000	Batch: 701	Acc: 0.242000
# Zoom Level: 1	Lr: 0.020100	Reg: 50.000000	Batch: 701	Acc: 0.220000
# Zoom Level: 1	Lr: 0.020100	Reg: 60.000000	Batch: 701	Acc: 0.278000
# Zoom Level: 1	Lr: 0.020100	Reg: 70.000000	Batch: 701	Acc: 0.210000
# Zoom Level: 1	Lr: 0.020100	Reg: 80.000000	Batch: 701	Acc: 0.214000
# Zoom Level: 1	Lr: 0.020100	Reg: 90.000000	Batch: 701	Acc: 0.204000
# Zoom Level: 1	Lr: 0.020100	Reg: 100.000000	Batch: 701	Acc: 0.090000
# Zoom Level: 1	Lr: 0.020100	Reg: 0.000000	Batch: 801	Acc: 0.320000
# Zoom Level: 1	Lr: 0.020100	Reg: 10.000000	Batch: 801	Acc: 0.274000
# Zoom Level: 1	Lr: 0.020100	Reg: 20.000000	Batch: 801	Acc: 0.292000
# Zoom Level: 1	Lr: 0.020100	Reg: 30.000000	Batch: 801	Acc: 0.278000
# Zoom Level: 1	Lr: 0.020100	Reg: 40.000000	Batch: 801	Acc: 0.246000
# Zoom Level: 1	Lr: 0.020100	Reg: 50.000000	Batch: 801	Acc: 0.262000
# Zoom Level: 1	Lr: 0.020100	Reg: 60.000000	Batch: 801	Acc: 0.246000
# Zoom Level: 1	Lr: 0.020100	Reg: 70.000000	Batch: 801	Acc: 0.228000
# Zoom Level: 1	Lr: 0.020100	Reg: 80.000000	Batch: 801	Acc: 0.246000
# Zoom Level: 1	Lr: 0.020100	Reg: 90.000000	Batch: 801	Acc: 0.202000
# Zoom Level: 1	Lr: 0.020100	Reg: 100.000000	Batch: 801	Acc: 0.056000
# Zoom Level: 1	Lr: 0.020100	Reg: 0.000000	Batch: 901	Acc: 0.304000
# Zoom Level: 1	Lr: 0.020100	Reg: 10.000000	Batch: 901	Acc: 0.288000
# Zoom Level: 1	Lr: 0.020100	Reg: 20.000000	Batch: 901	Acc: 0.264000
# Zoom Level: 1	Lr: 0.020100	Reg: 30.000000	Batch: 901	Acc: 0.258000
# Zoom Level: 1	Lr: 0.020100	Reg: 40.000000	Batch: 901	Acc: 0.284000
# Zoom Level: 1	Lr: 0.020100	Reg: 50.000000	Batch: 901	Acc: 0.246000
# Zoom Level: 1	Lr: 0.020100	Reg: 60.000000	Batch: 901	Acc: 0.266000
# Zoom Level: 1	Lr: 0.020100	Reg: 70.000000	Batch: 901	Acc: 0.242000
# Zoom Level: 1	Lr: 0.020100	Reg: 80.000000	Batch: 901	Acc: 0.248000
# Zoom Level: 1	Lr: 0.020100	Reg: 90.000000	Batch: 901	Acc: 0.242000
# Zoom Level: 1	Lr: 0.020100	Reg: 100.000000	Batch: 901	Acc: 0.108000
# Zoom Level: 1	Lr: 0.030100	Reg: 0.000000	Batch: 101	Acc: 0.366000
# Zoom Level: 1	Lr: 0.030100	Reg: 10.000000	Batch: 101	Acc: 0.256000
# Zoom Level: 1	Lr: 0.030100	Reg: 20.000000	Batch: 101	Acc: 0.254000
# Zoom Level: 1	Lr: 0.030100	Reg: 30.000000	Batch: 101	Acc: 0.254000
# Zoom Level: 1	Lr: 0.030100	Reg: 40.000000	Batch: 101	Acc: 0.194000
# Zoom Level: 1	Lr: 0.030100	Reg: 50.000000	Batch: 101	Acc: 0.172000
# Zoom Level: 1	Lr: 0.030100	Reg: 60.000000	Batch: 101	Acc: 0.182000
# Zoom Level: 1	Lr: 0.030100	Reg: 70.000000	Batch: 101	Acc: 0.132000
# Zoom Level: 1	Lr: 0.030100	Reg: 80.000000	Batch: 101	Acc: 0.060000
# Zoom Level: 1	Lr: 0.030100	Reg: 90.000000	Batch: 101	Acc: 0.110000
# Zoom Level: 1	Lr: 0.030100	Reg: 100.000000	Batch: 101	Acc: 0.070000
# Zoom Level: 1	Lr: 0.030100	Reg: 0.000000	Batch: 201	Acc: 0.364000
# Zoom Level: 1	Lr: 0.030100	Reg: 10.000000	Batch: 201	Acc: 0.262000
# Zoom Level: 1	Lr: 0.030100	Reg: 20.000000	Batch: 201	Acc: 0.236000
# Zoom Level: 1	Lr: 0.030100	Reg: 30.000000	Batch: 201	Acc: 0.268000
# Zoom Level: 1	Lr: 0.030100	Reg: 40.000000	Batch: 201	Acc: 0.242000
# Zoom Level: 1	Lr: 0.030100	Reg: 50.000000	Batch: 201	Acc: 0.226000
# Zoom Level: 1	Lr: 0.030100	Reg: 60.000000	Batch: 201	Acc: 0.102000
# Zoom Level: 1	Lr: 0.030100	Reg: 70.000000	Batch: 201	Acc: 0.080000
# Zoom Level: 1	Lr: 0.030100	Reg: 80.000000	Batch: 201	Acc: 0.066000
# Zoom Level: 1	Lr: 0.030100	Reg: 90.000000	Batch: 201	Acc: 0.096000
# Zoom Level: 1	Lr: 0.030100	Reg: 100.000000	Batch: 201	Acc: 0.088000
# Zoom Level: 1	Lr: 0.030100	Reg: 0.000000	Batch: 301	Acc: 0.356000
# Zoom Level: 1	Lr: 0.030100	Reg: 10.000000	Batch: 301	Acc: 0.274000
# Zoom Level: 1	Lr: 0.030100	Reg: 20.000000	Batch: 301	Acc: 0.268000
# Zoom Level: 1	Lr: 0.030100	Reg: 30.000000	Batch: 301	Acc: 0.266000
# Zoom Level: 1	Lr: 0.030100	Reg: 40.000000	Batch: 301	Acc: 0.218000
# Zoom Level: 1	Lr: 0.030100	Reg: 50.000000	Batch: 301	Acc: 0.216000
# Zoom Level: 1	Lr: 0.030100	Reg: 60.000000	Batch: 301	Acc: 0.210000
# Zoom Level: 1	Lr: 0.030100	Reg: 70.000000	Batch: 301	Acc: 0.044000
# Zoom Level: 1	Lr: 0.030100	Reg: 80.000000	Batch: 301	Acc: 0.080000
# Zoom Level: 1	Lr: 0.030100	Reg: 90.000000	Batch: 301	Acc: 0.068000
# Zoom Level: 1	Lr: 0.030100	Reg: 100.000000	Batch: 301	Acc: 0.102000
# Zoom Level: 1	Lr: 0.030100	Reg: 0.000000	Batch: 401	Acc: 0.354000
# Zoom Level: 1	Lr: 0.030100	Reg: 10.000000	Batch: 401	Acc: 0.282000
# Zoom Level: 1	Lr: 0.030100	Reg: 20.000000	Batch: 401	Acc: 0.286000
# Zoom Level: 1	Lr: 0.030100	Reg: 30.000000	Batch: 401	Acc: 0.252000
# Zoom Level: 1	Lr: 0.030100	Reg: 40.000000	Batch: 401	Acc: 0.248000
# Zoom Level: 1	Lr: 0.030100	Reg: 50.000000	Batch: 401	Acc: 0.238000
# Zoom Level: 1	Lr: 0.030100	Reg: 60.000000	Batch: 401	Acc: 0.194000
# Zoom Level: 1	Lr: 0.030100	Reg: 70.000000	Batch: 401	Acc: 0.042000
# Zoom Level: 1	Lr: 0.030100	Reg: 80.000000	Batch: 401	Acc: 0.034000
# Zoom Level: 1	Lr: 0.030100	Reg: 90.000000	Batch: 401	Acc: 0.086000
# Zoom Level: 1	Lr: 0.030100	Reg: 100.000000	Batch: 401	Acc: 0.066000
# Zoom Level: 1	Lr: 0.030100	Reg: 0.000000	Batch: 501	Acc: 0.362000
# Zoom Level: 1	Lr: 0.030100	Reg: 10.000000	Batch: 501	Acc: 0.290000
# Zoom Level: 1	Lr: 0.030100	Reg: 20.000000	Batch: 501	Acc: 0.258000
# Zoom Level: 1	Lr: 0.030100	Reg: 30.000000	Batch: 501	Acc: 0.260000
# Zoom Level: 1	Lr: 0.030100	Reg: 40.000000	Batch: 501	Acc: 0.212000
# Zoom Level: 1	Lr: 0.030100	Reg: 50.000000	Batch: 501	Acc: 0.232000
# Zoom Level: 1	Lr: 0.030100	Reg: 60.000000	Batch: 501	Acc: 0.180000
# Zoom Level: 1	Lr: 0.030100	Reg: 70.000000	Batch: 501	Acc: 0.024000
# Zoom Level: 1	Lr: 0.030100	Reg: 80.000000	Batch: 501	Acc: 0.072000
# Zoom Level: 1	Lr: 0.030100	Reg: 90.000000	Batch: 501	Acc: 0.068000
# Zoom Level: 1	Lr: 0.030100	Reg: 100.000000	Batch: 501	Acc: 0.054000
# Zoom Level: 1	Lr: 0.030100	Reg: 0.000000	Batch: 601	Acc: 0.350000
# Zoom Level: 1	Lr: 0.030100	Reg: 10.000000	Batch: 601	Acc: 0.292000
# Zoom Level: 1	Lr: 0.030100	Reg: 20.000000	Batch: 601	Acc: 0.288000
# Zoom Level: 1	Lr: 0.030100	Reg: 30.000000	Batch: 601	Acc: 0.262000
# Zoom Level: 1	Lr: 0.030100	Reg: 40.000000	Batch: 601	Acc: 0.230000
# Zoom Level: 1	Lr: 0.030100	Reg: 50.000000	Batch: 601	Acc: 0.236000
# Zoom Level: 1	Lr: 0.030100	Reg: 60.000000	Batch: 601	Acc: 0.200000
# Zoom Level: 1	Lr: 0.030100	Reg: 70.000000	Batch: 601	Acc: 0.108000
# Zoom Level: 1	Lr: 0.030100	Reg: 80.000000	Batch: 601	Acc: 0.104000
# Zoom Level: 1	Lr: 0.030100	Reg: 90.000000	Batch: 601	Acc: 0.108000
# Zoom Level: 1	Lr: 0.030100	Reg: 100.000000	Batch: 601	Acc: 0.102000
# Zoom Level: 1	Lr: 0.030100	Reg: 0.000000	Batch: 701	Acc: 0.332000
# Zoom Level: 1	Lr: 0.030100	Reg: 10.000000	Batch: 701	Acc: 0.280000
# Zoom Level: 1	Lr: 0.030100	Reg: 20.000000	Batch: 701	Acc: 0.250000
# Zoom Level: 1	Lr: 0.030100	Reg: 30.000000	Batch: 701	Acc: 0.266000
# Zoom Level: 1	Lr: 0.030100	Reg: 40.000000	Batch: 701	Acc: 0.258000
# Zoom Level: 1	Lr: 0.030100	Reg: 50.000000	Batch: 701	Acc: 0.248000
# Zoom Level: 1	Lr: 0.030100	Reg: 60.000000	Batch: 701	Acc: 0.194000
# Zoom Level: 1	Lr: 0.030100	Reg: 70.000000	Batch: 701	Acc: 0.068000
# Zoom Level: 1	Lr: 0.030100	Reg: 80.000000	Batch: 701	Acc: 0.070000
# Zoom Level: 1	Lr: 0.030100	Reg: 90.000000	Batch: 701	Acc: 0.084000
# Zoom Level: 1	Lr: 0.030100	Reg: 100.000000	Batch: 701	Acc: 0.076000
# Zoom Level: 1	Lr: 0.030100	Reg: 0.000000	Batch: 801	Acc: 0.320000
# Zoom Level: 1	Lr: 0.030100	Reg: 10.000000	Batch: 801	Acc: 0.288000
# Zoom Level: 1	Lr: 0.030100	Reg: 20.000000	Batch: 801	Acc: 0.264000
# Zoom Level: 1	Lr: 0.030100	Reg: 30.000000	Batch: 801	Acc: 0.230000
# Zoom Level: 1	Lr: 0.030100	Reg: 40.000000	Batch: 801	Acc: 0.278000
# Zoom Level: 1	Lr: 0.030100	Reg: 50.000000	Batch: 801	Acc: 0.242000
# Zoom Level: 1	Lr: 0.030100	Reg: 60.000000	Batch: 801	Acc: 0.200000
# Zoom Level: 1	Lr: 0.030100	Reg: 70.000000	Batch: 801	Acc: 0.104000
# Zoom Level: 1	Lr: 0.030100	Reg: 80.000000	Batch: 801	Acc: 0.066000
# Zoom Level: 1	Lr: 0.030100	Reg: 90.000000	Batch: 801	Acc: 0.116000
# Zoom Level: 1	Lr: 0.030100	Reg: 100.000000	Batch: 801	Acc: 0.090000
# Zoom Level: 1	Lr: 0.030100	Reg: 0.000000	Batch: 901	Acc: 0.318000
# Zoom Level: 1	Lr: 0.030100	Reg: 10.000000	Batch: 901	Acc: 0.296000
# Zoom Level: 1	Lr: 0.030100	Reg: 20.000000	Batch: 901	Acc: 0.262000
# Zoom Level: 1	Lr: 0.030100	Reg: 30.000000	Batch: 901	Acc: 0.286000
# Zoom Level: 1	Lr: 0.030100	Reg: 40.000000	Batch: 901	Acc: 0.272000
# Zoom Level: 1	Lr: 0.030100	Reg: 50.000000	Batch: 901	Acc: 0.218000
# Zoom Level: 1	Lr: 0.030100	Reg: 60.000000	Batch: 901	Acc: 0.192000
# Zoom Level: 1	Lr: 0.030100	Reg: 70.000000	Batch: 901	Acc: 0.116000
# Zoom Level: 1	Lr: 0.030100	Reg: 80.000000	Batch: 901	Acc: 0.096000
# Zoom Level: 1	Lr: 0.030100	Reg: 90.000000	Batch: 901	Acc: 0.074000
# Zoom Level: 1	Lr: 0.030100	Reg: 100.000000	Batch: 901	Acc: 0.060000
# Zoom Level: 1	Lr: 0.040100	Reg: 0.000000	Batch: 101	Acc: 0.356000
# Zoom Level: 1	Lr: 0.040100	Reg: 10.000000	Batch: 101	Acc: 0.268000
# Zoom Level: 1	Lr: 0.040100	Reg: 20.000000	Batch: 101	Acc: 0.220000
# Zoom Level: 1	Lr: 0.040100	Reg: 30.000000	Batch: 101	Acc: 0.244000
# Zoom Level: 1	Lr: 0.040100	Reg: 40.000000	Batch: 101	Acc: 0.220000
# Zoom Level: 1	Lr: 0.040100	Reg: 50.000000	Batch: 101	Acc: 0.082000
# Zoom Level: 1	Lr: 0.040100	Reg: 60.000000	Batch: 101	Acc: 0.066000
# Zoom Level: 1	Lr: 0.040100	Reg: 70.000000	Batch: 101	Acc: 0.038000
# Zoom Level: 1	Lr: 0.040100	Reg: 80.000000	Batch: 101	Acc: 0.110000
# Zoom Level: 1	Lr: 0.040100	Reg: 90.000000	Batch: 101	Acc: 0.090000
# /Users/dhruv/Documents/All Documents Backup/School/2019 Fall/CS343/cs343projects/project2/single_layer_net.py:283: RuntimeWarning: overflow encountered in double_scalars
#   loss = ((-1/N) * np.sum(correct_loss)) + ((1/2) * reg * np.sum(np.square(self.wts)))
# /Users/dhruv/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/dhruv/Documents/All Documents Backup/School/2019 Fall/CS343/cs343projects/project2/single_layer_net.py:283: RuntimeWarning: overflow encountered in square
#   loss = ((-1/N) * np.sum(correct_loss)) + ((1/2) * reg * np.sum(np.square(self.wts)))
# Zoom Level: 1	Lr: 0.040100	Reg: 100.000000	Batch: 101	Acc: 0.080000
# Zoom Level: 1	Lr: 0.040100	Reg: 0.000000	Batch: 201	Acc: 0.364000
# Zoom Level: 1	Lr: 0.040100	Reg: 10.000000	Batch: 201	Acc: 0.268000
# Zoom Level: 1	Lr: 0.040100	Reg: 20.000000	Batch: 201	Acc: 0.256000
# Zoom Level: 1	Lr: 0.040100	Reg: 30.000000	Batch: 201	Acc: 0.242000
# Zoom Level: 1	Lr: 0.040100	Reg: 40.000000	Batch: 201	Acc: 0.224000
# Zoom Level: 1	Lr: 0.040100	Reg: 50.000000	Batch: 201	Acc: 0.034000
# Zoom Level: 1	Lr: 0.040100	Reg: 60.000000	Batch: 201	Acc: 0.066000
# Zoom Level: 1	Lr: 0.040100	Reg: 70.000000	Batch: 201	Acc: 0.064000
# Zoom Level: 1	Lr: 0.040100	Reg: 80.000000	Batch: 201	Acc: 0.118000
# Zoom Level: 1	Lr: 0.040100	Reg: 90.000000	Batch: 201	Acc: 0.040000
# Zoom Level: 1	Lr: 0.040100	Reg: 100.000000	Batch: 201	Acc: 0.072000
# Zoom Level: 1	Lr: 0.040100	Reg: 0.000000	Batch: 301	Acc: 0.354000
# Zoom Level: 1	Lr: 0.040100	Reg: 10.000000	Batch: 301	Acc: 0.262000
# Zoom Level: 1	Lr: 0.040100	Reg: 20.000000	Batch: 301	Acc: 0.284000
# Zoom Level: 1	Lr: 0.040100	Reg: 30.000000	Batch: 301	Acc: 0.266000
# Zoom Level: 1	Lr: 0.040100	Reg: 40.000000	Batch: 301	Acc: 0.198000
# Zoom Level: 1	Lr: 0.040100	Reg: 50.000000	Batch: 301	Acc: 0.132000
# Zoom Level: 1	Lr: 0.040100	Reg: 60.000000	Batch: 301	Acc: 0.050000
# Zoom Level: 1	Lr: 0.040100	Reg: 70.000000	Batch: 301	Acc: 0.108000
# Zoom Level: 1	Lr: 0.040100	Reg: 80.000000	Batch: 301	Acc: 0.084000
# Zoom Level: 1	Lr: 0.040100	Reg: 90.000000	Batch: 301	Acc: 0.064000
# Zoom Level: 1	Lr: 0.040100	Reg: 100.000000	Batch: 301	Acc: 0.080000
# Zoom Level: 1	Lr: 0.040100	Reg: 0.000000	Batch: 401	Acc: 0.346000
# Zoom Level: 1	Lr: 0.040100	Reg: 10.000000	Batch: 401	Acc: 0.278000
# Zoom Level: 1	Lr: 0.040100	Reg: 20.000000	Batch: 401	Acc: 0.236000
# Zoom Level: 1	Lr: 0.040100	Reg: 30.000000	Batch: 401	Acc: 0.250000
# Zoom Level: 1	Lr: 0.040100	Reg: 40.000000	Batch: 401	Acc: 0.240000
# Zoom Level: 1	Lr: 0.040100	Reg: 50.000000	Batch: 401	Acc: 0.058000
# Zoom Level: 1	Lr: 0.040100	Reg: 60.000000	Batch: 401	Acc: 0.080000
# Zoom Level: 1	Lr: 0.040100	Reg: 70.000000	Batch: 401	Acc: 0.048000
# Zoom Level: 1	Lr: 0.040100	Reg: 80.000000	Batch: 401	Acc: 0.082000
# Zoom Level: 1	Lr: 0.040100	Reg: 90.000000	Batch: 401	Acc: 0.076000
# Zoom Level: 1	Lr: 0.040100	Reg: 100.000000	Batch: 401	Acc: 0.070000
# Zoom Level: 1	Lr: 0.040100	Reg: 0.000000	Batch: 501	Acc: 0.366000
# Zoom Level: 1	Lr: 0.040100	Reg: 10.000000	Batch: 501	Acc: 0.292000
# Zoom Level: 1	Lr: 0.040100	Reg: 20.000000	Batch: 501	Acc: 0.286000
# Zoom Level: 1	Lr: 0.040100	Reg: 30.000000	Batch: 501	Acc: 0.228000
# Zoom Level: 1	Lr: 0.040100	Reg: 40.000000	Batch: 501	Acc: 0.244000
# Zoom Level: 1	Lr: 0.040100	Reg: 50.000000	Batch: 501	Acc: 0.070000
# Zoom Level: 1	Lr: 0.040100	Reg: 60.000000	Batch: 501	Acc: 0.070000
# Zoom Level: 1	Lr: 0.040100	Reg: 70.000000	Batch: 501	Acc: 0.068000
# Zoom Level: 1	Lr: 0.040100	Reg: 80.000000	Batch: 501	Acc: 0.054000
# Zoom Level: 1	Lr: 0.040100	Reg: 90.000000	Batch: 501	Acc: 0.108000
# Zoom Level: 1	Lr: 0.040100	Reg: 100.000000	Batch: 501	Acc: 0.076000
# Zoom Level: 1	Lr: 0.040100	Reg: 0.000000	Batch: 601	Acc: 0.330000
# Zoom Level: 1	Lr: 0.040100	Reg: 10.000000	Batch: 601	Acc: 0.272000
# Zoom Level: 1	Lr: 0.040100	Reg: 20.000000	Batch: 601	Acc: 0.242000
# Zoom Level: 1	Lr: 0.040100	Reg: 30.000000	Batch: 601	Acc: 0.254000
# Zoom Level: 1	Lr: 0.040100	Reg: 40.000000	Batch: 601	Acc: 0.244000
# Zoom Level: 1	Lr: 0.040100	Reg: 50.000000	Batch: 601	Acc: 0.050000
# Zoom Level: 1	Lr: 0.040100	Reg: 60.000000	Batch: 601	Acc: 0.068000
# Zoom Level: 1	Lr: 0.040100	Reg: 70.000000	Batch: 601	Acc: 0.088000
# Zoom Level: 1	Lr: 0.040100	Reg: 80.000000	Batch: 601	Acc: 0.050000
# Zoom Level: 1	Lr: 0.040100	Reg: 90.000000	Batch: 601	Acc: 0.078000
# Zoom Level: 1	Lr: 0.040100	Reg: 100.000000	Batch: 601	Acc: 0.104000
# Zoom Level: 1	Lr: 0.040100	Reg: 0.000000	Batch: 701	Acc: 0.358000
# Zoom Level: 1	Lr: 0.040100	Reg: 10.000000	Batch: 701	Acc: 0.260000
# Zoom Level: 1	Lr: 0.040100	Reg: 20.000000	Batch: 701	Acc: 0.266000
# Zoom Level: 1	Lr: 0.040100	Reg: 30.000000	Batch: 701	Acc: 0.262000
# Zoom Level: 1	Lr: 0.040100	Reg: 40.000000	Batch: 701	Acc: 0.228000
# Zoom Level: 1	Lr: 0.040100	Reg: 50.000000	Batch: 701	Acc: 0.062000
# Zoom Level: 1	Lr: 0.040100	Reg: 60.000000	Batch: 701	Acc: 0.034000
# Zoom Level: 1	Lr: 0.040100	Reg: 70.000000	Batch: 701	Acc: 0.048000
# Zoom Level: 1	Lr: 0.040100	Reg: 80.000000	Batch: 701	Acc: 0.048000
# Zoom Level: 1	Lr: 0.040100	Reg: 90.000000	Batch: 701	Acc: 0.078000
# Zoom Level: 1	Lr: 0.040100	Reg: 100.000000	Batch: 701	Acc: 0.120000
# Zoom Level: 1	Lr: 0.040100	Reg: 0.000000	Batch: 801	Acc: 0.346000
# Zoom Level: 1	Lr: 0.040100	Reg: 10.000000	Batch: 801	Acc: 0.266000
# Zoom Level: 1	Lr: 0.040100	Reg: 20.000000	Batch: 801	Acc: 0.272000
# Zoom Level: 1	Lr: 0.040100	Reg: 30.000000	Batch: 801	Acc: 0.224000
# Zoom Level: 1	Lr: 0.040100	Reg: 40.000000	Batch: 801	Acc: 0.246000
# Zoom Level: 1	Lr: 0.040100	Reg: 50.000000	Batch: 801	Acc: 0.112000
# Zoom Level: 1	Lr: 0.040100	Reg: 60.000000	Batch: 801	Acc: 0.072000
# Zoom Level: 1	Lr: 0.040100	Reg: 70.000000	Batch: 801	Acc: 0.084000
# Zoom Level: 1	Lr: 0.040100	Reg: 80.000000	Batch: 801	Acc: 0.064000
# Zoom Level: 1	Lr: 0.040100	Reg: 90.000000	Batch: 801	Acc: 0.036000
# Zoom Level: 1	Lr: 0.040100	Reg: 100.000000	Batch: 801	Acc: 0.066000
# Zoom Level: 1	Lr: 0.040100	Reg: 0.000000	Batch: 901	Acc: 0.334000
# Zoom Level: 1	Lr: 0.040100	Reg: 10.000000	Batch: 901	Acc: 0.294000
# Zoom Level: 1	Lr: 0.040100	Reg: 20.000000	Batch: 901	Acc: 0.244000
# Zoom Level: 1	Lr: 0.040100	Reg: 30.000000	Batch: 901	Acc: 0.260000
# Zoom Level: 1	Lr: 0.040100	Reg: 40.000000	Batch: 901	Acc: 0.246000
# Zoom Level: 1	Lr: 0.040100	Reg: 50.000000	Batch: 901	Acc: 0.030000
# Zoom Level: 1	Lr: 0.040100	Reg: 60.000000	Batch: 901	Acc: 0.068000
# Zoom Level: 1	Lr: 0.040100	Reg: 70.000000	Batch: 901	Acc: 0.054000
# Zoom Level: 1	Lr: 0.040100	Reg: 80.000000	Batch: 901	Acc: 0.082000
# Zoom Level: 1	Lr: 0.040100	Reg: 90.000000	Batch: 901	Acc: 0.072000
# Zoom Level: 1	Lr: 0.040100	Reg: 100.000000	Batch: 901	Acc: 0.074000
# Zoom Level: 1	Lr: 0.050100	Reg: 0.000000	Batch: 101	Acc: 0.372000
# Zoom Level: 1	Lr: 0.050100	Reg: 10.000000	Batch: 101	Acc: 0.272000
# Zoom Level: 1	Lr: 0.050100	Reg: 20.000000	Batch: 101	Acc: 0.202000
# Zoom Level: 1	Lr: 0.050100	Reg: 30.000000	Batch: 101	Acc: 0.228000
# Zoom Level: 1	Lr: 0.050100	Reg: 40.000000	Batch: 101	Acc: 0.086000
# Zoom Level: 1	Lr: 0.050100	Reg: 50.000000	Batch: 101	Acc: 0.052000
# Zoom Level: 1	Lr: 0.050100	Reg: 60.000000	Batch: 101	Acc: 0.060000
# Zoom Level: 1	Lr: 0.050100	Reg: 70.000000	Batch: 101	Acc: 0.100000
# Zoom Level: 1	Lr: 0.050100	Reg: 80.000000	Batch: 101	Acc: 0.098000
# Zoom Level: 1	Lr: 0.050100	Reg: 90.000000	Batch: 101	Acc: 0.090000
# Zoom Level: 1	Lr: 0.050100	Reg: 100.000000	Batch: 101	Acc: 0.066000
# Zoom Level: 1	Lr: 0.050100	Reg: 0.000000	Batch: 201	Acc: 0.376000
# Zoom Level: 1	Lr: 0.050100	Reg: 10.000000	Batch: 201	Acc: 0.266000
# Zoom Level: 1	Lr: 0.050100	Reg: 20.000000	Batch: 201	Acc: 0.246000
# Zoom Level: 1	Lr: 0.050100	Reg: 30.000000	Batch: 201	Acc: 0.192000
# Zoom Level: 1	Lr: 0.050100	Reg: 40.000000	Batch: 201	Acc: 0.032000
# Zoom Level: 1	Lr: 0.050100	Reg: 50.000000	Batch: 201	Acc: 0.088000
# Zoom Level: 1	Lr: 0.050100	Reg: 60.000000	Batch: 201	Acc: 0.106000
# Zoom Level: 1	Lr: 0.050100	Reg: 70.000000	Batch: 201	Acc: 0.070000
# Zoom Level: 1	Lr: 0.050100	Reg: 80.000000	Batch: 201	Acc: 0.070000
# Zoom Level: 1	Lr: 0.050100	Reg: 90.000000	Batch: 201	Acc: 0.070000
# Zoom Level: 1	Lr: 0.050100	Reg: 100.000000	Batch: 201	Acc: 0.066000
# Zoom Level: 1	Lr: 0.050100	Reg: 0.000000	Batch: 301	Acc: 0.362000
# Zoom Level: 1	Lr: 0.050100	Reg: 10.000000	Batch: 301	Acc: 0.236000
# Zoom Level: 1	Lr: 0.050100	Reg: 20.000000	Batch: 301	Acc: 0.254000
# Zoom Level: 1	Lr: 0.050100	Reg: 30.000000	Batch: 301	Acc: 0.176000
# Zoom Level: 1	Lr: 0.050100	Reg: 40.000000	Batch: 301	Acc: 0.110000
# Zoom Level: 1	Lr: 0.050100	Reg: 50.000000	Batch: 301	Acc: 0.078000
# Zoom Level: 1	Lr: 0.050100	Reg: 60.000000	Batch: 301	Acc: 0.082000
# Zoom Level: 1	Lr: 0.050100	Reg: 70.000000	Batch: 301	Acc: 0.066000
# Zoom Level: 1	Lr: 0.050100	Reg: 80.000000	Batch: 301	Acc: 0.090000
# Zoom Level: 1	Lr: 0.050100	Reg: 90.000000	Batch: 301	Acc: 0.064000
# Zoom Level: 1	Lr: 0.050100	Reg: 100.000000	Batch: 301	Acc: 0.058000
# Zoom Level: 1	Lr: 0.050100	Reg: 0.000000	Batch: 401	Acc: 0.380000
# Zoom Level: 1	Lr: 0.050100	Reg: 10.000000	Batch: 401	Acc: 0.288000
# Zoom Level: 1	Lr: 0.050100	Reg: 20.000000	Batch: 401	Acc: 0.286000
# Zoom Level: 1	Lr: 0.050100	Reg: 30.000000	Batch: 401	Acc: 0.222000
# Zoom Level: 1	Lr: 0.050100	Reg: 40.000000	Batch: 401	Acc: 0.064000
# Zoom Level: 1	Lr: 0.050100	Reg: 50.000000	Batch: 401	Acc: 0.058000
# Zoom Level: 1	Lr: 0.050100	Reg: 60.000000	Batch: 401	Acc: 0.112000
# Zoom Level: 1	Lr: 0.050100	Reg: 70.000000	Batch: 401	Acc: 0.054000
# Zoom Level: 1	Lr: 0.050100	Reg: 80.000000	Batch: 401	Acc: 0.092000
# Zoom Level: 1	Lr: 0.050100	Reg: 90.000000	Batch: 401	Acc: 0.092000
# Zoom Level: 1	Lr: 0.050100	Reg: 100.000000	Batch: 401	Acc: 0.096000
# Zoom Level: 1	Lr: 0.050100	Reg: 0.000000	Batch: 501	Acc: 0.368000
# Zoom Level: 1	Lr: 0.050100	Reg: 10.000000	Batch: 501	Acc: 0.294000
# Zoom Level: 1	Lr: 0.050100	Reg: 20.000000	Batch: 501	Acc: 0.258000
# Zoom Level: 1	Lr: 0.050100	Reg: 30.000000	Batch: 501	Acc: 0.266000
# Zoom Level: 1	Lr: 0.050100	Reg: 40.000000	Batch: 501	Acc: 0.102000
# Zoom Level: 1	Lr: 0.050100	Reg: 50.000000	Batch: 501	Acc: 0.092000
# Zoom Level: 1	Lr: 0.050100	Reg: 60.000000	Batch: 501	Acc: 0.056000
# Zoom Level: 1	Lr: 0.050100	Reg: 70.000000	Batch: 501	Acc: 0.064000
# Zoom Level: 1	Lr: 0.050100	Reg: 80.000000	Batch: 501	Acc: 0.066000
# Zoom Level: 1	Lr: 0.050100	Reg: 90.000000	Batch: 501	Acc: 0.094000
# Zoom Level: 1	Lr: 0.050100	Reg: 100.000000	Batch: 501	Acc: 0.064000
# Zoom Level: 1	Lr: 0.050100	Reg: 0.000000	Batch: 601	Acc: 0.344000
# Zoom Level: 1	Lr: 0.050100	Reg: 10.000000	Batch: 601	Acc: 0.270000
# Zoom Level: 1	Lr: 0.050100	Reg: 20.000000	Batch: 601	Acc: 0.264000
# Zoom Level: 1	Lr: 0.050100	Reg: 30.000000	Batch: 601	Acc: 0.246000
# Zoom Level: 1	Lr: 0.050100	Reg: 40.000000	Batch: 601	Acc: 0.070000
# Zoom Level: 1	Lr: 0.050100	Reg: 50.000000	Batch: 601	Acc: 0.084000
# Zoom Level: 1	Lr: 0.050100	Reg: 60.000000	Batch: 601	Acc: 0.078000
# Zoom Level: 1	Lr: 0.050100	Reg: 70.000000	Batch: 601	Acc: 0.060000
# Zoom Level: 1	Lr: 0.050100	Reg: 80.000000	Batch: 601	Acc: 0.080000
# Zoom Level: 1	Lr: 0.050100	Reg: 90.000000	Batch: 601	Acc: 0.066000
# Zoom Level: 1	Lr: 0.050100	Reg: 100.000000	Batch: 601	Acc: 0.076000
# Zoom Level: 1	Lr: 0.050100	Reg: 0.000000	Batch: 701	Acc: 0.344000
# Zoom Level: 1	Lr: 0.050100	Reg: 10.000000	Batch: 701	Acc: 0.262000
# Zoom Level: 1	Lr: 0.050100	Reg: 20.000000	Batch: 701	Acc: 0.246000
# Zoom Level: 1	Lr: 0.050100	Reg: 30.000000	Batch: 701	Acc: 0.238000
# Zoom Level: 1	Lr: 0.050100	Reg: 40.000000	Batch: 701	Acc: 0.110000
# Zoom Level: 1	Lr: 0.050100	Reg: 50.000000	Batch: 701	Acc: 0.058000
# Zoom Level: 1	Lr: 0.050100	Reg: 60.000000	Batch: 701	Acc: 0.102000
# Zoom Level: 1	Lr: 0.050100	Reg: 70.000000	Batch: 701	Acc: 0.088000
# Zoom Level: 1	Lr: 0.050100	Reg: 80.000000	Batch: 701	Acc: 0.086000
# Zoom Level: 1	Lr: 0.050100	Reg: 90.000000	Batch: 701	Acc: 0.084000
# Zoom Level: 1	Lr: 0.050100	Reg: 100.000000	Batch: 701	Acc: 0.066000
# Zoom Level: 1	Lr: 0.050100	Reg: 0.000000	Batch: 801	Acc: 0.346000
# Zoom Level: 1	Lr: 0.050100	Reg: 10.000000	Batch: 801	Acc: 0.276000
# Zoom Level: 1	Lr: 0.050100	Reg: 20.000000	Batch: 801	Acc: 0.252000
# Zoom Level: 1	Lr: 0.050100	Reg: 30.000000	Batch: 801	Acc: 0.236000
# Zoom Level: 1	Lr: 0.050100	Reg: 40.000000	Batch: 801	Acc: 0.038000
# Zoom Level: 1	Lr: 0.050100	Reg: 50.000000	Batch: 801	Acc: 0.082000
# Zoom Level: 1	Lr: 0.050100	Reg: 60.000000	Batch: 801	Acc: 0.064000
# Zoom Level: 1	Lr: 0.050100	Reg: 70.000000	Batch: 801	Acc: 0.076000
# Zoom Level: 1	Lr: 0.050100	Reg: 80.000000	Batch: 801	Acc: 0.080000
# Zoom Level: 1	Lr: 0.050100	Reg: 90.000000	Batch: 801	Acc: 0.102000
# Zoom Level: 1	Lr: 0.050100	Reg: 100.000000	Batch: 801	Acc: 0.102000
# Zoom Level: 1	Lr: 0.050100	Reg: 0.000000	Batch: 901	Acc: 0.326000
# Zoom Level: 1	Lr: 0.050100	Reg: 10.000000	Batch: 901	Acc: 0.270000
# Zoom Level: 1	Lr: 0.050100	Reg: 20.000000	Batch: 901	Acc: 0.258000
# Zoom Level: 1	Lr: 0.050100	Reg: 30.000000	Batch: 901	Acc: 0.240000
# Zoom Level: 1	Lr: 0.050100	Reg: 40.000000	Batch: 901	Acc: 0.060000
# Zoom Level: 1	Lr: 0.050100	Reg: 50.000000	Batch: 901	Acc: 0.062000
# Zoom Level: 1	Lr: 0.050100	Reg: 60.000000	Batch: 901	Acc: 0.064000
# Zoom Level: 1	Lr: 0.050100	Reg: 70.000000	Batch: 901	Acc: 0.070000
# Zoom Level: 1	Lr: 0.050100	Reg: 80.000000	Batch: 901	Acc: 0.062000
# Zoom Level: 1	Lr: 0.050100	Reg: 90.000000	Batch: 901	Acc: 0.062000
# Zoom Level: 1	Lr: 0.050100	Reg: 100.000000	Batch: 901	Acc: 0.086000
# Zoom Level: 1	Lr: 0.060100	Reg: 0.000000	Batch: 101	Acc: 0.378000
# Zoom Level: 1	Lr: 0.060100	Reg: 10.000000	Batch: 101	Acc: 0.246000
# Zoom Level: 1	Lr: 0.060100	Reg: 20.000000	Batch: 101	Acc: 0.196000
# Zoom Level: 1	Lr: 0.060100	Reg: 30.000000	Batch: 101	Acc: 0.116000
# Zoom Level: 1	Lr: 0.060100	Reg: 40.000000	Batch: 101	Acc: 0.066000
# Zoom Level: 1	Lr: 0.060100	Reg: 50.000000	Batch: 101	Acc: 0.042000
# Zoom Level: 1	Lr: 0.060100	Reg: 60.000000	Batch: 101	Acc: 0.062000
# Zoom Level: 1	Lr: 0.060100	Reg: 70.000000	Batch: 101	Acc: 0.112000
# Zoom Level: 1	Lr: 0.060100	Reg: 80.000000	Batch: 101	Acc: 0.058000
# Zoom Level: 1	Lr: 0.060100	Reg: 90.000000	Batch: 101	Acc: 0.044000
# Zoom Level: 1	Lr: 0.060100	Reg: 100.000000	Batch: 101	Acc: 0.066000
# Zoom Level: 1	Lr: 0.060100	Reg: 0.000000	Batch: 201	Acc: 0.370000
# Zoom Level: 1	Lr: 0.060100	Reg: 10.000000	Batch: 201	Acc: 0.248000
# Zoom Level: 1	Lr: 0.060100	Reg: 20.000000	Batch: 201	Acc: 0.216000
# Zoom Level: 1	Lr: 0.060100	Reg: 30.000000	Batch: 201	Acc: 0.140000
# Zoom Level: 1	Lr: 0.060100	Reg: 40.000000	Batch: 201	Acc: 0.050000
# Zoom Level: 1	Lr: 0.060100	Reg: 50.000000	Batch: 201	Acc: 0.044000
# Zoom Level: 1	Lr: 0.060100	Reg: 60.000000	Batch: 201	Acc: 0.084000
# Zoom Level: 1	Lr: 0.060100	Reg: 70.000000	Batch: 201	Acc: 0.074000
# Zoom Level: 1	Lr: 0.060100	Reg: 80.000000	Batch: 201	Acc: 0.066000
# Zoom Level: 1	Lr: 0.060100	Reg: 90.000000	Batch: 201	Acc: 0.084000
# Zoom Level: 1	Lr: 0.060100	Reg: 100.000000	Batch: 201	Acc: 0.128000
# Zoom Level: 1	Lr: 0.060100	Reg: 0.000000	Batch: 301	Acc: 0.366000
# Zoom Level: 1	Lr: 0.060100	Reg: 10.000000	Batch: 301	Acc: 0.270000
# Zoom Level: 1	Lr: 0.060100	Reg: 20.000000	Batch: 301	Acc: 0.248000
# Zoom Level: 1	Lr: 0.060100	Reg: 30.000000	Batch: 301	Acc: 0.068000
# Zoom Level: 1	Lr: 0.060100	Reg: 40.000000	Batch: 301	Acc: 0.048000
# Zoom Level: 1	Lr: 0.060100	Reg: 50.000000	Batch: 301	Acc: 0.074000
# Zoom Level: 1	Lr: 0.060100	Reg: 60.000000	Batch: 301	Acc: 0.074000
# Zoom Level: 1	Lr: 0.060100	Reg: 70.000000	Batch: 301	Acc: 0.092000
# Zoom Level: 1	Lr: 0.060100	Reg: 80.000000	Batch: 301	Acc: 0.072000
# Zoom Level: 1	Lr: 0.060100	Reg: 90.000000	Batch: 301	Acc: 0.100000
# Zoom Level: 1	Lr: 0.060100	Reg: 100.000000	Batch: 301	Acc: 0.076000
# Zoom Level: 1	Lr: 0.060100	Reg: 0.000000	Batch: 401	Acc: 0.372000
# Zoom Level: 1	Lr: 0.060100	Reg: 10.000000	Batch: 401	Acc: 0.252000
# Zoom Level: 1	Lr: 0.060100	Reg: 20.000000	Batch: 401	Acc: 0.278000
# Zoom Level: 1	Lr: 0.060100	Reg: 30.000000	Batch: 401	Acc: 0.054000
# Zoom Level: 1	Lr: 0.060100	Reg: 40.000000	Batch: 401	Acc: 0.034000
# Zoom Level: 1	Lr: 0.060100	Reg: 50.000000	Batch: 401	Acc: 0.052000
# Zoom Level: 1	Lr: 0.060100	Reg: 60.000000	Batch: 401	Acc: 0.078000
# Zoom Level: 1	Lr: 0.060100	Reg: 70.000000	Batch: 401	Acc: 0.066000
# Zoom Level: 1	Lr: 0.060100	Reg: 80.000000	Batch: 401	Acc: 0.056000
# Zoom Level: 1	Lr: 0.060100	Reg: 90.000000	Batch: 401	Acc: 0.090000
# Zoom Level: 1	Lr: 0.060100	Reg: 100.000000	Batch: 401	Acc: 0.084000
# Zoom Level: 1	Lr: 0.060100	Reg: 0.000000	Batch: 501	Acc: 0.366000
# Zoom Level: 1	Lr: 0.060100	Reg: 10.000000	Batch: 501	Acc: 0.248000
# Zoom Level: 1	Lr: 0.060100	Reg: 20.000000	Batch: 501	Acc: 0.236000
# Zoom Level: 1	Lr: 0.060100	Reg: 30.000000	Batch: 501	Acc: 0.078000
# Zoom Level: 1	Lr: 0.060100	Reg: 40.000000	Batch: 501	Acc: 0.038000
# Zoom Level: 1	Lr: 0.060100	Reg: 50.000000	Batch: 501	Acc: 0.038000
# Zoom Level: 1	Lr: 0.060100	Reg: 60.000000	Batch: 501	Acc: 0.060000
# Zoom Level: 1	Lr: 0.060100	Reg: 70.000000	Batch: 501	Acc: 0.044000
# Zoom Level: 1	Lr: 0.060100	Reg: 80.000000	Batch: 501	Acc: 0.060000
# Zoom Level: 1	Lr: 0.060100	Reg: 90.000000	Batch: 501	Acc: 0.100000
# Zoom Level: 1	Lr: 0.060100	Reg: 100.000000	Batch: 501	Acc: 0.098000
# Zoom Level: 1	Lr: 0.060100	Reg: 0.000000	Batch: 601	Acc: 0.362000
# Zoom Level: 1	Lr: 0.060100	Reg: 10.000000	Batch: 601	Acc: 0.274000
# Zoom Level: 1	Lr: 0.060100	Reg: 20.000000	Batch: 601	Acc: 0.260000
# Zoom Level: 1	Lr: 0.060100	Reg: 30.000000	Batch: 601	Acc: 0.070000
# Zoom Level: 1	Lr: 0.060100	Reg: 40.000000	Batch: 601	Acc: 0.056000
# Zoom Level: 1	Lr: 0.060100	Reg: 50.000000	Batch: 601	Acc: 0.068000
# Zoom Level: 1	Lr: 0.060100	Reg: 60.000000	Batch: 601	Acc: 0.050000
# Zoom Level: 1	Lr: 0.060100	Reg: 70.000000	Batch: 601	Acc: 0.088000
# Zoom Level: 1	Lr: 0.060100	Reg: 80.000000	Batch: 601	Acc: 0.076000
# Zoom Level: 1	Lr: 0.060100	Reg: 90.000000	Batch: 601	Acc: 0.066000
# Zoom Level: 1	Lr: 0.060100	Reg: 100.000000	Batch: 601	Acc: 0.084000
# Zoom Level: 1	Lr: 0.060100	Reg: 0.000000	Batch: 701	Acc: 0.344000
# Zoom Level: 1	Lr: 0.060100	Reg: 10.000000	Batch: 701	Acc: 0.272000
# Zoom Level: 1	Lr: 0.060100	Reg: 20.000000	Batch: 701	Acc: 0.248000
# Zoom Level: 1	Lr: 0.060100	Reg: 30.000000	Batch: 701	Acc: 0.088000
# Zoom Level: 1	Lr: 0.060100	Reg: 40.000000	Batch: 701	Acc: 0.070000
# Zoom Level: 1	Lr: 0.060100	Reg: 50.000000	Batch: 701	Acc: 0.050000
# Zoom Level: 1	Lr: 0.060100	Reg: 60.000000	Batch: 701	Acc: 0.074000
# Zoom Level: 1	Lr: 0.060100	Reg: 70.000000	Batch: 701	Acc: 0.074000
# Zoom Level: 1	Lr: 0.060100	Reg: 80.000000	Batch: 701	Acc: 0.072000
# Zoom Level: 1	Lr: 0.060100	Reg: 90.000000	Batch: 701	Acc: 0.092000
# Zoom Level: 1	Lr: 0.060100	Reg: 100.000000	Batch: 701	Acc: 0.088000
# Zoom Level: 1	Lr: 0.060100	Reg: 0.000000	Batch: 801	Acc: 0.344000
# Zoom Level: 1	Lr: 0.060100	Reg: 10.000000	Batch: 801	Acc: 0.278000
# Zoom Level: 1	Lr: 0.060100	Reg: 20.000000	Batch: 801	Acc: 0.234000
# Zoom Level: 1	Lr: 0.060100	Reg: 30.000000	Batch: 801	Acc: 0.076000
# Zoom Level: 1	Lr: 0.060100	Reg: 40.000000	Batch: 801	Acc: 0.048000
# Zoom Level: 1	Lr: 0.060100	Reg: 50.000000	Batch: 801	Acc: 0.038000
# Zoom Level: 1	Lr: 0.060100	Reg: 60.000000	Batch: 801	Acc: 0.104000
# Zoom Level: 1	Lr: 0.060100	Reg: 70.000000	Batch: 801	Acc: 0.112000
# Zoom Level: 1	Lr: 0.060100	Reg: 80.000000	Batch: 801	Acc: 0.064000
# Zoom Level: 1	Lr: 0.060100	Reg: 90.000000	Batch: 801	Acc: 0.100000
# Zoom Level: 1	Lr: 0.060100	Reg: 100.000000	Batch: 801	Acc: 0.084000
# Zoom Level: 1	Lr: 0.060100	Reg: 0.000000	Batch: 901	Acc: 0.342000
# Zoom Level: 1	Lr: 0.060100	Reg: 10.000000	Batch: 901	Acc: 0.280000
# Zoom Level: 1	Lr: 0.060100	Reg: 20.000000	Batch: 901	Acc: 0.226000
# Zoom Level: 1	Lr: 0.060100	Reg: 30.000000	Batch: 901	Acc: 0.070000
# Zoom Level: 1	Lr: 0.060100	Reg: 40.000000	Batch: 901	Acc: 0.046000
# Zoom Level: 1	Lr: 0.060100	Reg: 50.000000	Batch: 901	Acc: 0.084000
# Zoom Level: 1	Lr: 0.060100	Reg: 60.000000	Batch: 901	Acc: 0.046000
# Zoom Level: 1	Lr: 0.060100	Reg: 70.000000	Batch: 901	Acc: 0.080000
# Zoom Level: 1	Lr: 0.060100	Reg: 80.000000	Batch: 901	Acc: 0.100000
# Zoom Level: 1	Lr: 0.060100	Reg: 90.000000	Batch: 901	Acc: 0.076000
# Zoom Level: 1	Lr: 0.060100	Reg: 100.000000	Batch: 901	Acc: 0.070000
# Zoom Level: 1	Lr: 0.070100	Reg: 0.000000	Batch: 101	Acc: 0.368000
# Zoom Level: 1	Lr: 0.070100	Reg: 10.000000	Batch: 101	Acc: 0.210000
# Zoom Level: 1	Lr: 0.070100	Reg: 20.000000	Batch: 101	Acc: 0.162000
# Zoom Level: 1	Lr: 0.070100	Reg: 30.000000	Batch: 101	Acc: 0.102000
# Zoom Level: 1	Lr: 0.070100	Reg: 40.000000	Batch: 101	Acc: 0.066000
# Zoom Level: 1	Lr: 0.070100	Reg: 50.000000	Batch: 101	Acc: 0.064000
# Zoom Level: 1	Lr: 0.070100	Reg: 60.000000	Batch: 101	Acc: 0.048000
# Zoom Level: 1	Lr: 0.070100	Reg: 70.000000	Batch: 101	Acc: 0.058000
# Zoom Level: 1	Lr: 0.070100	Reg: 80.000000	Batch: 101	Acc: 0.052000
# ...
# Zoom Level: 3	Lr: 0.097600	Reg: -5.000000	Batch: 126	Acc: 0.256000
# Zoom Level: 3	Lr: 0.097600	Reg: -2.500000	Batch: 126	Acc: 0.290000
# Zoom Level: 3	Lr: 0.097600	Reg: 0.000000	Batch: 126	Acc: 0.368000
# Zoom Level: 3	Lr: 0.097600	Reg: 2.500000	Batch: 126	Acc: 0.280000
# Zoom Level: 3	Lr: 0.097600	Reg: 5.000000	Batch: 126	Acc: 0.230000
# Zoom Level: 3	Lr: 0.097600	Reg: 7.500000	Batch: 126	Acc: 0.256000
# Zoom Level: 3	Lr: 0.097600	Reg: 10.000000	Batch: 126	Acc: 0.198000
# Zoom Level: 3	Lr: 0.097600	Reg: 12.500000	Batch: 126	Acc: 0.200000
# Zoom Level: 3	Lr: 0.097600	Reg: -12.500000	Batch: 151	Acc: 0.202000
# Zoom Level: 3	Lr: 0.097600	Reg: -10.000000	Batch: 151	Acc: 0.222000
# Zoom Level: 3	Lr: 0.097600	Reg: -7.500000	Batch: 151	Acc: 0.270000
# Zoom Level: 3	Lr: 0.097600	Reg: -5.000000	Batch: 151	Acc: 0.264000
# Zoom Level: 3	Lr: 0.097600	Reg: -2.500000	Batch: 151	Acc: 0.282000
# Zoom Level: 3	Lr: 0.097600	Reg: 0.000000	Batch: 151	Acc: 0.368000
# Zoom Level: 3	Lr: 0.097600	Reg: 2.500000	Batch: 151	Acc: 0.300000
# Zoom Level: 3	Lr: 0.097600	Reg: 5.000000	Batch: 151	Acc: 0.252000
# Zoom Level: 3	Lr: 0.097600	Reg: 7.500000	Batch: 151	Acc: 0.198000
# Zoom Level: 3	Lr: 0.097600	Reg: 10.000000	Batch: 151	Acc: 0.218000
# Zoom Level: 3	Lr: 0.097600	Reg: 12.500000	Batch: 151	Acc: 0.204000
# Zoom Level: 3	Lr: 0.097600	Reg: -12.500000	Batch: 176	Acc: 0.198000
# Zoom Level: 3	Lr: 0.097600	Reg: -10.000000	Batch: 176	Acc: 0.220000
# Zoom Level: 3	Lr: 0.097600	Reg: -7.500000	Batch: 176	Acc: 0.262000
# Zoom Level: 3	Lr: 0.097600	Reg: -5.000000	Batch: 176	Acc: 0.246000
# Zoom Level: 3	Lr: 0.097600	Reg: -2.500000	Batch: 176	Acc: 0.294000
# Zoom Level: 3	Lr: 0.097600	Reg: 0.000000	Batch: 176	Acc: 0.368000
# Zoom Level: 3	Lr: 0.097600	Reg: 2.500000	Batch: 176	Acc: 0.302000
# Zoom Level: 3	Lr: 0.097600	Reg: 5.000000	Batch: 176	Acc: 0.260000
# Zoom Level: 3	Lr: 0.097600	Reg: 7.500000	Batch: 176	Acc: 0.258000
# Zoom Level: 3	Lr: 0.097600	Reg: 10.000000	Batch: 176	Acc: 0.226000
# Zoom Level: 3	Lr: 0.097600	Reg: 12.500000	Batch: 176	Acc: 0.214000
# Zoom Level: 3	Lr: 0.097600	Reg: -12.500000	Batch: 201	Acc: 0.192000
# Zoom Level: 3	Lr: 0.097600	Reg: -10.000000	Batch: 201	Acc: 0.228000
# Zoom Level: 3	Lr: 0.097600	Reg: -7.500000	Batch: 201	Acc: 0.246000
# Zoom Level: 3	Lr: 0.097600	Reg: -5.000000	Batch: 201	Acc: 0.270000
# Zoom Level: 3	Lr: 0.097600	Reg: -2.500000	Batch: 201	Acc: 0.304000
# Zoom Level: 3	Lr: 0.097600	Reg: 0.000000	Batch: 201	Acc: 0.384000
# Zoom Level: 3	Lr: 0.097600	Reg: 2.500000	Batch: 201	Acc: 0.312000
# Zoom Level: 3	Lr: 0.097600	Reg: 5.000000	Batch: 201	Acc: 0.248000
# Zoom Level: 3	Lr: 0.097600	Reg: 7.500000	Batch: 201	Acc: 0.264000
# Zoom Level: 3	Lr: 0.097600	Reg: 10.000000	Batch: 201	Acc: 0.250000
# Zoom Level: 3	Lr: 0.097600	Reg: 12.500000	Batch: 201	Acc: 0.252000
# Zoom Level: 3	Lr: 0.100100	Reg: -12.500000	Batch: 10	Acc: 0.102000
# Zoom Level: 3	Lr: 0.100100	Reg: -10.000000	Batch: 10	Acc: 0.102000
# Zoom Level: 3	Lr: 0.100100	Reg: -7.500000	Batch: 10	Acc: 0.102000
# Zoom Level: 3	Lr: 0.100100	Reg: -5.000000	Batch: 10	Acc: 0.102000
# Zoom Level: 3	Lr: 0.100100	Reg: -2.500000	Batch: 10	Acc: 0.102000
# Zoom Level: 3	Lr: 0.100100	Reg: 0.000000	Batch: 10	Acc: 0.288000
# Zoom Level: 3	Lr: 0.100100	Reg: 2.500000	Batch: 10	Acc: 0.230000
# Zoom Level: 3	Lr: 0.100100	Reg: 5.000000	Batch: 10	Acc: 0.188000
# Zoom Level: 3	Lr: 0.100100	Reg: 7.500000	Batch: 10	Acc: 0.184000
# Zoom Level: 3	Lr: 0.100100	Reg: 10.000000	Batch: 10	Acc: 0.194000
# Zoom Level: 3	Lr: 0.100100	Reg: 12.500000	Batch: 10	Acc: 0.128000
# Zoom Level: 3	Lr: 0.100100	Reg: -12.500000	Batch: 26	Acc: 0.102000
# Zoom Level: 3	Lr: 0.100100	Reg: -10.000000	Batch: 26	Acc: 0.102000
# Zoom Level: 3	Lr: 0.100100	Reg: -7.500000	Batch: 26	Acc: 0.102000
# Zoom Level: 3	Lr: 0.100100	Reg: -5.000000	Batch: 26	Acc: 0.218000
# Zoom Level: 3	Lr: 0.100100	Reg: -2.500000	Batch: 26	Acc: 0.292000
# Zoom Level: 3	Lr: 0.100100	Reg: 0.000000	Batch: 26	Acc: 0.332000
# Zoom Level: 3	Lr: 0.100100	Reg: 2.500000	Batch: 26	Acc: 0.226000
# Zoom Level: 3	Lr: 0.100100	Reg: 5.000000	Batch: 26	Acc: 0.220000
# Zoom Level: 3	Lr: 0.100100	Reg: 7.500000	Batch: 26	Acc: 0.184000
# Zoom Level: 3	Lr: 0.100100	Reg: 10.000000	Batch: 26	Acc: 0.176000
# Zoom Level: 3	Lr: 0.100100	Reg: 12.500000	Batch: 26	Acc: 0.160000
# Zoom Level: 3	Lr: 0.100100	Reg: -12.500000	Batch: 51	Acc: 0.236000
# Zoom Level: 3	Lr: 0.100100	Reg: -10.000000	Batch: 51	Acc: 0.228000
# Zoom Level: 3	Lr: 0.100100	Reg: -7.500000	Batch: 51	Acc: 0.242000
# Zoom Level: 3	Lr: 0.100100	Reg: -5.000000	Batch: 51	Acc: 0.252000
# Zoom Level: 3	Lr: 0.100100	Reg: -2.500000	Batch: 51	Acc: 0.290000
# Zoom Level: 3	Lr: 0.100100	Reg: 0.000000	Batch: 51	Acc: 0.366000
# Zoom Level: 3	Lr: 0.100100	Reg: 2.500000	Batch: 51	Acc: 0.278000
# Zoom Level: 3	Lr: 0.100100	Reg: 5.000000	Batch: 51	Acc: 0.242000
# Zoom Level: 3	Lr: 0.100100	Reg: 7.500000	Batch: 51	Acc: 0.226000
# Zoom Level: 3	Lr: 0.100100	Reg: 10.000000	Batch: 51	Acc: 0.202000
# Zoom Level: 3	Lr: 0.100100	Reg: 12.500000	Batch: 51	Acc: 0.184000
# Zoom Level: 3	Lr: 0.100100	Reg: -12.500000	Batch: 76	Acc: 0.240000
# Zoom Level: 3	Lr: 0.100100	Reg: -10.000000	Batch: 76	Acc: 0.184000
# Zoom Level: 3	Lr: 0.100100	Reg: -7.500000	Batch: 76	Acc: 0.230000
# Zoom Level: 3	Lr: 0.100100	Reg: -5.000000	Batch: 76	Acc: 0.258000
# Zoom Level: 3	Lr: 0.100100	Reg: -2.500000	Batch: 76	Acc: 0.278000
# Zoom Level: 3	Lr: 0.100100	Reg: 0.000000	Batch: 76	Acc: 0.378000
# Zoom Level: 3	Lr: 0.100100	Reg: 2.500000	Batch: 76	Acc: 0.278000
# Zoom Level: 3	Lr: 0.100100	Reg: 5.000000	Batch: 76	Acc: 0.244000
# Zoom Level: 3	Lr: 0.100100	Reg: 7.500000	Batch: 76	Acc: 0.194000
# Zoom Level: 3	Lr: 0.100100	Reg: 10.000000	Batch: 76	Acc: 0.242000
# Zoom Level: 3	Lr: 0.100100	Reg: 12.500000	Batch: 76	Acc: 0.124000
# Zoom Level: 3	Lr: 0.100100	Reg: -12.500000	Batch: 101	Acc: 0.196000
# Zoom Level: 3	Lr: 0.100100	Reg: -10.000000	Batch: 101	Acc: 0.232000
# Zoom Level: 3	Lr: 0.100100	Reg: -7.500000	Batch: 101	Acc: 0.260000
# Zoom Level: 3	Lr: 0.100100	Reg: -5.000000	Batch: 101	Acc: 0.260000
# Zoom Level: 3	Lr: 0.100100	Reg: -2.500000	Batch: 101	Acc: 0.294000
# Zoom Level: 3	Lr: 0.100100	Reg: 0.000000	Batch: 101	Acc: 0.368000
# Zoom Level: 3	Lr: 0.100100	Reg: 2.500000	Batch: 101	Acc: 0.296000
# Zoom Level: 3	Lr: 0.100100	Reg: 5.000000	Batch: 101	Acc: 0.242000
# Zoom Level: 3	Lr: 0.100100	Reg: 7.500000	Batch: 101	Acc: 0.254000
# Zoom Level: 3	Lr: 0.100100	Reg: 10.000000	Batch: 101	Acc: 0.268000
# Zoom Level: 3	Lr: 0.100100	Reg: 12.500000	Batch: 101	Acc: 0.178000
# Zoom Level: 3	Lr: 0.100100	Reg: -12.500000	Batch: 126	Acc: 0.196000
# Zoom Level: 3	Lr: 0.100100	Reg: -10.000000	Batch: 126	Acc: 0.224000
# Zoom Level: 3	Lr: 0.100100	Reg: -7.500000	Batch: 126	Acc: 0.240000
# Zoom Level: 3	Lr: 0.100100	Reg: -5.000000	Batch: 126	Acc: 0.238000
# Zoom Level: 3	Lr: 0.100100	Reg: -2.500000	Batch: 126	Acc: 0.298000
# Zoom Level: 3	Lr: 0.100100	Reg: 0.000000	Batch: 126	Acc: 0.360000
# Zoom Level: 3	Lr: 0.100100	Reg: 2.500000	Batch: 126	Acc: 0.270000
# Zoom Level: 3	Lr: 0.100100	Reg: 5.000000	Batch: 126	Acc: 0.248000
# Zoom Level: 3	Lr: 0.100100	Reg: 7.500000	Batch: 126	Acc: 0.220000
# Zoom Level: 3	Lr: 0.100100	Reg: 10.000000	Batch: 126	Acc: 0.184000
# Zoom Level: 3	Lr: 0.100100	Reg: 12.500000	Batch: 126	Acc: 0.204000
# Zoom Level: 3	Lr: 0.100100	Reg: -12.500000	Batch: 151	Acc: 0.210000
# Zoom Level: 3	Lr: 0.100100	Reg: -10.000000	Batch: 151	Acc: 0.220000
# Zoom Level: 3	Lr: 0.100100	Reg: -7.500000	Batch: 151	Acc: 0.246000
# Zoom Level: 3	Lr: 0.100100	Reg: -5.000000	Batch: 151	Acc: 0.270000
# Zoom Level: 3	Lr: 0.100100	Reg: -2.500000	Batch: 151	Acc: 0.276000
# Zoom Level: 3	Lr: 0.100100	Reg: 0.000000	Batch: 151	Acc: 0.376000
# Zoom Level: 3	Lr: 0.100100	Reg: 2.500000	Batch: 151	Acc: 0.272000
# Zoom Level: 3	Lr: 0.100100	Reg: 5.000000	Batch: 151	Acc: 0.254000
# Zoom Level: 3	Lr: 0.100100	Reg: 7.500000	Batch: 151	Acc: 0.244000
# Zoom Level: 3	Lr: 0.100100	Reg: 10.000000	Batch: 151	Acc: 0.182000
# Zoom Level: 3	Lr: 0.100100	Reg: 12.500000	Batch: 151	Acc: 0.212000
# Zoom Level: 3	Lr: 0.100100	Reg: -12.500000	Batch: 176	Acc: 0.196000
# Zoom Level: 3	Lr: 0.100100	Reg: -10.000000	Batch: 176	Acc: 0.224000
# Zoom Level: 3	Lr: 0.100100	Reg: -7.500000	Batch: 176	Acc: 0.266000
# Zoom Level: 3	Lr: 0.100100	Reg: -5.000000	Batch: 176	Acc: 0.268000
# Zoom Level: 3	Lr: 0.100100	Reg: -2.500000	Batch: 176	Acc: 0.250000
# Zoom Level: 3	Lr: 0.100100	Reg: 0.000000	Batch: 176	Acc: 0.348000
# Zoom Level: 3	Lr: 0.100100	Reg: 2.500000	Batch: 176	Acc: 0.286000
# Zoom Level: 3	Lr: 0.100100	Reg: 5.000000	Batch: 176	Acc: 0.282000
# Zoom Level: 3	Lr: 0.100100	Reg: 7.500000	Batch: 176	Acc: 0.274000
# Zoom Level: 3	Lr: 0.100100	Reg: 10.000000	Batch: 176	Acc: 0.188000
# Zoom Level: 3	Lr: 0.100100	Reg: 12.500000	Batch: 176	Acc: 0.236000
# Zoom Level: 3	Lr: 0.100100	Reg: -12.500000	Batch: 201	Acc: 0.218000
# Zoom Level: 3	Lr: 0.100100	Reg: -10.000000	Batch: 201	Acc: 0.234000
# Zoom Level: 3	Lr: 0.100100	Reg: -7.500000	Batch: 201	Acc: 0.238000
# Zoom Level: 3	Lr: 0.100100	Reg: -5.000000	Batch: 201	Acc: 0.260000
# Zoom Level: 3	Lr: 0.100100	Reg: -2.500000	Batch: 201	Acc: 0.328000
# Zoom Level: 3	Lr: 0.100100	Reg: 0.000000	Batch: 201	Acc: 0.364000
# Zoom Level: 3	Lr: 0.100100	Reg: 2.500000	Batch: 201	Acc: 0.298000
# Zoom Level: 3	Lr: 0.100100	Reg: 5.000000	Batch: 201	Acc: 0.258000
# Zoom Level: 3	Lr: 0.100100	Reg: 7.500000	Batch: 201	Acc: 0.258000
# Zoom Level: 3	Lr: 0.100100	Reg: 10.000000	Batch: 201	Acc: 0.230000
# Zoom Level: 3	Lr: 0.100100	Reg: 12.500000	Batch: 201	Acc: 0.208000
# Zoom Level: 3	Lr: 0.102600	Reg: -12.500000	Batch: 10	Acc: 0.102000
# Zoom Level: 3	Lr: 0.102600	Reg: -10.000000	Batch: 10	Acc: 0.102000
# Zoom Level: 3	Lr: 0.102600	Reg: -7.500000	Batch: 10	Acc: 0.102000
# Zoom Level: 3	Lr: 0.102600	Reg: -5.000000	Batch: 10	Acc: 0.102000
# Zoom Level: 3	Lr: 0.102600	Reg: -2.500000	Batch: 10	Acc: 0.102000
# Zoom Level: 3	Lr: 0.102600	Reg: 0.000000	Batch: 10	Acc: 0.322000
# Zoom Level: 3	Lr: 0.102600	Reg: 2.500000	Batch: 10	Acc: 0.234000
# Zoom Level: 3	Lr: 0.102600	Reg: 5.000000	Batch: 10	Acc: 0.168000
# Zoom Level: 3	Lr: 0.102600	Reg: 7.500000	Batch: 10	Acc: 0.186000
# Zoom Level: 3	Lr: 0.102600	Reg: 10.000000	Batch: 10	Acc: 0.146000
# Zoom Level: 3	Lr: 0.102600	Reg: 12.500000	Batch: 10	Acc: 0.164000
# Zoom Level: 3	Lr: 0.102600	Reg: -12.500000	Batch: 26	Acc: 0.102000
# Zoom Level: 3	Lr: 0.102600	Reg: -10.000000	Batch: 26	Acc: 0.102000
# Zoom Level: 3	Lr: 0.102600	Reg: -7.500000	Batch: 26	Acc: 0.102000
# Zoom Level: 3	Lr: 0.102600	Reg: -5.000000	Batch: 26	Acc: 0.252000
# Zoom Level: 3	Lr: 0.102600	Reg: -2.500000	Batch: 26	Acc: 0.268000
# Zoom Level: 3	Lr: 0.102600	Reg: 0.000000	Batch: 26	Acc: 0.328000
# Zoom Level: 3	Lr: 0.102600	Reg: 2.500000	Batch: 26	Acc: 0.262000
# Zoom Level: 3	Lr: 0.102600	Reg: 5.000000	Batch: 26	Acc: 0.176000
# Zoom Level: 3	Lr: 0.102600	Reg: 7.500000	Batch: 26	Acc: 0.172000
# Zoom Level: 3	Lr: 0.102600	Reg: 10.000000	Batch: 26	Acc: 0.162000
# Zoom Level: 3	Lr: 0.102600	Reg: 12.500000	Batch: 26	Acc: 0.158000
# Zoom Level: 3	Lr: 0.102600	Reg: -12.500000	Batch: 51	Acc: 0.240000
# Zoom Level: 3	Lr: 0.102600	Reg: -10.000000	Batch: 51	Acc: 0.234000
# Zoom Level: 3	Lr: 0.102600	Reg: -7.500000	Batch: 51	Acc: 0.234000
# Zoom Level: 3	Lr: 0.102600	Reg: -5.000000	Batch: 51	Acc: 0.254000
# Zoom Level: 3	Lr: 0.102600	Reg: -2.500000	Batch: 51	Acc: 0.268000
# Zoom Level: 3	Lr: 0.102600	Reg: 0.000000	Batch: 51	Acc: 0.354000
# Zoom Level: 3	Lr: 0.102600	Reg: 2.500000	Batch: 51	Acc: 0.274000
# Zoom Level: 3	Lr: 0.102600	Reg: 5.000000	Batch: 51	Acc: 0.272000
# Zoom Level: 3	Lr: 0.102600	Reg: 7.500000	Batch: 51	Acc: 0.240000
# Zoom Level: 3	Lr: 0.102600	Reg: 10.000000	Batch: 51	Acc: 0.210000
# Zoom Level: 3	Lr: 0.102600	Reg: 12.500000	Batch: 51	Acc: 0.192000
# Zoom Level: 3	Lr: 0.102600	Reg: -12.500000	Batch: 76	Acc: 0.192000
# Zoom Level: 3	Lr: 0.102600	Reg: -10.000000	Batch: 76	Acc: 0.230000
# Zoom Level: 3	Lr: 0.102600	Reg: -7.500000	Batch: 76	Acc: 0.212000
# Zoom Level: 3	Lr: 0.102600	Reg: -5.000000	Batch: 76	Acc: 0.242000
# Zoom Level: 3	Lr: 0.102600	Reg: -2.500000	Batch: 76	Acc: 0.274000
# Zoom Level: 3	Lr: 0.102600	Reg: 0.000000	Batch: 76	Acc: 0.364000
# Zoom Level: 3	Lr: 0.102600	Reg: 2.500000	Batch: 76	Acc: 0.244000
# Zoom Level: 3	Lr: 0.102600	Reg: 5.000000	Batch: 76	Acc: 0.250000
# Zoom Level: 3	Lr: 0.102600	Reg: 7.500000	Batch: 76	Acc: 0.232000
# Zoom Level: 3	Lr: 0.102600	Reg: 10.000000	Batch: 76	Acc: 0.182000
# Zoom Level: 3	Lr: 0.102600	Reg: 12.500000	Batch: 76	Acc: 0.206000
# Zoom Level: 3	Lr: 0.102600	Reg: -12.500000	Batch: 101	Acc: 0.208000
# Zoom Level: 3	Lr: 0.102600	Reg: -10.000000	Batch: 101	Acc: 0.232000
# Zoom Level: 3	Lr: 0.102600	Reg: -7.500000	Batch: 101	Acc: 0.242000
# Zoom Level: 3	Lr: 0.102600	Reg: -5.000000	Batch: 101	Acc: 0.258000
# Zoom Level: 3	Lr: 0.102600	Reg: -2.500000	Batch: 101	Acc: 0.276000
# Zoom Level: 3	Lr: 0.102600	Reg: 0.000000	Batch: 101	Acc: 0.362000
# Zoom Level: 3	Lr: 0.102600	Reg: 2.500000	Batch: 101	Acc: 0.274000
# Zoom Level: 3	Lr: 0.102600	Reg: 5.000000	Batch: 101	Acc: 0.264000
# Zoom Level: 3	Lr: 0.102600	Reg: 7.500000	Batch: 101	Acc: 0.218000
# Zoom Level: 3	Lr: 0.102600	Reg: 10.000000	Batch: 101	Acc: 0.186000
# Zoom Level: 3	Lr: 0.102600	Reg: 12.500000	Batch: 101	Acc: 0.256000
# Zoom Level: 3	Lr: 0.102600	Reg: -12.500000	Batch: 126	Acc: 0.194000
# Zoom Level: 3	Lr: 0.102600	Reg: -10.000000	Batch: 126	Acc: 0.216000
# Zoom Level: 3	Lr: 0.102600	Reg: -7.500000	Batch: 126	Acc: 0.222000
# Zoom Level: 3	Lr: 0.102600	Reg: -5.000000	Batch: 126	Acc: 0.256000
# Zoom Level: 3	Lr: 0.102600	Reg: -2.500000	Batch: 126	Acc: 0.284000
# Zoom Level: 3	Lr: 0.102600	Reg: 0.000000	Batch: 126	Acc: 0.370000
# Zoom Level: 3	Lr: 0.102600	Reg: 2.500000	Batch: 126	Acc: 0.264000
# Zoom Level: 3	Lr: 0.102600	Reg: 5.000000	Batch: 126	Acc: 0.274000
# Zoom Level: 3	Lr: 0.102600	Reg: 7.500000	Batch: 126	Acc: 0.234000
# Zoom Level: 3	Lr: 0.102600	Reg: 10.000000	Batch: 126	Acc: 0.218000
# Zoom Level: 3	Lr: 0.102600	Reg: 12.500000	Batch: 126	Acc: 0.200000
# Zoom Level: 3	Lr: 0.102600	Reg: -12.500000	Batch: 151	Acc: 0.226000
# Zoom Level: 3	Lr: 0.102600	Reg: -10.000000	Batch: 151	Acc: 0.206000
# Zoom Level: 3	Lr: 0.102600	Reg: -7.500000	Batch: 151	Acc: 0.240000
# Zoom Level: 3	Lr: 0.102600	Reg: -5.000000	Batch: 151	Acc: 0.266000
# Zoom Level: 3	Lr: 0.102600	Reg: -2.500000	Batch: 151	Acc: 0.296000
# Zoom Level: 3	Lr: 0.102600	Reg: 0.000000	Batch: 151	Acc: 0.374000
# Zoom Level: 3	Lr: 0.102600	Reg: 2.500000	Batch: 151	Acc: 0.320000
# Zoom Level: 3	Lr: 0.102600	Reg: 5.000000	Batch: 151	Acc: 0.248000
# Zoom Level: 3	Lr: 0.102600	Reg: 7.500000	Batch: 151	Acc: 0.236000
# Zoom Level: 3	Lr: 0.102600	Reg: 10.000000	Batch: 151	Acc: 0.230000
# Zoom Level: 3	Lr: 0.102600	Reg: 12.500000	Batch: 151	Acc: 0.174000
# Zoom Level: 3	Lr: 0.102600	Reg: -12.500000	Batch: 176	Acc: 0.216000
# Zoom Level: 3	Lr: 0.102600	Reg: -10.000000	Batch: 176	Acc: 0.236000
# Zoom Level: 3	Lr: 0.102600	Reg: -7.500000	Batch: 176	Acc: 0.262000
# Zoom Level: 3	Lr: 0.102600	Reg: -5.000000	Batch: 176	Acc: 0.274000
# Zoom Level: 3	Lr: 0.102600	Reg: -2.500000	Batch: 176	Acc: 0.262000
# Zoom Level: 3	Lr: 0.102600	Reg: 0.000000	Batch: 176	Acc: 0.356000
# Zoom Level: 3	Lr: 0.102600	Reg: 2.500000	Batch: 176	Acc: 0.248000
# Zoom Level: 3	Lr: 0.102600	Reg: 5.000000	Batch: 176	Acc: 0.228000
# Zoom Level: 3	Lr: 0.102600	Reg: 7.500000	Batch: 176	Acc: 0.260000
# Zoom Level: 3	Lr: 0.102600	Reg: 10.000000	Batch: 176	Acc: 0.212000
# Zoom Level: 3	Lr: 0.102600	Reg: 12.500000	Batch: 176	Acc: 0.188000
# Zoom Level: 3	Lr: 0.102600	Reg: -12.500000	Batch: 201	Acc: 0.188000
# Zoom Level: 3	Lr: 0.102600	Reg: -10.000000	Batch: 201	Acc: 0.220000
# Zoom Level: 3	Lr: 0.102600	Reg: -7.500000	Batch: 201	Acc: 0.232000
# Zoom Level: 3	Lr: 0.102600	Reg: -5.000000	Batch: 201	Acc: 0.262000
# Zoom Level: 3	Lr: 0.102600	Reg: -2.500000	Batch: 201	Acc: 0.274000
# Zoom Level: 3	Lr: 0.102600	Reg: 0.000000	Batch: 201	Acc: 0.372000
# Zoom Level: 3	Lr: 0.102600	Reg: 2.500000	Batch: 201	Acc: 0.320000
# Zoom Level: 3	Lr: 0.102600	Reg: 5.000000	Batch: 201	Acc: 0.246000
# Zoom Level: 3	Lr: 0.102600	Reg: 7.500000	Batch: 201	Acc: 0.238000
# Zoom Level: 3	Lr: 0.102600	Reg: 10.000000	Batch: 201	Acc: 0.238000
# Zoom Level: 3	Lr: 0.102600	Reg: 12.500000	Batch: 201	Acc: 0.188000
# The best learning rate was 0.0776
# The best batch-size was 176
# The best regularization value was 0.0

# %% [markdown]
# #### (ii) Evaluate best model on test set
#
# **Question 4:** Now that you have "good" parameter values recorded, train a new model with the best learning rate, regularization strength, and batch size values. What accuracy do you get on the test set?

# %%
# Best values as calculated from grid search
best_lr = 0.0776
best_reg = 0
best_batch = 176

# %%
print(x_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ca585f49180f> in <module>
# ----> 1 print(x_test.shape)
#
# NameError: name 'x_test' is not defined

# %%
bestNet = SingleLayerNetSoftmax()
best_loss = bestNet.fit(x_train, y_train,
            lr=best_lr, reg=best_reg, mini_batch_sz=best_batch, n_epochs=300, verbose=2)
y_test_pred = bestNet.predict(x_test)

test_acc = bestNet.accuracy(y_test, y_test_pred)

print(f'Test accuracy {test_acc}')

plt.plot(best_loss)
plt.show()

# %%
# These are the best values we found using trial and error
best_lr = 0.0001
best_reg = 20
best_batch = 10

# %%
print(x_test.shape)
# Out:
# (500, 3072)

# %%
# We don't care about the bias wt
wts = bestNet.wts
# Reshape the wt vectors into spatial 'image' configurations to visualization
wts = wts.reshape(32, 32, 3, 10)

# Make a large new empty figure/plot
plt.figure(figsize=(20, 8))

# Loop through each output neuron
for i in range(10):
  # Make a 2x5 grid of images
  plt.subplot(2, 5, i+1)
  
  # Rescale the weights to be between 0 and 255
  currImg = 255.0 * (wts[:, :, :, i].squeeze() - np.min(wts)) / (np.max(wts) - np.min(wts))
  
  plt.imshow(currImg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])

# %%
bestNet = SingleLayerNetSoftmax()
best_loss = bestNet.fit(x_train, y_train,
            lr=best_lr, reg=best_reg, mini_batch_sz=best_batch, n_epochs=300, verbose=2)
y_test_pred = bestNet.predict(x_test)

test_acc = bestNet.accuracy(y_test, y_test_pred)

print(f'Test accuracy {test_acc}')

plt.plot(best_loss)
plt.show()
# Out:
# Starting to train network...There will be 300 epochs and 105000 iterations total, 350 iter/epoch.
#   Completed iter 0/105000. Training loss: 33.02.
#   Completed iter 100/105000. Training loss: 22.92.
#   Completed iter 200/105000. Training loss: 16.12.
#   Completed iter 300/105000. Training loss: 11.51.
#   Completed iter 400/105000. Training loss: 8.46.
#   Completed iter 500/105000. Training loss: 6.42.
#   Completed iter 600/105000. Training loss: 5.09.
#   Completed iter 700/105000. Training loss: 4.11.
#   Completed iter 800/105000. Training loss: 3.50.
#   Completed iter 900/105000. Training loss: 3.10.
#   Completed iter 1000/105000. Training loss: 2.81.
#   Completed iter 1100/105000. Training loss: 2.65.
#   Completed iter 1200/105000. Training loss: 2.52.
#   Completed iter 1300/105000. Training loss: 2.45.
#   Completed iter 1400/105000. Training loss: 2.40.
#   Completed iter 1500/105000. Training loss: 2.28.
#   Completed iter 1600/105000. Training loss: 2.31.
#   Completed iter 1700/105000. Training loss: 2.35.
#   Completed iter 1800/105000. Training loss: 2.29.
#   Completed iter 1900/105000. Training loss: 2.24.
#   Completed iter 2000/105000. Training loss: 2.31.
#   Completed iter 2100/105000. Training loss: 2.31.
#   Completed iter 2200/105000. Training loss: 2.32.
#   Completed iter 2300/105000. Training loss: 2.29.
#   Completed iter 2400/105000. Training loss: 2.29.
#   Completed iter 2500/105000. Training loss: 2.23.
#   Completed iter 2600/105000. Training loss: 2.21.
#   Completed iter 2700/105000. Training loss: 2.23.
#   Completed iter 2800/105000. Training loss: 2.17.
#   Completed iter 2900/105000. Training loss: 2.27.
#   Completed iter 3000/105000. Training loss: 2.28.
#   Completed iter 3100/105000. Training loss: 2.23.
#   Completed iter 3200/105000. Training loss: 2.24.
#   Completed iter 3300/105000. Training loss: 2.34.
#   Completed iter 3400/105000. Training loss: 2.28.
#   Completed iter 3500/105000. Training loss: 2.30.
#   Completed iter 3600/105000. Training loss: 2.24.
#   Completed iter 3700/105000. Training loss: 2.25.
#   Completed iter 3800/105000. Training loss: 2.26.
#   Completed iter 3900/105000. Training loss: 2.25.
#   Completed iter 4000/105000. Training loss: 2.27.
#   Completed iter 4100/105000. Training loss: 2.31.
#   Completed iter 4200/105000. Training loss: 2.24.
#   Completed iter 4300/105000. Training loss: 2.30.
#   Completed iter 4400/105000. Training loss: 2.27.
#   Completed iter 4500/105000. Training loss: 2.26.
#   Completed iter 4600/105000. Training loss: 2.24.
#   Completed iter 4700/105000. Training loss: 2.24.
#   Completed iter 4800/105000. Training loss: 2.28.
#   Completed iter 4900/105000. Training loss: 2.25.
#   Completed iter 5000/105000. Training loss: 2.28.
#   Completed iter 5100/105000. Training loss: 2.24.
#   Completed iter 5200/105000. Training loss: 2.27.
#   Completed iter 5300/105000. Training loss: 2.24.
#   Completed iter 5400/105000. Training loss: 2.26.
#   Completed iter 5500/105000. Training loss: 2.27.
#   Completed iter 5600/105000. Training loss: 2.26.
#   Completed iter 5700/105000. Training loss: 2.25.
#   Completed iter 5800/105000. Training loss: 2.21.
#   Completed iter 5900/105000. Training loss: 2.22.
#   Completed iter 6000/105000. Training loss: 2.28.
#   Completed iter 6100/105000. Training loss: 2.28.
#   Completed iter 6200/105000. Training loss: 2.25.
#   Completed iter 6300/105000. Training loss: 2.28.
#   Completed iter 6400/105000. Training loss: 2.32.
#   Completed iter 6500/105000. Training loss: 2.23.
#   Completed iter 6600/105000. Training loss: 2.34.
#   Completed iter 6700/105000. Training loss: 2.28.
#   Completed iter 6800/105000. Training loss: 2.31.
#   Completed iter 6900/105000. Training loss: 2.25.
#   Completed iter 7000/105000. Training loss: 2.26.
#   Completed iter 7100/105000. Training loss: 2.24.
#   Completed iter 7200/105000. Training loss: 2.25.
#   Completed iter 7300/105000. Training loss: 2.28.
#   Completed iter 7400/105000. Training loss: 2.31.
#   Completed iter 7500/105000. Training loss: 2.24.
#   Completed iter 7600/105000. Training loss: 2.22.
#   Completed iter 7700/105000. Training loss: 2.29.
#   Completed iter 7800/105000. Training loss: 2.27.
#   Completed iter 7900/105000. Training loss: 2.30.
#   Completed iter 8000/105000. Training loss: 2.22.
#   Completed iter 8100/105000. Training loss: 2.28.
#   Completed iter 8200/105000. Training loss: 2.25.
#   Completed iter 8300/105000. Training loss: 2.29.
#   Completed iter 8400/105000. Training loss: 2.26.
#   Completed iter 8500/105000. Training loss: 2.32.
#   Completed iter 8600/105000. Training loss: 2.27.
#   Completed iter 8700/105000. Training loss: 2.19.
#   Completed iter 8800/105000. Training loss: 2.25.
#   Completed iter 8900/105000. Training loss: 2.30.
#   Completed iter 9000/105000. Training loss: 2.24.
#   Completed iter 9100/105000. Training loss: 2.25.
#   Completed iter 9200/105000. Training loss: 2.30.
#   Completed iter 9300/105000. Training loss: 2.30.
#   Completed iter 9400/105000. Training loss: 2.25.
#   Completed iter 9500/105000. Training loss: 2.22.
#   Completed iter 9600/105000. Training loss: 2.26.
#   Completed iter 9700/105000. Training loss: 2.27.
#   Completed iter 9800/105000. Training loss: 2.26.
#   Completed iter 9900/105000. Training loss: 2.25.
#   Completed iter 10000/105000. Training loss: 2.25.
#   Completed iter 10100/105000. Training loss: 2.25.
#   Completed iter 10200/105000. Training loss: 2.23.
#   Completed iter 10300/105000. Training loss: 2.26.
#   Completed iter 10400/105000. Training loss: 2.25.
#   Completed iter 10500/105000. Training loss: 2.29.
#   Completed iter 10600/105000. Training loss: 2.30.
#   Completed iter 10700/105000. Training loss: 2.27.
#   Completed iter 10800/105000. Training loss: 2.30.
#   Completed iter 10900/105000. Training loss: 2.30.
#   Completed iter 11000/105000. Training loss: 2.25.
#   Completed iter 11100/105000. Training loss: 2.30.
#   Completed iter 11200/105000. Training loss: 2.23.
#   Completed iter 11300/105000. Training loss: 2.29.
#   Completed iter 11400/105000. Training loss: 2.27.
#   Completed iter 11500/105000. Training loss: 2.20.
#   Completed iter 11600/105000. Training loss: 2.26.
#   Completed iter 11700/105000. Training loss: 2.28.
#   Completed iter 11800/105000. Training loss: 2.22.
#   Completed iter 11900/105000. Training loss: 2.24.
#   Completed iter 12000/105000. Training loss: 2.23.
#   Completed iter 12100/105000. Training loss: 2.27.
#   Completed iter 12200/105000. Training loss: 2.25.
#   Completed iter 12300/105000. Training loss: 2.28.
#   Completed iter 12400/105000. Training loss: 2.27.
#   Completed iter 12500/105000. Training loss: 2.25.
#   Completed iter 12600/105000. Training loss: 2.27.
#   Completed iter 12700/105000. Training loss: 2.26.
#   Completed iter 12800/105000. Training loss: 2.27.
#   Completed iter 12900/105000. Training loss: 2.28.
#   Completed iter 13000/105000. Training loss: 2.24.
#   Completed iter 13100/105000. Training loss: 2.21.
#   Completed iter 13200/105000. Training loss: 2.29.
#   Completed iter 13300/105000. Training loss: 2.29.
#   Completed iter 13400/105000. Training loss: 2.22.
#   Completed iter 13500/105000. Training loss: 2.26.
#   Completed iter 13600/105000. Training loss: 2.26.
#   Completed iter 13700/105000. Training loss: 2.25.
#   Completed iter 13800/105000. Training loss: 2.26.
#   Completed iter 13900/105000. Training loss: 2.24.
#   Completed iter 14000/105000. Training loss: 2.21.
#   Completed iter 14100/105000. Training loss: 2.22.
#   Completed iter 14200/105000. Training loss: 2.22.
#   Completed iter 14300/105000. Training loss: 2.22.
#   Completed iter 14400/105000. Training loss: 2.31.
#   Completed iter 14500/105000. Training loss: 2.27.
#   Completed iter 14600/105000. Training loss: 2.29.
#   Completed iter 14700/105000. Training loss: 2.30.
#   Completed iter 14800/105000. Training loss: 2.29.
#   Completed iter 14900/105000. Training loss: 2.24.
#   Completed iter 15000/105000. Training loss: 2.25.
#   Completed iter 15100/105000. Training loss: 2.28.
#   Completed iter 15200/105000. Training loss: 2.27.
#   Completed iter 15300/105000. Training loss: 2.27.
#   Completed iter 15400/105000. Training loss: 2.23.
#   Completed iter 15500/105000. Training loss: 2.28.
#   Completed iter 15600/105000. Training loss: 2.25.
#   Completed iter 15700/105000. Training loss: 2.23.
#   Completed iter 15800/105000. Training loss: 2.25.
#   Completed iter 15900/105000. Training loss: 2.27.
#   Completed iter 16000/105000. Training loss: 2.25.
#   Completed iter 16100/105000. Training loss: 2.19.
#   Completed iter 16200/105000. Training loss: 2.31.
#   Completed iter 16300/105000. Training loss: 2.26.
#   Completed iter 16400/105000. Training loss: 2.29.
#   Completed iter 16500/105000. Training loss: 2.28.
#   Completed iter 16600/105000. Training loss: 2.26.
#   Completed iter 16700/105000. Training loss: 2.32.
#   Completed iter 16800/105000. Training loss: 2.29.
#   Completed iter 16900/105000. Training loss: 2.27.
#   Completed iter 17000/105000. Training loss: 2.28.
#   Completed iter 17100/105000. Training loss: 2.22.
#   Completed iter 17200/105000. Training loss: 2.25.
#   Completed iter 17300/105000. Training loss: 2.23.
#   Completed iter 17400/105000. Training loss: 2.25.
#   Completed iter 17500/105000. Training loss: 2.23.
#   Completed iter 17600/105000. Training loss: 2.28.
#   Completed iter 17700/105000. Training loss: 2.22.
#   Completed iter 17800/105000. Training loss: 2.24.
#   Completed iter 17900/105000. Training loss: 2.23.
#   Completed iter 18000/105000. Training loss: 2.28.
#   Completed iter 18100/105000. Training loss: 2.21.
#   Completed iter 18200/105000. Training loss: 2.30.
#   Completed iter 18300/105000. Training loss: 2.25.
#   Completed iter 18400/105000. Training loss: 2.31.
#   Completed iter 18500/105000. Training loss: 2.32.
#   Completed iter 18600/105000. Training loss: 2.26.
#   Completed iter 18700/105000. Training loss: 2.33.
#   Completed iter 18800/105000. Training loss: 2.30.
#   Completed iter 18900/105000. Training loss: 2.16.
#   Completed iter 19000/105000. Training loss: 2.26.
#   Completed iter 19100/105000. Training loss: 2.34.
#   Completed iter 19200/105000. Training loss: 2.29.
#   Completed iter 19300/105000. Training loss: 2.30.
#   Completed iter 19400/105000. Training loss: 2.29.
#   Completed iter 19500/105000. Training loss: 2.28.
#   Completed iter 19600/105000. Training loss: 2.27.
#   Completed iter 19700/105000. Training loss: 2.24.
#   Completed iter 19800/105000. Training loss: 2.23.
#   Completed iter 19900/105000. Training loss: 2.23.
#   Completed iter 20000/105000. Training loss: 2.27.
#   Completed iter 20100/105000. Training loss: 2.26.
#   Completed iter 20200/105000. Training loss: 2.22.
#   Completed iter 20300/105000. Training loss: 2.20.
#   Completed iter 20400/105000. Training loss: 2.32.
#   Completed iter 20500/105000. Training loss: 2.25.
#   Completed iter 20600/105000. Training loss: 2.32.
#   Completed iter 20700/105000. Training loss: 2.23.
#   Completed iter 20800/105000. Training loss: 2.22.
#   Completed iter 20900/105000. Training loss: 2.17.
#   Completed iter 21000/105000. Training loss: 2.26.
#   Completed iter 21100/105000. Training loss: 2.29.
#   Completed iter 21200/105000. Training loss: 2.30.
#   Completed iter 21300/105000. Training loss: 2.30.
#   Completed iter 21400/105000. Training loss: 2.26.
#   Completed iter 21500/105000. Training loss: 2.25.
#   Completed iter 21600/105000. Training loss: 2.28.
#   Completed iter 21700/105000. Training loss: 2.29.
#   Completed iter 21800/105000. Training loss: 2.27.
#   Completed iter 21900/105000. Training loss: 2.24.
#   Completed iter 22000/105000. Training loss: 2.30.
#   Completed iter 22100/105000. Training loss: 2.26.
#   Completed iter 22200/105000. Training loss: 2.25.
#   Completed iter 22300/105000. Training loss: 2.27.
#   Completed iter 22400/105000. Training loss: 2.26.
#   Completed iter 22500/105000. Training loss: 2.30.
#   Completed iter 22600/105000. Training loss: 2.24.
#   Completed iter 22700/105000. Training loss: 2.29.
#   Completed iter 22800/105000. Training loss: 2.26.
#   Completed iter 22900/105000. Training loss: 2.22.
#   Completed iter 23000/105000. Training loss: 2.25.
#   Completed iter 23100/105000. Training loss: 2.31.
#   Completed iter 23200/105000. Training loss: 2.25.
#   Completed iter 23300/105000. Training loss: 2.26.
#   Completed iter 23400/105000. Training loss: 2.30.
#   Completed iter 23500/105000. Training loss: 2.29.
#   Completed iter 23600/105000. Training loss: 2.26.
#   Completed iter 23700/105000. Training loss: 2.26.
#   Completed iter 23800/105000. Training loss: 2.29.
#   Completed iter 23900/105000. Training loss: 2.27.
#   Completed iter 24000/105000. Training loss: 2.31.
#   Completed iter 24100/105000. Training loss: 2.22.
#   Completed iter 24200/105000. Training loss: 2.21.
#   Completed iter 24300/105000. Training loss: 2.30.
#   Completed iter 24400/105000. Training loss: 2.26.
#   Completed iter 24500/105000. Training loss: 2.32.
#   Completed iter 24600/105000. Training loss: 2.30.
#   Completed iter 24700/105000. Training loss: 2.26.
#   Completed iter 24800/105000. Training loss: 2.20.
#   Completed iter 24900/105000. Training loss: 2.29.
#   Completed iter 25000/105000. Training loss: 2.25.
#   Completed iter 25100/105000. Training loss: 2.26.
#   Completed iter 25200/105000. Training loss: 2.26.
#   Completed iter 25300/105000. Training loss: 2.23.
#   Completed iter 25400/105000. Training loss: 2.27.
#   Completed iter 25500/105000. Training loss: 2.27.
#   Completed iter 25600/105000. Training loss: 2.28.
#   Completed iter 25700/105000. Training loss: 2.29.
#   Completed iter 25800/105000. Training loss: 2.25.
#   Completed iter 25900/105000. Training loss: 2.30.
#   Completed iter 26000/105000. Training loss: 2.25.
#   Completed iter 26100/105000. Training loss: 2.26.
#   Completed iter 26200/105000. Training loss: 2.29.
#   Completed iter 26300/105000. Training loss: 2.28.
#   Completed iter 26400/105000. Training loss: 2.28.
#   Completed iter 26500/105000. Training loss: 2.26.
#   Completed iter 26600/105000. Training loss: 2.31.
#   Completed iter 26700/105000. Training loss: 2.20.
#   Completed iter 26800/105000. Training loss: 2.25.
#   Completed iter 26900/105000. Training loss: 2.28.
#   Completed iter 27000/105000. Training loss: 2.25.
#   Completed iter 27100/105000. Training loss: 2.27.
#   Completed iter 27200/105000. Training loss: 2.27.
#   Completed iter 27300/105000. Training loss: 2.24.
#   Completed iter 27400/105000. Training loss: 2.24.
#   Completed iter 27500/105000. Training loss: 2.33.
#   Completed iter 27600/105000. Training loss: 2.28.
#   Completed iter 27700/105000. Training loss: 2.26.
#   Completed iter 27800/105000. Training loss: 2.22.
#   Completed iter 27900/105000. Training loss: 2.23.
#   Completed iter 28000/105000. Training loss: 2.25.
#   Completed iter 28100/105000. Training loss: 2.28.
#   Completed iter 28200/105000. Training loss: 2.30.
#   Completed iter 28300/105000. Training loss: 2.20.
#   Completed iter 28400/105000. Training loss: 2.26.
#   Completed iter 28500/105000. Training loss: 2.26.
#   Completed iter 28600/105000. Training loss: 2.27.
#   Completed iter 28700/105000. Training loss: 2.23.
#   Completed iter 28800/105000. Training loss: 2.26.
#   Completed iter 28900/105000. Training loss: 2.24.
#   Completed iter 29000/105000. Training loss: 2.26.
#   Completed iter 29100/105000. Training loss: 2.27.
#   Completed iter 29200/105000. Training loss: 2.25.
#   Completed iter 29300/105000. Training loss: 2.25.
#   Completed iter 29400/105000. Training loss: 2.29.
#   Completed iter 29500/105000. Training loss: 2.28.
#   Completed iter 29600/105000. Training loss: 2.25.
#   Completed iter 29700/105000. Training loss: 2.30.
#   Completed iter 29800/105000. Training loss: 2.29.
#   Completed iter 29900/105000. Training loss: 2.25.
#   Completed iter 30000/105000. Training loss: 2.30.
#   Completed iter 30100/105000. Training loss: 2.31.
#   Completed iter 30200/105000. Training loss: 2.28.
#   Completed iter 30300/105000. Training loss: 2.30.
#   Completed iter 30400/105000. Training loss: 2.27.
#   Completed iter 30500/105000. Training loss: 2.29.
#   Completed iter 30600/105000. Training loss: 2.31.
#   Completed iter 30700/105000. Training loss: 2.26.
#   Completed iter 30800/105000. Training loss: 2.26.
#   Completed iter 30900/105000. Training loss: 2.30.
#   Completed iter 31000/105000. Training loss: 2.30.
#   Completed iter 31100/105000. Training loss: 2.28.
#   Completed iter 31200/105000. Training loss: 2.27.
#   Completed iter 31300/105000. Training loss: 2.28.
#   Completed iter 31400/105000. Training loss: 2.22.
#   Completed iter 31500/105000. Training loss: 2.29.
#   Completed iter 31600/105000. Training loss: 2.22.
#   Completed iter 31700/105000. Training loss: 2.31.
#   Completed iter 31800/105000. Training loss: 2.21.
#   Completed iter 31900/105000. Training loss: 2.23.
#   Completed iter 32000/105000. Training loss: 2.32.
#   Completed iter 32100/105000. Training loss: 2.31.
#   Completed iter 32200/105000. Training loss: 2.29.
#   Completed iter 32300/105000. Training loss: 2.24.
#   Completed iter 32400/105000. Training loss: 2.28.
#   Completed iter 32500/105000. Training loss: 2.31.
#   Completed iter 32600/105000. Training loss: 2.29.
#   Completed iter 32700/105000. Training loss: 2.24.
#   Completed iter 32800/105000. Training loss: 2.33.
#   Completed iter 32900/105000. Training loss: 2.24.
#   Completed iter 33000/105000. Training loss: 2.22.
#   Completed iter 33100/105000. Training loss: 2.28.
#   Completed iter 33200/105000. Training loss: 2.30.
#   Completed iter 33300/105000. Training loss: 2.26.
#   Completed iter 33400/105000. Training loss: 2.23.
#   Completed iter 33500/105000. Training loss: 2.28.
#   Completed iter 33600/105000. Training loss: 2.27.
#   Completed iter 33700/105000. Training loss: 2.20.
#   Completed iter 33800/105000. Training loss: 2.24.
#   Completed iter 33900/105000. Training loss: 2.27.
#   Completed iter 34000/105000. Training loss: 2.24.
#   Completed iter 34100/105000. Training loss: 2.29.
#   Completed iter 34200/105000. Training loss: 2.25.
#   Completed iter 34300/105000. Training loss: 2.30.
#   Completed iter 34400/105000. Training loss: 2.24.
#   Completed iter 34500/105000. Training loss: 2.27.
#   Completed iter 34600/105000. Training loss: 2.28.
#   Completed iter 34700/105000. Training loss: 2.22.
#   Completed iter 34800/105000. Training loss: 2.29.
#   Completed iter 34900/105000. Training loss: 2.29.
#   Completed iter 35000/105000. Training loss: 2.33.
#   Completed iter 35100/105000. Training loss: 2.32.
#   Completed iter 35200/105000. Training loss: 2.28.
#   Completed iter 35300/105000. Training loss: 2.24.
#   Completed iter 35400/105000. Training loss: 2.29.
#   Completed iter 35500/105000. Training loss: 2.32.
#   Completed iter 35600/105000. Training loss: 2.27.
#   Completed iter 35700/105000. Training loss: 2.29.
#   Completed iter 35800/105000. Training loss: 2.22.
#   Completed iter 35900/105000. Training loss: 2.27.
#   Completed iter 36000/105000. Training loss: 2.25.
#   Completed iter 36100/105000. Training loss: 2.26.
#   Completed iter 36200/105000. Training loss: 2.28.
#   Completed iter 36300/105000. Training loss: 2.30.
#   Completed iter 36400/105000. Training loss: 2.25.
#   Completed iter 36500/105000. Training loss: 2.28.
#   Completed iter 36600/105000. Training loss: 2.28.
#   Completed iter 36700/105000. Training loss: 2.30.
#   Completed iter 36800/105000. Training loss: 2.21.
#   Completed iter 36900/105000. Training loss: 2.28.
#   Completed iter 37000/105000. Training loss: 2.27.
#   Completed iter 37100/105000. Training loss: 2.33.
#   Completed iter 37200/105000. Training loss: 2.31.
#   Completed iter 37300/105000. Training loss: 2.30.
#   Completed iter 37400/105000. Training loss: 2.29.
#   Completed iter 37500/105000. Training loss: 2.30.
#   Completed iter 37600/105000. Training loss: 2.23.
#   Completed iter 37700/105000. Training loss: 2.28.
#   Completed iter 37800/105000. Training loss: 2.23.
#   Completed iter 37900/105000. Training loss: 2.27.
#   Completed iter 38000/105000. Training loss: 2.31.
#   Completed iter 38100/105000. Training loss: 2.22.
#   Completed iter 38200/105000. Training loss: 2.27.
#   Completed iter 38300/105000. Training loss: 2.30.
#   Completed iter 38400/105000. Training loss: 2.32.
#   Completed iter 38500/105000. Training loss: 2.24.
#   Completed iter 38600/105000. Training loss: 2.23.
#   Completed iter 38700/105000. Training loss: 2.30.
#   Completed iter 38800/105000. Training loss: 2.25.
#   Completed iter 38900/105000. Training loss: 2.23.
#   Completed iter 39000/105000. Training loss: 2.27.
#   Completed iter 39100/105000. Training loss: 2.26.
#   Completed iter 39200/105000. Training loss: 2.24.
#   Completed iter 39300/105000. Training loss: 2.22.
#   Completed iter 39400/105000. Training loss: 2.26.
#   Completed iter 39500/105000. Training loss: 2.31.
#   Completed iter 39600/105000. Training loss: 2.21.
#   Completed iter 39700/105000. Training loss: 2.27.
#   Completed iter 39800/105000. Training loss: 2.29.
#   Completed iter 39900/105000. Training loss: 2.32.
#   Completed iter 40000/105000. Training loss: 2.28.
#   Completed iter 40100/105000. Training loss: 2.27.
#   Completed iter 40200/105000. Training loss: 2.22.
#   Completed iter 40300/105000. Training loss: 2.29.
#   Completed iter 40400/105000. Training loss: 2.27.
#   Completed iter 40500/105000. Training loss: 2.23.
#   Completed iter 40600/105000. Training loss: 2.30.
#   Completed iter 40700/105000. Training loss: 2.30.
#   Completed iter 40800/105000. Training loss: 2.29.
#   Completed iter 40900/105000. Training loss: 2.27.
#   Completed iter 41000/105000. Training loss: 2.30.
#   Completed iter 41100/105000. Training loss: 2.29.
#   Completed iter 41200/105000. Training loss: 2.28.
#   Completed iter 41300/105000. Training loss: 2.29.
#   Completed iter 41400/105000. Training loss: 2.25.
#   Completed iter 41500/105000. Training loss: 2.28.
#   Completed iter 41600/105000. Training loss: 2.30.
#   Completed iter 41700/105000. Training loss: 2.31.
#   Completed iter 41800/105000. Training loss: 2.20.
#   Completed iter 41900/105000. Training loss: 2.30.
#   Completed iter 42000/105000. Training loss: 2.26.
#   Completed iter 42100/105000. Training loss: 2.23.
#   Completed iter 42200/105000. Training loss: 2.26.
#   Completed iter 42300/105000. Training loss: 2.27.
#   Completed iter 42400/105000. Training loss: 2.26.
#   Completed iter 42500/105000. Training loss: 2.30.
#   Completed iter 42600/105000. Training loss: 2.27.
#   Completed iter 42700/105000. Training loss: 2.25.
#   Completed iter 42800/105000. Training loss: 2.25.
#   Completed iter 42900/105000. Training loss: 2.24.
#   Completed iter 43000/105000. Training loss: 2.27.
#   Completed iter 43100/105000. Training loss: 2.30.
#   Completed iter 43200/105000. Training loss: 2.28.
#   Completed iter 43300/105000. Training loss: 2.32.
#   Completed iter 43400/105000. Training loss: 2.27.
#   Completed iter 43500/105000. Training loss: 2.18.
#   Completed iter 43600/105000. Training loss: 2.31.
#   Completed iter 43700/105000. Training loss: 2.29.
#   Completed iter 43800/105000. Training loss: 2.24.
#   Completed iter 43900/105000. Training loss: 2.26.
#   Completed iter 44000/105000. Training loss: 2.27.
#   Completed iter 44100/105000. Training loss: 2.28.
#   Completed iter 44200/105000. Training loss: 2.23.
#   Completed iter 44300/105000. Training loss: 2.25.
#   Completed iter 44400/105000. Training loss: 2.18.
#   Completed iter 44500/105000. Training loss: 2.29.
#   Completed iter 44600/105000. Training loss: 2.32.
#   Completed iter 44700/105000. Training loss: 2.24.
#   Completed iter 44800/105000. Training loss: 2.27.
#   Completed iter 44900/105000. Training loss: 2.24.
#   Completed iter 45000/105000. Training loss: 2.26.
#   Completed iter 45100/105000. Training loss: 2.22.
#   Completed iter 45200/105000. Training loss: 2.27.
#   Completed iter 45300/105000. Training loss: 2.25.
#   Completed iter 45400/105000. Training loss: 2.22.
#   Completed iter 45500/105000. Training loss: 2.27.
#   Completed iter 45600/105000. Training loss: 2.29.
#   Completed iter 45700/105000. Training loss: 2.30.
#   Completed iter 45800/105000. Training loss: 2.25.
#   Completed iter 45900/105000. Training loss: 2.28.
#   Completed iter 46000/105000. Training loss: 2.24.
#   Completed iter 46100/105000. Training loss: 2.25.
#   Completed iter 46200/105000. Training loss: 2.28.
#   Completed iter 46300/105000. Training loss: 2.29.
#   Completed iter 46400/105000. Training loss: 2.26.
#   Completed iter 46500/105000. Training loss: 2.29.
#   Completed iter 46600/105000. Training loss: 2.28.
#   Completed iter 46700/105000. Training loss: 2.21.
#   Completed iter 46800/105000. Training loss: 2.20.
#   Completed iter 46900/105000. Training loss: 2.24.
#   Completed iter 47000/105000. Training loss: 2.27.
#   Completed iter 47100/105000. Training loss: 2.28.
#   Completed iter 47200/105000. Training loss: 2.29.
#   Completed iter 47300/105000. Training loss: 2.30.
#   Completed iter 47400/105000. Training loss: 2.24.
#   Completed iter 47500/105000. Training loss: 2.28.
#   Completed iter 47600/105000. Training loss: 2.21.
#   Completed iter 47700/105000. Training loss: 2.32.
#   Completed iter 47800/105000. Training loss: 2.26.
#   Completed iter 47900/105000. Training loss: 2.29.
#   Completed iter 48000/105000. Training loss: 2.26.
#   Completed iter 48100/105000. Training loss: 2.24.
#   Completed iter 48200/105000. Training loss: 2.24.
#   Completed iter 48300/105000. Training loss: 2.27.
#   Completed iter 48400/105000. Training loss: 2.26.
#   Completed iter 48500/105000. Training loss: 2.30.
#   Completed iter 48600/105000. Training loss: 2.20.
#   Completed iter 48700/105000. Training loss: 2.31.
#   Completed iter 48800/105000. Training loss: 2.27.
#   Completed iter 48900/105000. Training loss: 2.24.
#   Completed iter 49000/105000. Training loss: 2.24.
#   Completed iter 49100/105000. Training loss: 2.22.
#   Completed iter 49200/105000. Training loss: 2.27.
#   Completed iter 49300/105000. Training loss: 2.22.
#   Completed iter 49400/105000. Training loss: 2.30.
#   Completed iter 49500/105000. Training loss: 2.29.
#   Completed iter 49600/105000. Training loss: 2.30.
#   Completed iter 49700/105000. Training loss: 2.26.
#   Completed iter 49800/105000. Training loss: 2.29.
#   Completed iter 49900/105000. Training loss: 2.29.
#   Completed iter 50000/105000. Training loss: 2.29.
#   Completed iter 50100/105000. Training loss: 2.27.
#   Completed iter 50200/105000. Training loss: 2.22.
#   Completed iter 50300/105000. Training loss: 2.30.
#   Completed iter 50400/105000. Training loss: 2.20.
#   Completed iter 50500/105000. Training loss: 2.29.
#   Completed iter 50600/105000. Training loss: 2.27.
#   Completed iter 50700/105000. Training loss: 2.24.
#   Completed iter 50800/105000. Training loss: 2.35.
#   Completed iter 50900/105000. Training loss: 2.26.
#   Completed iter 51000/105000. Training loss: 2.27.
#   Completed iter 51100/105000. Training loss: 2.25.
#   Completed iter 51200/105000. Training loss: 2.29.
#   Completed iter 51300/105000. Training loss: 2.23.
#   Completed iter 51400/105000. Training loss: 2.31.
#   Completed iter 51500/105000. Training loss: 2.27.
#   Completed iter 51600/105000. Training loss: 2.23.
#   Completed iter 51700/105000. Training loss: 2.26.
#   Completed iter 51800/105000. Training loss: 2.34.
#   Completed iter 51900/105000. Training loss: 2.30.
#   Completed iter 52000/105000. Training loss: 2.25.
#   Completed iter 52100/105000. Training loss: 2.25.
#   Completed iter 52200/105000. Training loss: 2.27.
#   Completed iter 52300/105000. Training loss: 2.28.
#   Completed iter 52400/105000. Training loss: 2.18.
#   Completed iter 52500/105000. Training loss: 2.24.
#   Completed iter 52600/105000. Training loss: 2.24.
#   Completed iter 52700/105000. Training loss: 2.27.
#   Completed iter 52800/105000. Training loss: 2.24.
#   Completed iter 52900/105000. Training loss: 2.29.
#   Completed iter 53000/105000. Training loss: 2.26.
#   Completed iter 53100/105000. Training loss: 2.24.
#   Completed iter 53200/105000. Training loss: 2.23.
#   Completed iter 53300/105000. Training loss: 2.26.
#   Completed iter 53400/105000. Training loss: 2.28.
#   Completed iter 53500/105000. Training loss: 2.26.
#   Completed iter 53600/105000. Training loss: 2.29.
#   Completed iter 53700/105000. Training loss: 2.23.
#   Completed iter 53800/105000. Training loss: 2.24.
#   Completed iter 53900/105000. Training loss: 2.31.
#   Completed iter 54000/105000. Training loss: 2.26.
#   Completed iter 54100/105000. Training loss: 2.22.
#   Completed iter 54200/105000. Training loss: 2.29.
#   Completed iter 54300/105000. Training loss: 2.26.
#   Completed iter 54400/105000. Training loss: 2.29.
#   Completed iter 54500/105000. Training loss: 2.29.
#   Completed iter 54600/105000. Training loss: 2.20.
#   Completed iter 54700/105000. Training loss: 2.30.
#   Completed iter 54800/105000. Training loss: 2.27.
#   Completed iter 54900/105000. Training loss: 2.27.
#   Completed iter 55000/105000. Training loss: 2.26.
#   Completed iter 55100/105000. Training loss: 2.28.
#   Completed iter 55200/105000. Training loss: 2.25.
#   Completed iter 55300/105000. Training loss: 2.24.
#   Completed iter 55400/105000. Training loss: 2.23.
#   Completed iter 55500/105000. Training loss: 2.25.
#   Completed iter 55600/105000. Training loss: 2.22.
#   Completed iter 55700/105000. Training loss: 2.30.
#   Completed iter 55800/105000. Training loss: 2.21.
#   Completed iter 55900/105000. Training loss: 2.19.
#   Completed iter 56000/105000. Training loss: 2.30.
#   Completed iter 56100/105000. Training loss: 2.32.
#   Completed iter 56200/105000. Training loss: 2.32.
#   Completed iter 56300/105000. Training loss: 2.32.
#   Completed iter 56400/105000. Training loss: 2.25.
#   Completed iter 56500/105000. Training loss: 2.32.
#   Completed iter 56600/105000. Training loss: 2.25.
#   Completed iter 56700/105000. Training loss: 2.28.
#   Completed iter 56800/105000. Training loss: 2.22.
#   Completed iter 56900/105000. Training loss: 2.25.
#   Completed iter 57000/105000. Training loss: 2.27.
#   Completed iter 57100/105000. Training loss: 2.33.
#   Completed iter 57200/105000. Training loss: 2.20.
#   Completed iter 57300/105000. Training loss: 2.19.
#   Completed iter 57400/105000. Training loss: 2.25.
#   Completed iter 57500/105000. Training loss: 2.32.
#   Completed iter 57600/105000. Training loss: 2.29.
#   Completed iter 57700/105000. Training loss: 2.29.
#   Completed iter 57800/105000. Training loss: 2.31.
#   Completed iter 57900/105000. Training loss: 2.24.
#   Completed iter 58000/105000. Training loss: 2.30.
#   Completed iter 58100/105000. Training loss: 2.29.
#   Completed iter 58200/105000. Training loss: 2.23.
#   Completed iter 58300/105000. Training loss: 2.25.
#   Completed iter 58400/105000. Training loss: 2.27.
#   Completed iter 58500/105000. Training loss: 2.29.
#   Completed iter 58600/105000. Training loss: 2.30.
#   Completed iter 58700/105000. Training loss: 2.28.
#   Completed iter 58800/105000. Training loss: 2.31.
#   Completed iter 58900/105000. Training loss: 2.27.
#   Completed iter 59000/105000. Training loss: 2.28.
#   Completed iter 59100/105000. Training loss: 2.27.
#   Completed iter 59200/105000. Training loss: 2.26.
#   Completed iter 59300/105000. Training loss: 2.26.
#   Completed iter 59400/105000. Training loss: 2.27.
#   Completed iter 59500/105000. Training loss: 2.23.
#   Completed iter 59600/105000. Training loss: 2.28.
#   Completed iter 59700/105000. Training loss: 2.29.
#   Completed iter 59800/105000. Training loss: 2.19.
#   Completed iter 59900/105000. Training loss: 2.29.
#   Completed iter 60000/105000. Training loss: 2.27.
#   Completed iter 60100/105000. Training loss: 2.32.
#   Completed iter 60200/105000. Training loss: 2.26.
#   Completed iter 60300/105000. Training loss: 2.27.
#   Completed iter 60400/105000. Training loss: 2.27.
#   Completed iter 60500/105000. Training loss: 2.21.
#   Completed iter 60600/105000. Training loss: 2.25.
#   Completed iter 60700/105000. Training loss: 2.28.
#   Completed iter 60800/105000. Training loss: 2.27.
#   Completed iter 60900/105000. Training loss: 2.26.
#   Completed iter 61000/105000. Training loss: 2.23.
#   Completed iter 61100/105000. Training loss: 2.32.
#   Completed iter 61200/105000. Training loss: 2.24.
#   Completed iter 61300/105000. Training loss: 2.27.
#   Completed iter 61400/105000. Training loss: 2.24.
#   Completed iter 61500/105000. Training loss: 2.29.
#   Completed iter 61600/105000. Training loss: 2.28.
#   Completed iter 61700/105000. Training loss: 2.26.
#   Completed iter 61800/105000. Training loss: 2.26.
#   Completed iter 61900/105000. Training loss: 2.32.
#   Completed iter 62000/105000. Training loss: 2.25.
#   Completed iter 62100/105000. Training loss: 2.26.
#   Completed iter 62200/105000. Training loss: 2.30.
#   Completed iter 62300/105000. Training loss: 2.27.
#   Completed iter 62400/105000. Training loss: 2.22.
#   Completed iter 62500/105000. Training loss: 2.29.
#   Completed iter 62600/105000. Training loss: 2.29.
#   Completed iter 62700/105000. Training loss: 2.27.
#   Completed iter 62800/105000. Training loss: 2.25.
#   Completed iter 62900/105000. Training loss: 2.23.
#   Completed iter 63000/105000. Training loss: 2.23.
#   Completed iter 63100/105000. Training loss: 2.28.
#   Completed iter 63200/105000. Training loss: 2.27.
#   Completed iter 63300/105000. Training loss: 2.23.
#   Completed iter 63400/105000. Training loss: 2.28.
#   Completed iter 63500/105000. Training loss: 2.29.
#   Completed iter 63600/105000. Training loss: 2.27.
#   Completed iter 63700/105000. Training loss: 2.28.
#   Completed iter 63800/105000. Training loss: 2.26.
#   Completed iter 63900/105000. Training loss: 2.26.
#   Completed iter 64000/105000. Training loss: 2.26.
#   Completed iter 64100/105000. Training loss: 2.25.
#   Completed iter 64200/105000. Training loss: 2.25.
#   Completed iter 64300/105000. Training loss: 2.26.
#   Completed iter 64400/105000. Training loss: 2.28.
#   Completed iter 64500/105000. Training loss: 2.27.
#   Completed iter 64600/105000. Training loss: 2.25.
#   Completed iter 64700/105000. Training loss: 2.27.
#   Completed iter 64800/105000. Training loss: 2.30.
#   Completed iter 64900/105000. Training loss: 2.20.
#   Completed iter 65000/105000. Training loss: 2.27.
#   Completed iter 65100/105000. Training loss: 2.31.
#   Completed iter 65200/105000. Training loss: 2.28.
#   Completed iter 65300/105000. Training loss: 2.22.
#   Completed iter 65400/105000. Training loss: 2.29.
#   Completed iter 65500/105000. Training loss: 2.22.
#   Completed iter 65600/105000. Training loss: 2.28.
#   Completed iter 65700/105000. Training loss: 2.25.
#   Completed iter 65800/105000. Training loss: 2.30.
#   Completed iter 65900/105000. Training loss: 2.25.
#   Completed iter 66000/105000. Training loss: 2.26.
#   Completed iter 66100/105000. Training loss: 2.25.
#   Completed iter 66200/105000. Training loss: 2.25.
#   Completed iter 66300/105000. Training loss: 2.27.
#   Completed iter 66400/105000. Training loss: 2.21.
#   Completed iter 66500/105000. Training loss: 2.31.
#   Completed iter 66600/105000. Training loss: 2.22.
#   Completed iter 66700/105000. Training loss: 2.26.
#   Completed iter 66800/105000. Training loss: 2.27.
#   Completed iter 66900/105000. Training loss: 2.23.
#   Completed iter 67000/105000. Training loss: 2.27.
#   Completed iter 67100/105000. Training loss: 2.32.
#   Completed iter 67200/105000. Training loss: 2.29.
#   Completed iter 67300/105000. Training loss: 2.20.
#   Completed iter 67400/105000. Training loss: 2.30.
#   Completed iter 67500/105000. Training loss: 2.21.
#   Completed iter 67600/105000. Training loss: 2.26.
#   Completed iter 67700/105000. Training loss: 2.18.
#   Completed iter 67800/105000. Training loss: 2.25.
#   Completed iter 67900/105000. Training loss: 2.27.
#   Completed iter 68000/105000. Training loss: 2.27.
#   Completed iter 68100/105000. Training loss: 2.25.
#   Completed iter 68200/105000. Training loss: 2.28.
#   Completed iter 68300/105000. Training loss: 2.27.
#   Completed iter 68400/105000. Training loss: 2.21.
#   Completed iter 68500/105000. Training loss: 2.27.
#   Completed iter 68600/105000. Training loss: 2.31.
#   Completed iter 68700/105000. Training loss: 2.21.
#   Completed iter 68800/105000. Training loss: 2.24.
#   Completed iter 68900/105000. Training loss: 2.28.
#   Completed iter 69000/105000. Training loss: 2.25.
#   Completed iter 69100/105000. Training loss: 2.37.
#   Completed iter 69200/105000. Training loss: 2.26.
#   Completed iter 69300/105000. Training loss: 2.31.
#   Completed iter 69400/105000. Training loss: 2.25.
#   Completed iter 69500/105000. Training loss: 2.27.
#   Completed iter 69600/105000. Training loss: 2.32.
#   Completed iter 69700/105000. Training loss: 2.25.
#   Completed iter 69800/105000. Training loss: 2.26.
#   Completed iter 69900/105000. Training loss: 2.24.
#   Completed iter 70000/105000. Training loss: 2.25.
#   Completed iter 70100/105000. Training loss: 2.28.
#   Completed iter 70200/105000. Training loss: 2.29.
#   Completed iter 70300/105000. Training loss: 2.33.
#   Completed iter 70400/105000. Training loss: 2.26.
#   Completed iter 70500/105000. Training loss: 2.30.
#   Completed iter 70600/105000. Training loss: 2.25.
#   Completed iter 70700/105000. Training loss: 2.28.
#   Completed iter 70800/105000. Training loss: 2.26.
#   Completed iter 70900/105000. Training loss: 2.26.
#   Completed iter 71000/105000. Training loss: 2.27.
#   Completed iter 71100/105000. Training loss: 2.23.
#   Completed iter 71200/105000. Training loss: 2.28.
#   Completed iter 71300/105000. Training loss: 2.24.
#   Completed iter 71400/105000. Training loss: 2.28.
#   Completed iter 71500/105000. Training loss: 2.28.
#   Completed iter 71600/105000. Training loss: 2.30.
#   Completed iter 71700/105000. Training loss: 2.22.
#   Completed iter 71800/105000. Training loss: 2.34.
#   Completed iter 71900/105000. Training loss: 2.30.
#   Completed iter 72000/105000. Training loss: 2.25.
#   Completed iter 72100/105000. Training loss: 2.32.
#   Completed iter 72200/105000. Training loss: 2.25.
#   Completed iter 72300/105000. Training loss: 2.25.
#   Completed iter 72400/105000. Training loss: 2.23.
#   Completed iter 72500/105000. Training loss: 2.30.
#   Completed iter 72600/105000. Training loss: 2.28.
#   Completed iter 72700/105000. Training loss: 2.31.
#   Completed iter 72800/105000. Training loss: 2.21.
#   Completed iter 72900/105000. Training loss: 2.28.
#   Completed iter 73000/105000. Training loss: 2.23.
#   Completed iter 73100/105000. Training loss: 2.22.
#   Completed iter 73200/105000. Training loss: 2.28.
#   Completed iter 73300/105000. Training loss: 2.31.
#   Completed iter 73400/105000. Training loss: 2.30.
#   Completed iter 73500/105000. Training loss: 2.28.
#   Completed iter 73600/105000. Training loss: 2.30.
#   Completed iter 73700/105000. Training loss: 2.28.
#   Completed iter 73800/105000. Training loss: 2.27.
#   Completed iter 73900/105000. Training loss: 2.26.
#   Completed iter 74000/105000. Training loss: 2.29.
#   Completed iter 74100/105000. Training loss: 2.27.
#   Completed iter 74200/105000. Training loss: 2.30.
#   Completed iter 74300/105000. Training loss: 2.20.
#   Completed iter 74400/105000. Training loss: 2.30.
#   Completed iter 74500/105000. Training loss: 2.23.
#   Completed iter 74600/105000. Training loss: 2.30.
#   Completed iter 74700/105000. Training loss: 2.31.
#   Completed iter 74800/105000. Training loss: 2.32.
#   Completed iter 74900/105000. Training loss: 2.22.
#   Completed iter 75000/105000. Training loss: 2.27.
#   Completed iter 75100/105000. Training loss: 2.20.
#   Completed iter 75200/105000. Training loss: 2.25.
#   Completed iter 75300/105000. Training loss: 2.28.
#   Completed iter 75400/105000. Training loss: 2.20.
#   Completed iter 75500/105000. Training loss: 2.25.
#   Completed iter 75600/105000. Training loss: 2.18.
#   Completed iter 75700/105000. Training loss: 2.22.
#   Completed iter 75800/105000. Training loss: 2.23.
#   Completed iter 75900/105000. Training loss: 2.27.
#   Completed iter 76000/105000. Training loss: 2.28.
#   Completed iter 76100/105000. Training loss: 2.28.
#   Completed iter 76200/105000. Training loss: 2.25.
#   Completed iter 76300/105000. Training loss: 2.23.
#   Completed iter 76400/105000. Training loss: 2.28.
#   Completed iter 76500/105000. Training loss: 2.27.
#   Completed iter 76600/105000. Training loss: 2.28.
#   Completed iter 76700/105000. Training loss: 2.32.
#   Completed iter 76800/105000. Training loss: 2.23.
#   Completed iter 76900/105000. Training loss: 2.28.
#   Completed iter 77000/105000. Training loss: 2.28.
#   Completed iter 77100/105000. Training loss: 2.28.
#   Completed iter 77200/105000. Training loss: 2.27.
#   Completed iter 77300/105000. Training loss: 2.24.
#   Completed iter 77400/105000. Training loss: 2.26.
#   Completed iter 77500/105000. Training loss: 2.22.
#   Completed iter 77600/105000. Training loss: 2.29.
#   Completed iter 77700/105000. Training loss: 2.28.
#   Completed iter 77800/105000. Training loss: 2.24.
#   Completed iter 77900/105000. Training loss: 2.27.
#   Completed iter 78000/105000. Training loss: 2.27.
#   Completed iter 78100/105000. Training loss: 2.26.
#   Completed iter 78200/105000. Training loss: 2.25.
#   Completed iter 78300/105000. Training loss: 2.28.
#   Completed iter 78400/105000. Training loss: 2.23.
#   Completed iter 78500/105000. Training loss: 2.29.
#   Completed iter 78600/105000. Training loss: 2.28.
#   Completed iter 78700/105000. Training loss: 2.27.
#   Completed iter 78800/105000. Training loss: 2.28.
#   Completed iter 78900/105000. Training loss: 2.23.
#   Completed iter 79000/105000. Training loss: 2.29.
#   Completed iter 79100/105000. Training loss: 2.25.
#   Completed iter 79200/105000. Training loss: 2.25.
#   Completed iter 79300/105000. Training loss: 2.31.
#   Completed iter 79400/105000. Training loss: 2.22.
#   Completed iter 79500/105000. Training loss: 2.26.
#   Completed iter 79600/105000. Training loss: 2.21.
#   Completed iter 79700/105000. Training loss: 2.27.
#   Completed iter 79800/105000. Training loss: 2.28.
#   Completed iter 79900/105000. Training loss: 2.30.
#   Completed iter 80000/105000. Training loss: 2.24.
#   Completed iter 80100/105000. Training loss: 2.27.
#   Completed iter 80200/105000. Training loss: 2.26.
#   Completed iter 80300/105000. Training loss: 2.28.
#   Completed iter 80400/105000. Training loss: 2.25.
#   Completed iter 80500/105000. Training loss: 2.30.
#   Completed iter 80600/105000. Training loss: 2.20.
#   Completed iter 80700/105000. Training loss: 2.24.
#   Completed iter 80800/105000. Training loss: 2.20.
#   Completed iter 80900/105000. Training loss: 2.22.
#   Completed iter 81000/105000. Training loss: 2.16.
#   Completed iter 81100/105000. Training loss: 2.22.
#   Completed iter 81200/105000. Training loss: 2.21.
#   Completed iter 81300/105000. Training loss: 2.26.
#   Completed iter 81400/105000. Training loss: 2.25.
#   Completed iter 81500/105000. Training loss: 2.26.
#   Completed iter 81600/105000. Training loss: 2.28.
#   Completed iter 81700/105000. Training loss: 2.23.
#   Completed iter 81800/105000. Training loss: 2.20.
#   Completed iter 81900/105000. Training loss: 2.23.
#   Completed iter 82000/105000. Training loss: 2.28.
#   Completed iter 82100/105000. Training loss: 2.29.
#   Completed iter 82200/105000. Training loss: 2.22.
#   Completed iter 82300/105000. Training loss: 2.23.
#   Completed iter 82400/105000. Training loss: 2.25.
#   Completed iter 82500/105000. Training loss: 2.27.
#   Completed iter 82600/105000. Training loss: 2.32.
#   Completed iter 82700/105000. Training loss: 2.24.
#   Completed iter 82800/105000. Training loss: 2.24.
#   Completed iter 82900/105000. Training loss: 2.27.
#   Completed iter 83000/105000. Training loss: 2.28.
#   Completed iter 83100/105000. Training loss: 2.18.
#   Completed iter 83200/105000. Training loss: 2.26.
#   Completed iter 83300/105000. Training loss: 2.30.
#   Completed iter 83400/105000. Training loss: 2.27.
#   Completed iter 83500/105000. Training loss: 2.28.
#   Completed iter 83600/105000. Training loss: 2.23.
#   Completed iter 83700/105000. Training loss: 2.30.
#   Completed iter 83800/105000. Training loss: 2.34.
#   Completed iter 83900/105000. Training loss: 2.20.
#   Completed iter 84000/105000. Training loss: 2.27.
#   Completed iter 84100/105000. Training loss: 2.29.
#   Completed iter 84200/105000. Training loss: 2.27.
#   Completed iter 84300/105000. Training loss: 2.28.
#   Completed iter 84400/105000. Training loss: 2.24.
#   Completed iter 84500/105000. Training loss: 2.23.
#   Completed iter 84600/105000. Training loss: 2.30.
#   Completed iter 84700/105000. Training loss: 2.29.
#   Completed iter 84800/105000. Training loss: 2.31.
#   Completed iter 84900/105000. Training loss: 2.27.
#   Completed iter 85000/105000. Training loss: 2.29.
#   Completed iter 85100/105000. Training loss: 2.25.
#   Completed iter 85200/105000. Training loss: 2.25.
#   Completed iter 85300/105000. Training loss: 2.27.
#   Completed iter 85400/105000. Training loss: 2.31.
#   Completed iter 85500/105000. Training loss: 2.33.
#   Completed iter 85600/105000. Training loss: 2.27.
#   Completed iter 85700/105000. Training loss: 2.26.
#   Completed iter 85800/105000. Training loss: 2.20.
#   Completed iter 85900/105000. Training loss: 2.28.
#   Completed iter 86000/105000. Training loss: 2.27.
#   Completed iter 86100/105000. Training loss: 2.29.
#   Completed iter 86200/105000. Training loss: 2.23.
#   Completed iter 86300/105000. Training loss: 2.31.
#   Completed iter 86400/105000. Training loss: 2.29.
#   Completed iter 86500/105000. Training loss: 2.30.
#   Completed iter 86600/105000. Training loss: 2.31.
#   Completed iter 86700/105000. Training loss: 2.29.
#   Completed iter 86800/105000. Training loss: 2.28.
#   Completed iter 86900/105000. Training loss: 2.30.
#   Completed iter 87000/105000. Training loss: 2.28.
#   Completed iter 87100/105000. Training loss: 2.28.
#   Completed iter 87200/105000. Training loss: 2.24.
#   Completed iter 87300/105000. Training loss: 2.30.
#   Completed iter 87400/105000. Training loss: 2.25.
#   Completed iter 87500/105000. Training loss: 2.28.
#   Completed iter 87600/105000. Training loss: 2.26.
#   Completed iter 87700/105000. Training loss: 2.25.
#   Completed iter 87800/105000. Training loss: 2.26.
#   Completed iter 87900/105000. Training loss: 2.29.
#   Completed iter 88000/105000. Training loss: 2.27.
#   Completed iter 88100/105000. Training loss: 2.28.
#   Completed iter 88200/105000. Training loss: 2.21.
#   Completed iter 88300/105000. Training loss: 2.27.
#   Completed iter 88400/105000. Training loss: 2.26.
#   Completed iter 88500/105000. Training loss: 2.29.
#   Completed iter 88600/105000. Training loss: 2.26.
#   Completed iter 88700/105000. Training loss: 2.29.
#   Completed iter 88800/105000. Training loss: 2.23.
#   Completed iter 88900/105000. Training loss: 2.22.
#   Completed iter 89000/105000. Training loss: 2.21.
#   Completed iter 89100/105000. Training loss: 2.25.
#   Completed iter 89200/105000. Training loss: 2.31.
#   Completed iter 89300/105000. Training loss: 2.26.
#   Completed iter 89400/105000. Training loss: 2.21.
#   Completed iter 89500/105000. Training loss: 2.26.
#   Completed iter 89600/105000. Training loss: 2.29.
#   Completed iter 89700/105000. Training loss: 2.26.
#   Completed iter 89800/105000. Training loss: 2.27.
#   Completed iter 89900/105000. Training loss: 2.25.
#   Completed iter 90000/105000. Training loss: 2.20.
#   Completed iter 90100/105000. Training loss: 2.23.
#   Completed iter 90200/105000. Training loss: 2.25.
#   Completed iter 90300/105000. Training loss: 2.28.
#   Completed iter 90400/105000. Training loss: 2.22.
#   Completed iter 90500/105000. Training loss: 2.29.
#   Completed iter 90600/105000. Training loss: 2.27.
#   Completed iter 90700/105000. Training loss: 2.31.
#   Completed iter 90800/105000. Training loss: 2.23.
#   Completed iter 90900/105000. Training loss: 2.20.
#   Completed iter 91000/105000. Training loss: 2.21.
#   Completed iter 91100/105000. Training loss: 2.26.
#   Completed iter 91200/105000. Training loss: 2.30.
#   Completed iter 91300/105000. Training loss: 2.31.
#   Completed iter 91400/105000. Training loss: 2.18.
#   Completed iter 91500/105000. Training loss: 2.31.
#   Completed iter 91600/105000. Training loss: 2.24.
#   Completed iter 91700/105000. Training loss: 2.32.
#   Completed iter 91800/105000. Training loss: 2.30.
#   Completed iter 91900/105000. Training loss: 2.24.
#   Completed iter 92000/105000. Training loss: 2.25.
#   Completed iter 92100/105000. Training loss: 2.26.
#   Completed iter 92200/105000. Training loss: 2.27.
#   Completed iter 92300/105000. Training loss: 2.26.
#   Completed iter 92400/105000. Training loss: 2.23.
#   Completed iter 92500/105000. Training loss: 2.26.
#   Completed iter 92600/105000. Training loss: 2.29.
#   Completed iter 92700/105000. Training loss: 2.28.
#   Completed iter 92800/105000. Training loss: 2.18.
#   Completed iter 92900/105000. Training loss: 2.27.
#   Completed iter 93000/105000. Training loss: 2.27.
#   Completed iter 93100/105000. Training loss: 2.29.
#   Completed iter 93200/105000. Training loss: 2.25.
#   Completed iter 93300/105000. Training loss: 2.23.
#   Completed iter 93400/105000. Training loss: 2.30.
#   Completed iter 93500/105000. Training loss: 2.21.
#   Completed iter 93600/105000. Training loss: 2.30.
#   Completed iter 93700/105000. Training loss: 2.28.
#   Completed iter 93800/105000. Training loss: 2.35.
#   Completed iter 93900/105000. Training loss: 2.29.
#   Completed iter 94000/105000. Training loss: 2.29.
#   Completed iter 94100/105000. Training loss: 2.22.
#   Completed iter 94200/105000. Training loss: 2.30.
#   Completed iter 94300/105000. Training loss: 2.29.
#   Completed iter 94400/105000. Training loss: 2.26.
#   Completed iter 94500/105000. Training loss: 2.31.
#   Completed iter 94600/105000. Training loss: 2.32.
#   Completed iter 94700/105000. Training loss: 2.25.
#   Completed iter 94800/105000. Training loss: 2.22.
#   Completed iter 94900/105000. Training loss: 2.27.
#   Completed iter 95000/105000. Training loss: 2.24.
#   Completed iter 95100/105000. Training loss: 2.23.
#   Completed iter 95200/105000. Training loss: 2.20.
#   Completed iter 95300/105000. Training loss: 2.27.
#   Completed iter 95400/105000. Training loss: 2.23.
#   Completed iter 95500/105000. Training loss: 2.18.
#   Completed iter 95600/105000. Training loss: 2.17.
#   Completed iter 95700/105000. Training loss: 2.28.
#   Completed iter 95800/105000. Training loss: 2.25.
#   Completed iter 95900/105000. Training loss: 2.26.
#   Completed iter 96000/105000. Training loss: 2.27.
#   Completed iter 96100/105000. Training loss: 2.27.
#   Completed iter 96200/105000. Training loss: 2.30.
#   Completed iter 96300/105000. Training loss: 2.31.
#   Completed iter 96400/105000. Training loss: 2.31.
#   Completed iter 96500/105000. Training loss: 2.27.
#   Completed iter 96600/105000. Training loss: 2.30.
#   Completed iter 96700/105000. Training loss: 2.25.
#   Completed iter 96800/105000. Training loss: 2.26.
#   Completed iter 96900/105000. Training loss: 2.33.
#   Completed iter 97000/105000. Training loss: 2.30.
#   Completed iter 97100/105000. Training loss: 2.30.
#   Completed iter 97200/105000. Training loss: 2.24.
#   Completed iter 97300/105000. Training loss: 2.27.
#   Completed iter 97400/105000. Training loss: 2.22.
#   Completed iter 97500/105000. Training loss: 2.31.
#   Completed iter 97600/105000. Training loss: 2.28.
#   Completed iter 97700/105000. Training loss: 2.26.
#   Completed iter 97800/105000. Training loss: 2.23.
#   Completed iter 97900/105000. Training loss: 2.26.
#   Completed iter 98000/105000. Training loss: 2.27.
#   Completed iter 98100/105000. Training loss: 2.32.
#   Completed iter 98200/105000. Training loss: 2.28.
#   Completed iter 98300/105000. Training loss: 2.29.
#   Completed iter 98400/105000. Training loss: 2.20.
#   Completed iter 98500/105000. Training loss: 2.23.
#   Completed iter 98600/105000. Training loss: 2.24.
#   Completed iter 98700/105000. Training loss: 2.29.
#   Completed iter 98800/105000. Training loss: 2.23.
#   Completed iter 98900/105000. Training loss: 2.29.
#   Completed iter 99000/105000. Training loss: 2.22.
#   Completed iter 99100/105000. Training loss: 2.32.
#   Completed iter 99200/105000. Training loss: 2.29.
#   Completed iter 99300/105000. Training loss: 2.25.
#   Completed iter 99400/105000. Training loss: 2.28.
#   Completed iter 99500/105000. Training loss: 2.29.
#   Completed iter 99600/105000. Training loss: 2.26.
#   Completed iter 99700/105000. Training loss: 2.26.
#   Completed iter 99800/105000. Training loss: 2.28.
#   Completed iter 99900/105000. Training loss: 2.26.
#   Completed iter 100000/105000. Training loss: 2.27.
#   Completed iter 100100/105000. Training loss: 2.17.
#   Completed iter 100200/105000. Training loss: 2.24.
#   Completed iter 100300/105000. Training loss: 2.22.
#   Completed iter 100400/105000. Training loss: 2.25.
#   Completed iter 100500/105000. Training loss: 2.29.
#   Completed iter 100600/105000. Training loss: 2.30.
#   Completed iter 100700/105000. Training loss: 2.19.
#   Completed iter 100800/105000. Training loss: 2.27.
#   Completed iter 100900/105000. Training loss: 2.30.
#   Completed iter 101000/105000. Training loss: 2.24.
#   Completed iter 101100/105000. Training loss: 2.24.
#   Completed iter 101200/105000. Training loss: 2.28.
#   Completed iter 101300/105000. Training loss: 2.28.
#   Completed iter 101400/105000. Training loss: 2.30.
#   Completed iter 101500/105000. Training loss: 2.36.
#   Completed iter 101600/105000. Training loss: 2.26.
#   Completed iter 101700/105000. Training loss: 2.25.
#   Completed iter 101800/105000. Training loss: 2.29.
#   Completed iter 101900/105000. Training loss: 2.27.
#   Completed iter 102000/105000. Training loss: 2.24.
#   Completed iter 102100/105000. Training loss: 2.27.
#   Completed iter 102200/105000. Training loss: 2.29.
#   Completed iter 102300/105000. Training loss: 2.20.
#   Completed iter 102400/105000. Training loss: 2.25.
#   Completed iter 102500/105000. Training loss: 2.21.
#   Completed iter 102600/105000. Training loss: 2.26.
#   Completed iter 102700/105000. Training loss: 2.25.
#   Completed iter 102800/105000. Training loss: 2.29.
#   Completed iter 102900/105000. Training loss: 2.28.
#   Completed iter 103000/105000. Training loss: 2.21.
#   Completed iter 103100/105000. Training loss: 2.22.
#   Completed iter 103200/105000. Training loss: 2.25.
#   Completed iter 103300/105000. Training loss: 2.21.
#   Completed iter 103400/105000. Training loss: 2.24.
#   Completed iter 103500/105000. Training loss: 2.24.
#   Completed iter 103600/105000. Training loss: 2.25.
#   Completed iter 103700/105000. Training loss: 2.27.
#   Completed iter 103800/105000. Training loss: 2.30.
#   Completed iter 103900/105000. Training loss: 2.27.
#   Completed iter 104000/105000. Training loss: 2.17.
#   Completed iter 104100/105000. Training loss: 2.28.
#   Completed iter 104200/105000. Training loss: 2.18.
#   Completed iter 104300/105000. Training loss: 2.29.
#   Completed iter 104400/105000. Training loss: 2.21.
#   Completed iter 104500/105000. Training loss: 2.29.
#   Completed iter 104600/105000. Training loss: 2.21.
#   Completed iter 104700/105000. Training loss: 2.26.
#   Completed iter 104800/105000. Training loss: 2.30.
#   Completed iter 104900/105000. Training loss: 2.28.
# Finished training!
# Test accuracy 0.272

# %% [markdown]
# ### d. Visualize learned weights
#
# **TODO:** Run the following code that plots the network weights going to each output neuron. If all goes well, you should see something really cool! Include the plot in your submitted project to show me what you got!
#
# **Note:** the quality of your visualizations will depend on:
# - The quality of the hyperparameters that you got via grid search.
# - How many epochs that you trained the network before plotting the weights
#
# One extension idea: is to find the combination of the above that result in the best visualizations.

# %%
# We don't care about the bias wt
wts = bestNet.wts
# Reshape the wt vectors into spatial 'image' configurations to visualization
wts = wts.reshape(32, 32, 3, 10)

# Make a large new empty figure/plot
plt.figure(figsize=(20, 8))

# Loop through each output neuron
for i in range(10):
  # Make a 2x5 grid of images
  plt.subplot(2, 5, i+1)
  
  # Rescale the weights to be between 0 and 255
  currImg = 255.0 * (wts[:, :, :, i].squeeze() - np.min(wts)) / (np.max(wts) - np.min(wts))
  
  plt.imshow(currImg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
