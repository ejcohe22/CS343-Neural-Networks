# %% [markdown]
# **Sawyer Strong & Erik Cohen**
#
# Fall 2019
#
# CS 343: Neural Networks
#
# Project 2: Multi-layer Perceptrons
#
# **Draft due 11:59pm Thurs Sept 26**
#
#
# Summary of files in this project:
# - `softmax_layer.ipynb`
# - `single_layer_net.py`
# - `preprocess_data.py`
# - `mlp.ipynb`
# - `mlp.py`
#
# **REMINDER**: Submit rubric on Google Classroom

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

# for obtaining the STL-dataset
import load_stl10_dataset

# for preprocessing dataset
import preprocess_data

# Set the color style so that Professor Layton can see your plots
plt.style.use(['seaborn-colorblind', 'seaborn-darkgrid'])
# Make the font size larger
plt.rcParams.update({'font.size': 20})

# Turn off scientific notation when printing
np.set_printoptions(suppress=True, precision=3)

# Automatically reload external modules
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Overview
#
# In this project, you will implement Multilayer Perception (MLP) networks that classify image data belonging to one of 10 classes from the STL-10 dataset.
#
# You will create two networks that use the softmax activation function and cross-entropy loss:
#
# - One without a hidden layer (**Task 2**; this notebook) and
# - One with a hidden layer (**Task 3**; ``mlp.ipynb``)
#
# Before implementing the MLP with hidden layer, we will create a simpler single layer network (similar architecture to ADALINE) to test your loss and activation function code.
#
# Focus areas in this project are:
# - Working with a large dataset
# - Batch vs stochastic training
# - Regularization
# - Multi-class data classification
# - Network weight visualization

# %% [markdown]
# ## Task 1) Download and preprocess datasets

# %% [markdown]
# ### a. STL-10
#
# More info: https://cs.stanford.edu/~acoates/stl10/
#
# **Properties:**
# - 10 classes of images: airplane, bird, car, cat, deer, dog, horse, monkey, ship, truck
# - 5000 images.
# - 96x96 resolution (we will work with them converted to 32x32 for rapid development and debugging purposes)

# %% [markdown]
# #### (i) Download the STL-10 dataset, convert to 32x32 images
#
# This data acquistion script should "just work". You're welcome to take a peek at the script to see where the data is going, but you shouldn't need to tinker with it. It needs to download the dataset from the internet, which might take a few minutes. I set up the script so that it caches the dataset locally in your project folder, so you should only need to download it once. There is a progress percentage indicator.
#
# You should see the following output:
#
# `Images are: (5000, 96, 96, 3)
# Labels are: (5000,)
# Resizing 5000 images to 32x32...Done!
# `

# %%
# Download the dataset from the internet, convert it to Numpy ndarray, resize to 32x32
# cache it locally on your computer for faster loading next time.
stl_imgs, stl_labels = load_stl10_dataset.load()
# Out:
# Found cached numpy arrays the images and labels. Loading them...
# Images are: (5000, 32, 32, 3)
# Labels are: (5000,)

# %% [markdown]
# #### (ii) Take a look at a sample of the images in the dataset
#
# Let's take a look at the image categories that we want the neural network to learn

# %%
# Load in the string names for each class
classes = np.loadtxt(os.path.join('data', 'stl10_binary', 'class_names.txt'), dtype=str)

# %%
plt.figure(figsize=(10, 12))
plt.subplot
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    randInd = random.randint(0, len(stl_imgs)-1)
    plt.imshow(stl_imgs[randInd])
    plt.xlabel(classes[stl_labels[randInd]-1])
plt.show()

# %% [markdown]
# #### (iii) Preprocess the data
#
# Preprocessing data is an important part of working with neural networks.
#
# **TODO**: Fill in the function `preprocess_stl` in `preprocess_data.py`, implementing the 4 listed goals, to get the desired print out below.

# %%
# Preprocess image pixel values for the MLP net
stl_imgs, stl_labels = preprocess_data.preprocess_stl(stl_imgs, stl_labels)

print(f'stl_imgs dtype is {stl_imgs.dtype} and it should be float64')
print(f'stl_imgs max is {np.max(stl_imgs[:, 1:]):.3f} and it should be 0.668')
print(f'stl_imgs shape is {stl_imgs.shape} and it should be (5000, 3072)')
print(f'stl_labels span {stl_labels.min()}->{stl_labels.max()} and it should be 0->9')
# Out:
# stl_imgs dtype is float64 and it should be float64
# stl_imgs max is 0.668 and it should be 0.668
# stl_imgs shape is (5000, 3072) and it should be (5000, 3072)
# stl_labels span 0->9 and it should be 0->9

# %% [markdown]
# #### (iii) Create train, validation, test, and dev splits
#
# **TODO**: Complete the `create_splits` function in `preprocess_data.py` to divvy up the dataset into train/test/validation/development subsets, following the two main goals lists. You should obtain a printout as follows:
#
# `Train data shape:  (3500, 3072)
# Train labels shape:  (3500,)
# Test data shape:  (500, 3072)
# Test labels shape:  (500,)
# Validation data shape:  (500, 3072)
# Validation labels shape:  (500,)
# dev data shape:  (500, 3072)
# dev labels shape:  (500,)
# `

# %%
x_train, y_train, x_test, y_test, x_val, y_val, x_dev, y_dev = preprocess_data.create_splits(stl_imgs, stl_labels)  

print ('Train data shape: ', x_train.shape)
print ('Train labels shape: ', y_train.shape)
print ('Test data shape: ', x_test.shape)
print ('Test labels shape: ', y_test.shape)
print ('Validation data shape: ', x_val.shape)
print ('Validation labels shape: ', y_val.shape)
print ('dev data shape: ', x_dev.shape)
print ('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (3500, 3072)
# Train labels shape:  (3500,)
# Test data shape:  (500, 3072)
# Test labels shape:  (500,)
# Validation data shape:  (500, 3072)
# Validation labels shape:  (500,)
# dev data shape:  (500, 3072)
# dev labels shape:  (500,)

# %% [markdown]
# ## Task 2) Implement single layer network to test softmax activation and cross-entropy loss
#
# You will first implement and test out the softmax activation and cross-entropy loss in a single layer net before embedding it in a more complex multiple layer network.

# %% [markdown]
# ### a. Implement the following functions
#
# In `single_layer_net.py`, implement the following methods in the base class `SingleLayerNet`:
#
# - `fit`
# - `net_in`
# - `predict`
# - `one_hot`
# - `accuracy`
#
#
# In the child class `SingleLayerNetSoftmax` implement the following methods:
#
# - `activation` (softmax) $f(x_i) = \frac{e^{x_i}}{\sum_{j=1}^C e^{x_j}}$ where $x_i$ are the "net in" values and there are $C$ output neurons (one per input class). $f(x_i)$ is the activation values of each output neuron $i$. Since this is softmax, it is the probability that a given input belongs to the class $i$ coded by the output neuron.
# - `loss` (cross-entropy) $L(x_m) = -\frac{1}{B}\sum_{b=1}^B{Log \left (\frac{e^{x_m}}{\sum_{n=1}^C e^{x_n}}\right )}$. $m$ is the correct class for the $b^{th}$ input. $x_m$ is the output neuron activation for the correct class, $x_n$ is the output neuron activation for all of the classes (in the sum). The batch size is $B$, so the loss is averaged over each mini-batch of inputs. The expression in the $Log$ is just the softmax.
# - `gradient` (for softmax/cross-entropy)
#
# You're welcome to work in any order, but I recommend starting with `fit` because as you work though it, you should recognize why we need most of the other methods. You can finish `fit` or branch off as you need the other methods.

# %% [markdown]
# ### b. Test key functions

# %%
from single_layer_net import SingleLayerNetSoftmax

# %%
# Let's generate some small Gaussian weights equal to the length of an image feature vector
np.random.seed(0)
randWts = np.random.normal(loc=0, scale=0.01, size=(x_dev.shape[1], 10))
b = 1
softmaxNet = SingleLayerNetSoftmax()
randWts.shape

# for test code purposes, use the last 15 images/labels
test_imgs, test_labels = stl_imgs[-15:], stl_labels[-15:]

# %% [markdown]
# #### Test the `onehot` function

# %%
not_y_test = np.array([2, 2, 0, 1])
c_test = 4
y_one_hot = softmaxNet.one_hot(not_y_test, c_test)
print(f'Your one hot vectors:\n{y_one_hot}')
# Out:
# Your one hot vectors:
# [[0. 0. 1. 0.]
#  [0. 0. 1. 0.]
#  [1. 0. 0. 0.]
#  [0. 1. 0. 0.]]

# %% [markdown]
# Your one hot vectors should look like:
#
#     [[0. 0. 1. 0.]
#      [0. 0. 1. 0.]
#      [1. 0. 0. 0.]
#      [0. 1. 0. 0.]]

# %% [markdown]
# #### Test the `loss`,  `net_in`, softmax `activation` functions

# %%
lossNoReg, lossReg = softmaxNet.test_loss(randWts, b, test_imgs, test_labels)
print(f'The loss (without regularization) is {lossNoReg:.2f} and it should approx be 2.28')
print(f'The loss (with 0.5 regularization) is {lossReg:.2f} and it should approx be 3.04')
# Out:
# net in shape=(15, 10), min=0.6586955718394151, max=1.4084436090585781
# Should be
# net in shape=(15, 10), min=0.6586955718394152, max=1.4084436090585783
#
# net act shape=(15, 10), min=0.07413774498031761, max=0.14167423767472354
# Should be
# net act shape=(15, 10), min=0.07413774498031761, max=0.14167423767472354
#
# The loss (without regularization) is 2.28 and it should approx be 2.28
# The loss (with 0.5 regularization) is 3.04 and it should approx be 3.04

# %% [markdown]
# #### Test the `gradient` function

# %%
grad_wts, grad_b = softmaxNet.test_gradient(randWts, b, test_imgs, test_labels, 10)
print(f'1st few Wt gradient values are {grad_wts[:4,0]}\nand should be                  [0.01  0.015 0.014 0.007] ')
print(f'1st few Wt bias values are {grad_b[:4]}\nand should be              [ 0.103 -0.099  0.101 -0.026]')
# Out:
# net in: (15, 10), 0.6586955718394151, 1.4084436090585781
# y one hot: (15, 10), sum is 15.0
# 1st few Wt gradient values are [0.01  0.015 0.014 0.007]
# and should be                  [0.01  0.015 0.014 0.007]
# 1st few Wt bias values are [ 0.103 -0.099  0.101 -0.026]
# and should be              [ 0.103 -0.099  0.101 -0.026]

# %% [markdown]
# #### Test `fit` function

# %%
softmaxNet = SingleLayerNetSoftmax()
loss_history = softmaxNet.fit(x_dev, y_dev, n_epochs=600, mini_batch_sz=250)
# Out:
# Starting to train network...There will be 600 epochs and 1200 iterations total, 2 iter/epoch.
#   Completed iter 0/1200. Training loss: 2.31.
#   Completed iter 100/1200. Training loss: 2.32.
#   Completed iter 200/1200. Training loss: 2.29.
#   Completed iter 300/1200. Training loss: 2.26.
#   Completed iter 400/1200. Training loss: 2.24.
#   Completed iter 500/1200. Training loss: 2.23.
#   Completed iter 600/1200. Training loss: 2.23.
#   Completed iter 700/1200. Training loss: 2.24.
#   Completed iter 800/1200. Training loss: 2.19.
#   Completed iter 900/1200. Training loss: 2.21.
#   Completed iter 1000/1200. Training loss: 2.17.
#   Completed iter 1100/1200. Training loss: 2.18.
# Finished training!

# %% [markdown]
# Given the random mini-batch sampling process, you should get different specific numbers, but the loss should decrease with iterations. You should get something like this:
#
#     Starting to train network...There will be 600 epochs and 1200 iterations total, 2 iter/epoch.
#       Completed iter 0/1200. Training loss: 2.29.
#       Completed iter 100/1200. Training loss: 2.30.
#       Completed iter 200/1200. Training loss: 2.27.
#       Completed iter 300/1200. Training loss: 2.29.
#       Completed iter 400/1200. Training loss: 2.27.
#       Completed iter 500/1200. Training loss: 2.23.
#       Completed iter 600/1200. Training loss: 2.23.
#       Completed iter 700/1200. Training loss: 2.23.
#       Completed iter 800/1200. Training loss: 2.21.
#       Completed iter 900/1200. Training loss: 2.20.
#       Completed iter 1000/1200. Training loss: 2.20.
#       Completed iter 1100/1200. Training loss: 2.17.
#     Finished training!

# %% [markdown]
# ##### Plot the loss.
#
# It should look noisy, but on average be decreasing and look roughly linear.

# %%
def plot_cross_entropy_loss(loss_history):
    plt.plot(loss_history)
    plt.xlabel('Training iteration')
    plt.ylabel('loss (cross-entropy)')
    plt.show()
    
plot_cross_entropy_loss(loss_history)

# %% [markdown]
# **Question 1**: What do you think the linear drop in loss over the epochs tells us about the state of the training process? How is current training going? What's the future potential like?

# %% [markdown]
# **Answer:** The linear drop suggests that training is currently incomplete. We could increase the accuracy of the model by training for more epochs, or speed up training with a slightly larger learning rate.

# %% [markdown]
# #### Test regularization with training. The loss should hover around 17-18 for `reg=10`
#
# **Question 2**: Play around with the regularization parameter. You can drastically change the magnitude, but it should remain positive. How does this affect the training loss and why?

# %% [markdown]
# **Answer:** Increasing the regularization parameter can drastically increase loss, while reducing the regularization parameter decreases the loss, asymptotically approaching a minimum value. This is because the regularization term is an additive one.

# %%
softmaxNet = SingleLayerNetSoftmax()
loss_history = softmaxNet.fit(x_dev, y_dev, reg=10, n_epochs=500)
plot_cross_entropy_loss(loss_history)
# Out:
# Starting to train network...There will be 500 epochs and 500 iterations total, 1 iter/epoch.
#   Completed iter 0/500. Training loss: 17.77.
#   Completed iter 100/500. Training loss: 17.74.
#   Completed iter 200/500. Training loss: 17.74.
#   Completed iter 300/500. Training loss: 17.73.
#   Completed iter 400/500. Training loss: 17.71.
# Finished training!

# %% [markdown]
# #### Test training batch size
#
# **Question 3**: Play around with the batch size parameter. **How does this affect the training loss and why?** (Think about the error gradient and how the weights change)

# %% [markdown]
# **Answer:** The bigger the batch size, the less oscilation that we can see in the loss function. This is a result of the model not making changes based on smaller sets of images and then finding different changes to make on other sets of images. This is why, as we increase the batch size, we see a siginificantly smoother loss curve over iterations.

# %%
softmaxNet = SingleLayerNetSoftmax()
loss_history = softmaxNet.fit(x_dev, y_dev, mini_batch_sz=100, n_epochs=10, verbose=0);
plot_cross_entropy_loss(loss_history)

# %% [markdown]
# ### c. Train and optimize STL-10 dataset performance, plot results
#
# #### (i) Grid search
#
# As you've surely noticed, hyperparameters can drastically affect learning!
#
#
# **TODO:** Implement a grid search for the best hyperparameters
#
# - learning rate,
# - regularization
# - batch size
#
# The grid search process should:
#
# 1. Fit the model with specific values of hyperparameters that we're testing (using the training set).
# 2. Compute the accuracy on the training set.
# 3. Compute the accuracy on the validation set.
# 4. Print out and record the best parameter combination as you go (that improves the **validation set accuracy**).
# 5. Wipe the weights clean (reinitialize them) every time you try new parameters. It's easiest just to create a new net object on each run.
#
#
# This can take quite a bit of simulation time!
#
# I suggest implementing the coarse-to-fine search strategy. First try varying parameters over many orders of magnitude. Use the "new best" print outs to refine the ranges that you test. Abort simulations prematurely if you feel there aren't productive (no reason to wait!). This can take however long or short that you want to dedicate. Remember, you are printing out the best parameter values on each run, so you can just proceed with those.
#
# You should be able to achieve ~35% accuracy without too much effort (10% is chance performance).
#
# Your grade won't depend on the accuracy that you achieve, but if you get roughly the above accuracy, the payoff will be cooler visualizations in 2d!
#
# ##### Guidelines
# - Learning rates above 1e-1 don't really make sense.
# - Your mini-batch sizes should be <= N and >= 1

# %%
np.random.seed(42)

best_val_acc = 0
best_lr = 0
best_reg = 0
best_batch = 0

#Set default values that will be used when a hyperparam is not being explored
default_lr = 0.001
default_reg = 0.1
default_batch_size = 100

#Set the initial values for the hyperparams
init_lr = 0.05001
init_reg = 50
init_batch = 501

#Set the initial values for the intervals at we'll search across, for each hyperparam
#These will be halved every time the search gets finer
lr_interval = 0.005
reg_interval = 5
batch_interval = 50

#Implement coarse-to-fine search for each hyperparameter
#An outer for loop in which we adjust the intervals and initial values for each search
#An inner loop in which we search using the given intervals and inital values

#Learning Rate Search
for i in range(4):
    
    best_acc = 0
    
    for j in range(-10,11):
        
        lr = init_lr+(lr_interval*j)
        
        #Train
        softmaxNet = SingleLayerNetSoftmax()
        softmaxNet.fit(x_train, y_train, 10, lr, default_batch_size, default_reg, 0)
            
        #Compute accuracy
        train_pred = softmaxNet.predict(x_train)
        val_pred = softmaxNet.predict(x_val)
        train_acc = softmaxNet.accuracy(y_train,train_pred)
        val_acc = softmaxNet.accuracy(y_val,val_pred)
        
        print(f"Learning Rate: {lr:5f}\tAccuracy: {val_acc:3f}")
        
        #Update best if needed
        if val_acc > best_acc:
            best_acc = val_acc
            best_lr = lr
            
    
            
    #Set inital values to best values
    init_lr = best_lr
    lr_interval = lr_interval/2
    
    
    print(f"Zooming in on learning rate {best_lr:5f}\n")

#Batch Size Search
for i in range(4):
    
    best_acc = 0
    
    for j in range(-10,11):
        
        batch = init_batch+(batch_interval*j)
        
        if batch<1:
            continue
        
        #Train
        softmaxNet = SingleLayerNetSoftmax()
        softmaxNet.fit(x_train, y_train, 10, default_lr, batch, default_reg, 0)
            
        #Compute accuracy
        train_pred = softmaxNet.predict(x_train)
        val_pred = softmaxNet.predict(x_val)
        train_acc = softmaxNet.accuracy(y_train,train_pred)
        val_acc = softmaxNet.accuracy(y_val,val_pred)
        
        print(f"Batch Size: {batch:5f}\tAccuracy: {val_acc:3f}")
        
        #Update best if needed
        if val_acc > best_acc:
            best_acc = val_acc
            best_batch = batch

            
    #Set inital values to best values
    init_batch = best_batch
    batch_interval = int(batch_interval/2)

    print(f"Zooming in on batch size {best_batch:5f}\n")

#Batch Size Search
for i in range(4):
    
    best_acc = 0
    
    for j in range(-10,11):
        
        reg = init_reg+(reg_interval*j)
        
        #Train
        softmaxNet = SingleLayerNetSoftmax()
        softmaxNet.fit(x_train, y_train, 10, default_lr, default_batch_size, reg, 0)
            
        #Compute accuracy
        train_pred = softmaxNet.predict(x_train)
        val_pred = softmaxNet.predict(x_val)
        train_acc = softmaxNet.accuracy(y_train,train_pred)
        val_acc = softmaxNet.accuracy(y_val,val_pred)
        
        print(f"Reg rate: {reg:5f}\tAccuracy: {val_acc:3f}")
        
        #Update best if needed
        if val_acc > best_acc:
            best_acc = val_acc
            best_reg = reg
            
    #Set inital values to best values
    init_reg = best_reg
    reg_interval = reg_interval/2
    
    print(f"Zooming in on reg rate {best_reg:5f}\n")    

print(f"The best learning rate was {best_lr}")
print(f"The best batch-size was {best_batch}")
print(f"The best regularization value was {best_reg}")
# Out:
# Learning Rate: 0.000010	Accuracy: 0.108000
# Learning Rate: 0.005010	Accuracy: 0.346000
# Learning Rate: 0.010010	Accuracy: 0.366000
# Learning Rate: 0.015010	Accuracy: 0.378000
# Learning Rate: 0.020010	Accuracy: 0.362000
# Learning Rate: 0.025010	Accuracy: 0.370000
# Learning Rate: 0.030010	Accuracy: 0.376000
# Learning Rate: 0.035010	Accuracy: 0.392000
# Learning Rate: 0.040010	Accuracy: 0.364000
# Learning Rate: 0.045010	Accuracy: 0.374000
# Learning Rate: 0.050010	Accuracy: 0.378000
# Learning Rate: 0.055010	Accuracy: 0.360000
# Learning Rate: 0.060010	Accuracy: 0.380000
# Learning Rate: 0.065010	Accuracy: 0.382000
# Learning Rate: 0.070010	Accuracy: 0.374000
# Learning Rate: 0.075010	Accuracy: 0.370000
# Learning Rate: 0.080010	Accuracy: 0.384000
# Learning Rate: 0.085010	Accuracy: 0.380000
# Learning Rate: 0.090010	Accuracy: 0.372000
# Learning Rate: 0.095010	Accuracy: 0.378000
# Learning Rate: 0.100010	Accuracy: 0.366000
# Zooming in on learning rate 0.035010
#
# Learning Rate: 0.010010	Accuracy: 0.356000
# Learning Rate: 0.012510	Accuracy: 0.360000
# Learning Rate: 0.015010	Accuracy: 0.366000
# Learning Rate: 0.017510	Accuracy: 0.366000
# Learning Rate: 0.020010	Accuracy: 0.358000
# Learning Rate: 0.022510	Accuracy: 0.374000
# Learning Rate: 0.025010	Accuracy: 0.366000
# Learning Rate: 0.027510	Accuracy: 0.366000
# Learning Rate: 0.030010	Accuracy: 0.364000
# Learning Rate: 0.032510	Accuracy: 0.362000
# Learning Rate: 0.035010	Accuracy: 0.366000
# Learning Rate: 0.037510	Accuracy: 0.370000
# Learning Rate: 0.040010	Accuracy: 0.386000
# Learning Rate: 0.042510	Accuracy: 0.346000
# Learning Rate: 0.045010	Accuracy: 0.374000
# Learning Rate: 0.047510	Accuracy: 0.352000
# Learning Rate: 0.050010	Accuracy: 0.368000
# Learning Rate: 0.052510	Accuracy: 0.366000
# Learning Rate: 0.055010	Accuracy: 0.378000
# Learning Rate: 0.057510	Accuracy: 0.388000
# Learning Rate: 0.060010	Accuracy: 0.366000
# Zooming in on learning rate 0.057510
#
# Learning Rate: 0.045010	Accuracy: 0.362000
# Learning Rate: 0.046260	Accuracy: 0.362000
# Learning Rate: 0.047510	Accuracy: 0.364000
# Learning Rate: 0.048760	Accuracy: 0.376000
# Learning Rate: 0.050010	Accuracy: 0.360000
# Learning Rate: 0.051260	Accuracy: 0.374000
# Learning Rate: 0.052510	Accuracy: 0.372000
# Learning Rate: 0.053760	Accuracy: 0.372000
# Learning Rate: 0.055010	Accuracy: 0.378000
# Learning Rate: 0.056260	Accuracy: 0.358000
# Learning Rate: 0.057510	Accuracy: 0.360000
# Learning Rate: 0.058760	Accuracy: 0.356000
# Learning Rate: 0.060010	Accuracy: 0.358000
# Learning Rate: 0.061260	Accuracy: 0.376000
# Learning Rate: 0.062510	Accuracy: 0.374000
# Learning Rate: 0.063760	Accuracy: 0.374000
# Learning Rate: 0.065010	Accuracy: 0.358000
# Learning Rate: 0.066260	Accuracy: 0.362000
# Learning Rate: 0.067510	Accuracy: 0.382000
# Learning Rate: 0.068760	Accuracy: 0.366000
# Learning Rate: 0.070010	Accuracy: 0.368000
# Zooming in on learning rate 0.067510
#
# Learning Rate: 0.061260	Accuracy: 0.364000
# Learning Rate: 0.061885	Accuracy: 0.386000
# Learning Rate: 0.062510	Accuracy: 0.376000
# Learning Rate: 0.063135	Accuracy: 0.376000
# Learning Rate: 0.063760	Accuracy: 0.380000
# Learning Rate: 0.064385	Accuracy: 0.378000
# Learning Rate: 0.065010	Accuracy: 0.374000
# Learning Rate: 0.065635	Accuracy: 0.358000
# Learning Rate: 0.066260	Accuracy: 0.360000
# Learning Rate: 0.066885	Accuracy: 0.366000
# Learning Rate: 0.067510	Accuracy: 0.372000
# Learning Rate: 0.068135	Accuracy: 0.392000
# Learning Rate: 0.068760	Accuracy: 0.358000
# Learning Rate: 0.069385	Accuracy: 0.396000
# Learning Rate: 0.070010	Accuracy: 0.360000
# Learning Rate: 0.070635	Accuracy: 0.388000
# Learning Rate: 0.071260	Accuracy: 0.380000
# Learning Rate: 0.071885	Accuracy: 0.386000
# Learning Rate: 0.072510	Accuracy: 0.356000
# Learning Rate: 0.073135	Accuracy: 0.382000
# Learning Rate: 0.073760	Accuracy: 0.344000
# Zooming in on learning rate 0.069385
#
# Batch Size: 1.000000	Accuracy: 0.354000
# Batch Size: 51.000000	Accuracy: 0.296000
# Batch Size: 101.000000	Accuracy: 0.304000
# Batch Size: 151.000000	Accuracy: 0.270000
# Batch Size: 201.000000	Accuracy: 0.256000
# Batch Size: 251.000000	Accuracy: 0.220000
# Batch Size: 301.000000	Accuracy: 0.218000
# Batch Size: 351.000000	Accuracy: 0.228000
# Batch Size: 401.000000	Accuracy: 0.234000
# Batch Size: 451.000000	Accuracy: 0.222000
# Batch Size: 501.000000	Accuracy: 0.206000
# Batch Size: 551.000000	Accuracy: 0.194000
# Batch Size: 601.000000	Accuracy: 0.196000
# Batch Size: 651.000000	Accuracy: 0.238000
# Batch Size: 701.000000	Accuracy: 0.160000
# Batch Size: 751.000000	Accuracy: 0.180000
# Batch Size: 801.000000	Accuracy: 0.174000
# Batch Size: 851.000000	Accuracy: 0.200000
# Batch Size: 901.000000	Accuracy: 0.174000
# Batch Size: 951.000000	Accuracy: 0.156000
# Batch Size: 1001.000000	Accuracy: 0.188000
# Zooming in on batch size 1.000000
#
# Batch Size: 1.000000	Accuracy: 0.354000
# Batch Size: 26.000000	Accuracy: 0.348000
# Batch Size: 51.000000	Accuracy: 0.310000
# Batch Size: 76.000000	Accuracy: 0.276000
# Batch Size: 101.000000	Accuracy: 0.290000
# Batch Size: 126.000000	Accuracy: 0.262000
# Batch Size: 151.000000	Accuracy: 0.280000
# Batch Size: 176.000000	Accuracy: 0.280000
# Batch Size: 201.000000	Accuracy: 0.254000
# Batch Size: 226.000000	Accuracy: 0.264000
# Batch Size: 251.000000	Accuracy: 0.202000
# Zooming in on batch size 1.000000
#
# Batch Size: 1.000000	Accuracy: 0.362000
# Batch Size: 13.000000	Accuracy: 0.360000
# Batch Size: 25.000000	Accuracy: 0.332000
# Batch Size: 37.000000	Accuracy: 0.326000
# Batch Size: 49.000000	Accuracy: 0.304000
# Batch Size: 61.000000	Accuracy: 0.308000
# Batch Size: 73.000000	Accuracy: 0.308000
# Batch Size: 85.000000	Accuracy: 0.282000
# Batch Size: 97.000000	Accuracy: 0.248000
# Batch Size: 109.000000	Accuracy: 0.270000
# Batch Size: 121.000000	Accuracy: 0.268000
# Zooming in on batch size 1.000000
#
# Batch Size: 1.000000	Accuracy: 0.364000
# Batch Size: 7.000000	Accuracy: 0.376000
# Batch Size: 13.000000	Accuracy: 0.358000
# Batch Size: 19.000000	Accuracy: 0.346000
# Batch Size: 25.000000	Accuracy: 0.346000
# Batch Size: 31.000000	Accuracy: 0.342000
# Batch Size: 37.000000	Accuracy: 0.332000
# Batch Size: 43.000000	Accuracy: 0.296000
# Batch Size: 49.000000	Accuracy: 0.324000
# Batch Size: 55.000000	Accuracy: 0.308000
# Batch Size: 61.000000	Accuracy: 0.302000
# Zooming in on batch size 7.000000
#
# Reg rate: 0.000000	Accuracy: 0.282000
# Reg rate: 5.000000	Accuracy: 0.270000
# Reg rate: 10.000000	Accuracy: 0.280000
# Reg rate: 15.000000	Accuracy: 0.278000
# Reg rate: 20.000000	Accuracy: 0.270000
# Reg rate: 25.000000	Accuracy: 0.290000
# Reg rate: 30.000000	Accuracy: 0.274000
# Reg rate: 35.000000	Accuracy: 0.282000
# Reg rate: 40.000000	Accuracy: 0.290000
# Reg rate: 45.000000	Accuracy: 0.282000
# Reg rate: 50.000000	Accuracy: 0.266000
# Reg rate: 55.000000	Accuracy: 0.284000
# Reg rate: 60.000000	Accuracy: 0.262000
# Reg rate: 65.000000	Accuracy: 0.286000
# Reg rate: 70.000000	Accuracy: 0.258000
# Reg rate: 75.000000	Accuracy: 0.268000
# Reg rate: 80.000000	Accuracy: 0.270000
# Reg rate: 85.000000	Accuracy: 0.256000
# Reg rate: 90.000000	Accuracy: 0.272000
# Reg rate: 95.000000	Accuracy: 0.278000
# Reg rate: 100.000000	Accuracy: 0.282000
# Zooming in on reg rate 25.000000
#
# Reg rate: 0.000000	Accuracy: 0.296000
# Reg rate: 2.500000	Accuracy: 0.272000
# Reg rate: 5.000000	Accuracy: 0.294000
# Reg rate: 7.500000	Accuracy: 0.278000
# Reg rate: 10.000000	Accuracy: 0.262000
# Reg rate: 12.500000	Accuracy: 0.278000
# Reg rate: 15.000000	Accuracy: 0.268000
# Reg rate: 17.500000	Accuracy: 0.288000
# Reg rate: 20.000000	Accuracy: 0.288000
# Reg rate: 22.500000	Accuracy: 0.294000
# Reg rate: 25.000000	Accuracy: 0.292000
# Reg rate: 27.500000	Accuracy: 0.296000
# Reg rate: 30.000000	Accuracy: 0.272000
# Reg rate: 32.500000	Accuracy: 0.254000
# Reg rate: 35.000000	Accuracy: 0.288000
# Reg rate: 37.500000	Accuracy: 0.278000
# Reg rate: 40.000000	Accuracy: 0.298000
# Reg rate: 42.500000	Accuracy: 0.272000
# Reg rate: 45.000000	Accuracy: 0.278000
# Reg rate: 47.500000	Accuracy: 0.280000
# Reg rate: 50.000000	Accuracy: 0.264000
# Zooming in on reg rate 40.000000
#
# Reg rate: 27.500000	Accuracy: 0.286000
# Reg rate: 28.750000	Accuracy: 0.288000
# Reg rate: 30.000000	Accuracy: 0.284000
# Reg rate: 31.250000	Accuracy: 0.282000
# Reg rate: 32.500000	Accuracy: 0.294000
# Reg rate: 33.750000	Accuracy: 0.268000
# Reg rate: 35.000000	Accuracy: 0.260000
# Reg rate: 36.250000	Accuracy: 0.264000
# Reg rate: 37.500000	Accuracy: 0.256000
# Reg rate: 38.750000	Accuracy: 0.286000
# Reg rate: 40.000000	Accuracy: 0.258000
# Reg rate: 41.250000	Accuracy: 0.260000
# Reg rate: 42.500000	Accuracy: 0.284000
# Reg rate: 43.750000	Accuracy: 0.260000
# Reg rate: 45.000000	Accuracy: 0.272000
# Reg rate: 46.250000	Accuracy: 0.292000
# Reg rate: 47.500000	Accuracy: 0.278000
# Reg rate: 48.750000	Accuracy: 0.288000
# Reg rate: 50.000000	Accuracy: 0.284000
# Reg rate: 51.250000	Accuracy: 0.272000
# Reg rate: 52.500000	Accuracy: 0.292000
# Zooming in on reg rate 32.500000
#
# Reg rate: 26.250000	Accuracy: 0.276000
# Reg rate: 26.875000	Accuracy: 0.286000
# Reg rate: 27.500000	Accuracy: 0.282000
# Reg rate: 28.125000	Accuracy: 0.276000
# Reg rate: 28.750000	Accuracy: 0.274000
# Reg rate: 29.375000	Accuracy: 0.296000
# Reg rate: 30.000000	Accuracy: 0.274000
# Reg rate: 30.625000	Accuracy: 0.288000
# Reg rate: 31.250000	Accuracy: 0.266000
# Reg rate: 31.875000	Accuracy: 0.274000
# Reg rate: 32.500000	Accuracy: 0.280000
# Reg rate: 33.125000	Accuracy: 0.264000
# Reg rate: 33.750000	Accuracy: 0.256000
# Reg rate: 34.375000	Accuracy: 0.264000
# Reg rate: 35.000000	Accuracy: 0.264000
# Reg rate: 35.625000	Accuracy: 0.252000
# Reg rate: 36.250000	Accuracy: 0.284000
# Reg rate: 36.875000	Accuracy: 0.282000
# Reg rate: 37.500000	Accuracy: 0.276000
# Reg rate: 38.125000	Accuracy: 0.292000
# Reg rate: 38.750000	Accuracy: 0.288000
# Zooming in on reg rate 29.375000
#
# The best learning rate was 0.069385
# The best batch-size was 7
# The best regularization value was 29.375

# %% [markdown]
# #### (ii) Evaluate best model on test set
#
# **Question 4:** Now that you have "good" parameter values recorded, train a new model with the best learning rate, regularization strength, and batch size values. What accuracy do you get on the test set?

# %%
# TODO: Replace the following with your best values that you find above with grid search
best_lr = 0.069385
best_reg = 29.375
best_batch = 7

# %%
print(x_test.shape)
# Out:
# (500, 3072)

# %%
bestNet = SingleLayerNetSoftmax()
best_loss = bestNet.fit(x_train, y_train,
            lr=best_lr, reg=best_reg, mini_batch_sz=best_batch, n_epochs=300, verbose=2)
y_test_pred = bestNet.predict(x_test)

test_acc = bestNet.accuracy(y_test, y_test_pred)

print(f'Test accuracy {test_acc}')

plt.plot(best_loss)
plt.show()
# Out:
# Starting to train network...There will be 300 epochs and 150000 iterations total, 500 iter/epoch.
#   Completed iter 0/150000. Training loss: 47.32.
#   Completed iter 100/150000. Training loss: 149.16.
#   Completed iter 200/150000. Training loss: 231.28.
#   Completed iter 300/150000. Training loss: 315.77.
#   Completed iter 400/150000. Training loss: 397.01.
#   Completed iter 500/150000. Training loss: 481.55.
#   Completed iter 600/150000. Training loss: 572.67.
#   Completed iter 700/150000. Training loss: 659.94.
#   Completed iter 800/150000. Training loss: 743.30.
#   Completed iter 900/150000. Training loss: 828.35.
#   Completed iter 1000/150000. Training loss: 916.54.
#   Completed iter 1100/150000. Training loss: 1016.39.
#   Completed iter 1200/150000. Training loss: 1117.66.
#   Completed iter 1300/150000. Training loss: 1222.45.
#   Completed iter 1400/150000. Training loss: 1323.55.
#   Completed iter 1500/150000. Training loss: 1422.43.
#   Completed iter 1600/150000. Training loss: 1516.89.
#   Completed iter 1700/150000. Training loss: 1616.58.
#   Completed iter 1800/150000. Training loss: 1714.36.
#   Completed iter 1900/150000. Training loss: 1818.52.
#   Completed iter 2000/150000. Training loss: 1932.51.
#   Completed iter 2100/150000. Training loss: 2044.88.
#   Completed iter 2200/150000. Training loss: 2152.75.
#   Completed iter 2300/150000. Training loss: 2258.20.
#   Completed iter 2400/150000. Training loss: 2357.30.
#   Completed iter 2500/150000. Training loss: 2469.72.
#   Completed iter 2600/150000. Training loss: 2580.59.
#   Completed iter 2700/150000. Training loss: 2686.93.
#   Completed iter 2800/150000. Training loss: 2804.32.
#   Completed iter 2900/150000. Training loss: 2915.04.
#   Completed iter 3000/150000. Training loss: 3026.15.
#   Completed iter 3100/150000. Training loss: 3130.67.
#   Completed iter 3200/150000. Training loss: 3239.85.
#   Completed iter 3300/150000. Training loss: 3342.75.
#   Completed iter 3400/150000. Training loss: 3454.10.
#   Completed iter 3500/150000. Training loss: 3559.28.
#   Completed iter 3600/150000. Training loss: 3670.73.
#   Completed iter 3700/150000. Training loss: 3773.44.
#   Completed iter 3800/150000. Training loss: 3877.88.
#   Completed iter 3900/150000. Training loss: 3996.60.
#   Completed iter 4000/150000. Training loss: 4106.04.
#   Completed iter 4100/150000. Training loss: 4219.50.
#   Completed iter 4200/150000. Training loss: 4321.92.
#   Completed iter 4300/150000. Training loss: 4426.05.
#   Completed iter 4400/150000. Training loss: 4539.66.
#   Completed iter 4500/150000. Training loss: 4656.29.
#   Completed iter 4600/150000. Training loss: 4763.99.
#   Completed iter 4700/150000. Training loss: 4870.23.
#   Completed iter 4800/150000. Training loss: 4977.83.
#   Completed iter 4900/150000. Training loss: 5087.16.
#   Completed iter 5000/150000. Training loss: 5194.23.
#   Completed iter 5100/150000. Training loss: 5303.74.
#   Completed iter 5200/150000. Training loss: 5420.57.
#   Completed iter 5300/150000. Training loss: 5535.84.
#   Completed iter 5400/150000. Training loss: 5652.14.
#   Completed iter 5500/150000. Training loss: 5763.19.
#   Completed iter 5600/150000. Training loss: 5872.96.
#   Completed iter 5700/150000. Training loss: 5987.15.
#   Completed iter 5800/150000. Training loss: 6105.10.
#   Completed iter 5900/150000. Training loss: 6220.74.
#   Completed iter 6000/150000. Training loss: 6331.70.
#   Completed iter 6100/150000. Training loss: 6443.83.
#   Completed iter 6200/150000. Training loss: 6555.62.
#   Completed iter 6300/150000. Training loss: 6662.34.
#   Completed iter 6400/150000. Training loss: 6777.21.
#   Completed iter 6500/150000. Training loss: 6889.33.
#   Completed iter 6600/150000. Training loss: 6998.24.
#   Completed iter 6700/150000. Training loss: 7108.42.
#   Completed iter 6800/150000. Training loss: 7226.51.
#   Completed iter 6900/150000. Training loss: 7342.81.
#   Completed iter 7000/150000. Training loss: 7457.76.
#   Completed iter 7100/150000. Training loss: 7572.92.
#   Completed iter 7200/150000. Training loss: 7686.69.
#   Completed iter 7300/150000. Training loss: 7796.97.
#   Completed iter 7400/150000. Training loss: 7913.12.
#   Completed iter 7500/150000. Training loss: 8020.10.
#   Completed iter 7600/150000. Training loss: 8137.03.
#   Completed iter 7700/150000. Training loss: 8252.51.
#   Completed iter 7800/150000. Training loss: 8362.10.
#   Completed iter 7900/150000. Training loss: 8483.38.
#   Completed iter 8000/150000. Training loss: 8603.90.
#   Completed iter 8100/150000. Training loss: 8711.58.
#   Completed iter 8200/150000. Training loss: 8825.54.
#   Completed iter 8300/150000. Training loss: 8931.64.
#   Completed iter 8400/150000. Training loss: 9051.09.
#   Completed iter 8500/150000. Training loss: 9159.54.
#   Completed iter 8600/150000. Training loss: 9274.44.
#   Completed iter 8700/150000. Training loss: 9385.02.
#   Completed iter 8800/150000. Training loss: 9494.80.
#   Completed iter 8900/150000. Training loss: 9604.05.
#   Completed iter 9000/150000. Training loss: 9717.20.
#   Completed iter 9100/150000. Training loss: 9825.79.
#   Completed iter 9200/150000. Training loss: 9938.05.
#   Completed iter 9300/150000. Training loss: 10046.81.
#   Completed iter 9400/150000. Training loss: 10158.88.
#   Completed iter 9500/150000. Training loss: 10267.12.
#   Completed iter 9600/150000. Training loss: 10382.63.
#   Completed iter 9700/150000. Training loss: 10496.36.
#   Completed iter 9800/150000. Training loss: 10607.58.
#   Completed iter 9900/150000. Training loss: 10721.50.
#   Completed iter 10000/150000. Training loss: 10825.15.
#   Completed iter 10100/150000. Training loss: 10933.29.
#   Completed iter 10200/150000. Training loss: 11041.34.
#   Completed iter 10300/150000. Training loss: 11156.14.
#   Completed iter 10400/150000. Training loss: 11269.99.
#   Completed iter 10500/150000. Training loss: 11378.45.
#   Completed iter 10600/150000. Training loss: 11490.65.
#   Completed iter 10700/150000. Training loss: 11605.37.
#   Completed iter 10800/150000. Training loss: 11708.88.
#   Completed iter 10900/150000. Training loss: 11820.81.
#   Completed iter 11000/150000. Training loss: 11928.50.
#   Completed iter 11100/150000. Training loss: 12032.98.
#   Completed iter 11200/150000. Training loss: 12138.83.
#   Completed iter 11300/150000. Training loss: 12241.41.
#   Completed iter 11400/150000. Training loss: 12346.07.
#   Completed iter 11500/150000. Training loss: 12449.90.
#   Completed iter 11600/150000. Training loss: 12564.46.
#   Completed iter 11700/150000. Training loss: 12676.36.
#   Completed iter 11800/150000. Training loss: 12785.23.
#   Completed iter 11900/150000. Training loss: 12896.09.
#   Completed iter 12000/150000. Training loss: 13001.95.
#   Completed iter 12100/150000. Training loss: 13104.43.
#   Completed iter 12200/150000. Training loss: 13206.12.
#   Completed iter 12300/150000. Training loss: 13313.32.
#   Completed iter 12400/150000. Training loss: 13420.29.
#   Completed iter 12500/150000. Training loss: 13520.36.
#   Completed iter 12600/150000. Training loss: 13626.23.
#   Completed iter 12700/150000. Training loss: 13733.27.
#   Completed iter 12800/150000. Training loss: 13841.82.
#   Completed iter 12900/150000. Training loss: 13943.82.
#   Completed iter 13000/150000. Training loss: 14045.17.
#   Completed iter 13100/150000. Training loss: 14149.77.
#   Completed iter 13200/150000. Training loss: 14259.86.
#   Completed iter 13300/150000. Training loss: 14367.03.
#   Completed iter 13400/150000. Training loss: 14479.24.
#   Completed iter 13500/150000. Training loss: 14585.37.
#   Completed iter 13600/150000. Training loss: 14694.25.
#   Completed iter 13700/150000. Training loss: 14796.45.
#   Completed iter 13800/150000. Training loss: 14909.74.
#   Completed iter 13900/150000. Training loss: 15016.69.
#   Completed iter 14000/150000. Training loss: 15123.74.
#   Completed iter 14100/150000. Training loss: 15230.90.
#   Completed iter 14200/150000. Training loss: 15340.18.
#   Completed iter 14300/150000. Training loss: 15439.88.
#   Completed iter 14400/150000. Training loss: 15541.38.
#   Completed iter 14500/150000. Training loss: 15646.48.
#   Completed iter 14600/150000. Training loss: 15752.00.
#   Completed iter 14700/150000. Training loss: 15854.25.
#   Completed iter 14800/150000. Training loss: 15956.51.
#   Completed iter 14900/150000. Training loss: 16070.69.
#   Completed iter 15000/150000. Training loss: 16172.74.
#   Completed iter 15100/150000. Training loss: 16276.68.
#   Completed iter 15200/150000. Training loss: 16380.96.
#   Completed iter 15300/150000. Training loss: 16479.57.
#   Completed iter 15400/150000. Training loss: 16581.28.
#   Completed iter 15500/150000. Training loss: 16688.15.
#   Completed iter 15600/150000. Training loss: 16791.39.
#   Completed iter 15700/150000. Training loss: 16894.47.
#   Completed iter 15800/150000. Training loss: 17000.14.
#   Completed iter 15900/150000. Training loss: 17104.45.
#   Completed iter 16000/150000. Training loss: 17204.52.
#   Completed iter 16100/150000. Training loss: 17306.28.
#   Completed iter 16200/150000. Training loss: 17404.05.
#   Completed iter 16300/150000. Training loss: 17501.33.
#   Completed iter 16400/150000. Training loss: 17601.34.
#   Completed iter 16500/150000. Training loss: 17700.47.
#   Completed iter 16600/150000. Training loss: 17797.63.
#   Completed iter 16700/150000. Training loss: 17896.80.
#   Completed iter 16800/150000. Training loss: 17998.68.
#   Completed iter 16900/150000. Training loss: 18099.71.
#   Completed iter 17000/150000. Training loss: 18200.42.
#   Completed iter 17100/150000. Training loss: 18299.35.
#   Completed iter 17200/150000. Training loss: 18396.21.
#   Completed iter 17300/150000. Training loss: 18495.02.
#   Completed iter 17400/150000. Training loss: 18593.33.
#   Completed iter 17500/150000. Training loss: 18693.63.
#   Completed iter 17600/150000. Training loss: 18795.44.
#   Completed iter 17700/150000. Training loss: 18898.94.
#   Completed iter 17800/150000. Training loss: 18997.83.
#   Completed iter 17900/150000. Training loss: 19094.72.
#   Completed iter 18000/150000. Training loss: 19196.33.
#   Completed iter 18100/150000. Training loss: 19292.38.
#   Completed iter 18200/150000. Training loss: 19388.25.
#   Completed iter 18300/150000. Training loss: 19488.75.
#   Completed iter 18400/150000. Training loss: 19588.45.
#   Completed iter 18500/150000. Training loss: 19685.56.
#   Completed iter 18600/150000. Training loss: 19789.03.
#   Completed iter 18700/150000. Training loss: 19881.28.
#   Completed iter 18800/150000. Training loss: 19977.59.
#   Completed iter 18900/150000. Training loss: 20081.18.
#   Completed iter 19000/150000. Training loss: 20177.12.
#   Completed iter 19100/150000. Training loss: 20274.56.
#   Completed iter 19200/150000. Training loss: 20369.99.
#   Completed iter 19300/150000. Training loss: 20468.19.
#   Completed iter 19400/150000. Training loss: 20571.05.
#   Completed iter 19500/150000. Training loss: 20663.18.
#   Completed iter 19600/150000. Training loss: 20764.70.
#   Completed iter 19700/150000. Training loss: 20862.15.
#   Completed iter 19800/150000. Training loss: 20963.68.
#   Completed iter 19900/150000. Training loss: 21060.88.
#   Completed iter 20000/150000. Training loss: 21153.07.
#   Completed iter 20100/150000. Training loss: 21249.77.
#   Completed iter 20200/150000. Training loss: 21350.34.
#   Completed iter 20300/150000. Training loss: 21444.35.
#   Completed iter 20400/150000. Training loss: 21540.73.
#   Completed iter 20500/150000. Training loss: 21631.28.
#   Completed iter 20600/150000. Training loss: 21726.84.
#   Completed iter 20700/150000. Training loss: 21815.85.
#   Completed iter 20800/150000. Training loss: 21913.96.
#   Completed iter 20900/150000. Training loss: 22002.74.
#   Completed iter 21000/150000. Training loss: 22099.61.
#   Completed iter 21100/150000. Training loss: 22193.81.
#   Completed iter 21200/150000. Training loss: 22291.24.
#   Completed iter 21300/150000. Training loss: 22387.57.
#   Completed iter 21400/150000. Training loss: 22481.35.
#   Completed iter 21500/150000. Training loss: 22573.61.
#   Completed iter 21600/150000. Training loss: 22667.55.
#   Completed iter 21700/150000. Training loss: 22764.84.
#   Completed iter 21800/150000. Training loss: 22861.47.
#   Completed iter 21900/150000. Training loss: 22954.84.
#   Completed iter 22000/150000. Training loss: 23048.84.
#   Completed iter 22100/150000. Training loss: 23143.02.
#   Completed iter 22200/150000. Training loss: 23233.57.
#   Completed iter 22300/150000. Training loss: 23325.68.
#   Completed iter 22400/150000. Training loss: 23422.48.
#   Completed iter 22500/150000. Training loss: 23511.85.
#   Completed iter 22600/150000. Training loss: 23607.36.
#   Completed iter 22700/150000. Training loss: 23700.37.
#   Completed iter 22800/150000. Training loss: 23792.19.
#   Completed iter 22900/150000. Training loss: 23886.00.
#   Completed iter 23000/150000. Training loss: 23977.45.
#   Completed iter 23100/150000. Training loss: 24070.70.
#   Completed iter 23200/150000. Training loss: 24158.95.
#   Completed iter 23300/150000. Training loss: 24249.34.
#   Completed iter 23400/150000. Training loss: 24342.54.
#   Completed iter 23500/150000. Training loss: 24432.30.
#   Completed iter 23600/150000. Training loss: 24520.59.
#   Completed iter 23700/150000. Training loss: 24613.41.
#   Completed iter 23800/150000. Training loss: 24710.40.
#   Completed iter 23900/150000. Training loss: 24805.98.
#   Completed iter 24000/150000. Training loss: 24897.81.
#   Completed iter 24100/150000. Training loss: 24989.18.
#   Completed iter 24200/150000. Training loss: 25074.92.
#   Completed iter 24300/150000. Training loss: 25165.36.
#   Completed iter 24400/150000. Training loss: 25258.40.
#   Completed iter 24500/150000. Training loss: 25345.83.
#   Completed iter 24600/150000. Training loss: 25435.36.
#   Completed iter 24700/150000. Training loss: 25525.62.
#   Completed iter 24800/150000. Training loss: 25614.58.
#   Completed iter 24900/150000. Training loss: 25704.42.
#   Completed iter 25000/150000. Training loss: 25794.76.
#   Completed iter 25100/150000. Training loss: 25881.49.
#   Completed iter 25200/150000. Training loss: 25966.28.
#   Completed iter 25300/150000. Training loss: 26052.73.
#   Completed iter 25400/150000. Training loss: 26139.71.
#   Completed iter 25500/150000. Training loss: 26227.66.
#   Completed iter 25600/150000. Training loss: 26315.84.
#   Completed iter 25700/150000. Training loss: 26403.20.
#   Completed iter 25800/150000. Training loss: 26494.54.
#   Completed iter 25900/150000. Training loss: 26582.11.
#   Completed iter 26000/150000. Training loss: 26678.66.
#   Completed iter 26100/150000. Training loss: 26769.39.
#   Completed iter 26200/150000. Training loss: 26854.34.
#   Completed iter 26300/150000. Training loss: 26938.12.
#   Completed iter 26400/150000. Training loss: 27033.86.
#   Completed iter 26500/150000. Training loss: 27119.79.
#   Completed iter 26600/150000. Training loss: 27206.10.
#   Completed iter 26700/150000. Training loss: 27289.20.
#   Completed iter 26800/150000. Training loss: 27377.28.
#   Completed iter 26900/150000. Training loss: 27464.12.
#   Completed iter 27000/150000. Training loss: 27554.70.
#   Completed iter 27100/150000. Training loss: 27641.15.
#   Completed iter 27200/150000. Training loss: 27722.34.
#   Completed iter 27300/150000. Training loss: 27802.24.
#   Completed iter 27400/150000. Training loss: 27888.89.
#   Completed iter 27500/150000. Training loss: 27974.39.
#   Completed iter 27600/150000. Training loss: 28057.87.
#   Completed iter 27700/150000. Training loss: 28140.86.
#   Completed iter 27800/150000. Training loss: 28226.50.
#   Completed iter 27900/150000. Training loss: 28310.07.
#   Completed iter 28000/150000. Training loss: 28392.00.
#   Completed iter 28100/150000. Training loss: 28477.49.
#   Completed iter 28200/150000. Training loss: 28562.29.
#   Completed iter 28300/150000. Training loss: 28648.82.
#   Completed iter 28400/150000. Training loss: 28735.06.
#   Completed iter 28500/150000. Training loss: 28811.10.
#   Completed iter 28600/150000. Training loss: 28896.47.
#   Completed iter 28700/150000. Training loss: 28982.00.
#   Completed iter 28800/150000. Training loss: 29065.18.
#   Completed iter 28900/150000. Training loss: 29146.66.
#   Completed iter 29000/150000. Training loss: 29221.37.
#   Completed iter 29100/150000. Training loss: 29306.44.
#   Completed iter 29200/150000. Training loss: 29385.07.
#   Completed iter 29300/150000. Training loss: 29469.63.
#   Completed iter 29400/150000. Training loss: 29550.75.
#   Completed iter 29500/150000. Training loss: 29633.09.
#   Completed iter 29600/150000. Training loss: 29715.07.
#   Completed iter 29700/150000. Training loss: 29798.08.
#   Completed iter 29800/150000. Training loss: 29878.40.
#   Completed iter 29900/150000. Training loss: 29961.45.
#   Completed iter 30000/150000. Training loss: 30047.18.
#   Completed iter 30100/150000. Training loss: 30130.82.
#   Completed iter 30200/150000. Training loss: 30216.66.
#   Completed iter 30300/150000. Training loss: 30297.40.
#   Completed iter 30400/150000. Training loss: 30374.01.
#   Completed iter 30500/150000. Training loss: 30460.19.
#   Completed iter 30600/150000. Training loss: 30542.50.
#   Completed iter 30700/150000. Training loss: 30621.86.
#   Completed iter 30800/150000. Training loss: 30701.73.
#   Completed iter 30900/150000. Training loss: 30789.45.
#   Completed iter 31000/150000. Training loss: 30869.69.
#   Completed iter 31100/150000. Training loss: 30949.33.
#   Completed iter 31200/150000. Training loss: 31030.93.
#   Completed iter 31300/150000. Training loss: 31113.08.
#   Completed iter 31400/150000. Training loss: 31192.90.
#   Completed iter 31500/150000. Training loss: 31275.96.
#   Completed iter 31600/150000. Training loss: 31359.85.
#   Completed iter 31700/150000. Training loss: 31439.30.
#   Completed iter 31800/150000. Training loss: 31520.37.
#   Completed iter 31900/150000. Training loss: 31599.71.
#   Completed iter 32000/150000. Training loss: 31676.83.
#   Completed iter 32100/150000. Training loss: 31753.73.
#   Completed iter 32200/150000. Training loss: 31835.46.
#   Completed iter 32300/150000. Training loss: 31913.18.
#   Completed iter 32400/150000. Training loss: 31989.81.
#   Completed iter 32500/150000. Training loss: 32061.87.
#   Completed iter 32600/150000. Training loss: 32139.86.
#   Completed iter 32700/150000. Training loss: 32219.77.
#   Completed iter 32800/150000. Training loss: 32299.02.
#   Completed iter 32900/150000. Training loss: 32375.84.
#   Completed iter 33000/150000. Training loss: 32456.02.
#   Completed iter 33100/150000. Training loss: 32528.28.
#   Completed iter 33200/150000. Training loss: 32606.17.
#   Completed iter 33300/150000. Training loss: 32678.09.
#   Completed iter 33400/150000. Training loss: 32752.16.
#   Completed iter 33500/150000. Training loss: 32829.37.
#   Completed iter 33600/150000. Training loss: 32908.09.
#   Completed iter 33700/150000. Training loss: 32984.85.
#   Completed iter 33800/150000. Training loss: 33062.45.
#   Completed iter 33900/150000. Training loss: 33140.96.
#   Completed iter 34000/150000. Training loss: 33222.81.
#   Completed iter 34100/150000. Training loss: 33300.99.
#   Completed iter 34200/150000. Training loss: 33376.19.
#   Completed iter 34300/150000. Training loss: 33451.61.
#   Completed iter 34400/150000. Training loss: 33526.92.
#   Completed iter 34500/150000. Training loss: 33597.53.
#   Completed iter 34600/150000. Training loss: 33671.89.
#   Completed iter 34700/150000. Training loss: 33752.41.
#   Completed iter 34800/150000. Training loss: 33829.23.
#   Completed iter 34900/150000. Training loss: 33907.00.
#   Completed iter 35000/150000. Training loss: 33988.85.
#   Completed iter 35100/150000. Training loss: 34065.36.
#   Completed iter 35200/150000. Training loss: 34141.70.
#   Completed iter 35300/150000. Training loss: 34211.93.
#   Completed iter 35400/150000. Training loss: 34289.62.
#   Completed iter 35500/150000. Training loss: 34360.72.
#   Completed iter 35600/150000. Training loss: 34437.80.
#   Completed iter 35700/150000. Training loss: 34513.51.
#   Completed iter 35800/150000. Training loss: 34585.58.
#   Completed iter 35900/150000. Training loss: 34659.60.
#   Completed iter 36000/150000. Training loss: 34734.58.
#   Completed iter 36100/150000. Training loss: 34812.47.
#   Completed iter 36200/150000. Training loss: 34891.02.
#   Completed iter 36300/150000. Training loss: 34968.14.
#   Completed iter 36400/150000. Training loss: 35046.27.
#   Completed iter 36500/150000. Training loss: 35122.42.
#   Completed iter 36600/150000. Training loss: 35192.09.
#   Completed iter 36700/150000. Training loss: 35266.15.
#   Completed iter 36800/150000. Training loss: 35338.17.
#   Completed iter 36900/150000. Training loss: 35414.34.
#   Completed iter 37000/150000. Training loss: 35483.09.
#   Completed iter 37100/150000. Training loss: 35556.12.
#   Completed iter 37200/150000. Training loss: 35625.13.
#   Completed iter 37300/150000. Training loss: 35696.46.
#   Completed iter 37400/150000. Training loss: 35771.12.
#   Completed iter 37500/150000. Training loss: 35844.61.
#   Completed iter 37600/150000. Training loss: 35916.54.
#   Completed iter 37700/150000. Training loss: 35990.96.
#   Completed iter 37800/150000. Training loss: 36062.03.
#   Completed iter 37900/150000. Training loss: 36130.94.
#   Completed iter 38000/150000. Training loss: 36198.02.
#   Completed iter 38100/150000. Training loss: 36267.96.
#   Completed iter 38200/150000. Training loss: 36340.30.
#   Completed iter 38300/150000. Training loss: 36409.81.
#   Completed iter 38400/150000. Training loss: 36477.65.
#   Completed iter 38500/150000. Training loss: 36549.00.
#   Completed iter 38600/150000. Training loss: 36618.93.
#   Completed iter 38700/150000. Training loss: 36686.15.
#   Completed iter 38800/150000. Training loss: 36753.93.
#   Completed iter 38900/150000. Training loss: 36824.55.
#   Completed iter 39000/150000. Training loss: 36893.00.
#   Completed iter 39100/150000. Training loss: 36968.93.
#   Completed iter 39200/150000. Training loss: 37044.73.
#   Completed iter 39300/150000. Training loss: 37116.33.
#   Completed iter 39400/150000. Training loss: 37182.59.
#   Completed iter 39500/150000. Training loss: 37252.68.
#   Completed iter 39600/150000. Training loss: 37321.04.
#   Completed iter 39700/150000. Training loss: 37392.70.
#   Completed iter 39800/150000. Training loss: 37462.64.
#   Completed iter 39900/150000. Training loss: 37530.74.
#   Completed iter 40000/150000. Training loss: 37600.69.
#   Completed iter 40100/150000. Training loss: 37668.46.
#   Completed iter 40200/150000. Training loss: 37737.85.
#   Completed iter 40300/150000. Training loss: 37807.86.
#   Completed iter 40400/150000. Training loss: 37877.18.
#   Completed iter 40500/150000. Training loss: 37941.80.
#   Completed iter 40600/150000. Training loss: 38008.73.
#   Completed iter 40700/150000. Training loss: 38077.80.
#   Completed iter 40800/150000. Training loss: 38148.74.
#   Completed iter 40900/150000. Training loss: 38216.22.
#   Completed iter 41000/150000. Training loss: 38282.19.
#   Completed iter 41100/150000. Training loss: 38346.04.
#   Completed iter 41200/150000. Training loss: 38414.25.
#   Completed iter 41300/150000. Training loss: 38482.60.
#   Completed iter 41400/150000. Training loss: 38553.70.
#   Completed iter 41500/150000. Training loss: 38621.38.
#   Completed iter 41600/150000. Training loss: 38693.58.
#   Completed iter 41700/150000. Training loss: 38762.22.
#   Completed iter 41800/150000. Training loss: 38832.21.
#   Completed iter 41900/150000. Training loss: 38901.86.
#   Completed iter 42000/150000. Training loss: 38966.15.
#   Completed iter 42100/150000. Training loss: 39032.83.
#   Completed iter 42200/150000. Training loss: 39100.06.
#   Completed iter 42300/150000. Training loss: 39168.33.
#   Completed iter 42400/150000. Training loss: 39234.80.
#   Completed iter 42500/150000. Training loss: 39305.38.
#   Completed iter 42600/150000. Training loss: 39370.10.
#   Completed iter 42700/150000. Training loss: 39435.97.
#   Completed iter 42800/150000. Training loss: 39500.38.
#   Completed iter 42900/150000. Training loss: 39571.85.
#   Completed iter 43000/150000. Training loss: 39642.08.
#   Completed iter 43100/150000. Training loss: 39707.49.
#   Completed iter 43200/150000. Training loss: 39774.65.
#   Completed iter 43300/150000. Training loss: 39839.97.
#   Completed iter 43400/150000. Training loss: 39909.81.
#   Completed iter 43500/150000. Training loss: 39977.76.
#   Completed iter 43600/150000. Training loss: 40044.92.
#   Completed iter 43700/150000. Training loss: 40113.55.
#   Completed iter 43800/150000. Training loss: 40180.46.
#   Completed iter 43900/150000. Training loss: 40242.28.
#   Completed iter 44000/150000. Training loss: 40309.85.
#   Completed iter 44100/150000. Training loss: 40376.48.
#   Completed iter 44200/150000. Training loss: 40444.94.
#   Completed iter 44300/150000. Training loss: 40512.22.
#   Completed iter 44400/150000. Training loss: 40578.93.
#   Completed iter 44500/150000. Training loss: 40644.61.
#   Completed iter 44600/150000. Training loss: 40707.84.
#   Completed iter 44700/150000. Training loss: 40771.56.
#   Completed iter 44800/150000. Training loss: 40835.99.
#   Completed iter 44900/150000. Training loss: 40902.42.
#   Completed iter 45000/150000. Training loss: 40968.56.
#   Completed iter 45100/150000. Training loss: 41035.29.
#   Completed iter 45200/150000. Training loss: 41102.80.
#   Completed iter 45300/150000. Training loss: 41172.66.
#   Completed iter 45400/150000. Training loss: 41237.90.
#   Completed iter 45500/150000. Training loss: 41303.28.
#   Completed iter 45600/150000. Training loss: 41370.48.
#   Completed iter 45700/150000. Training loss: 41432.96.
#   Completed iter 45800/150000. Training loss: 41498.83.
#   Completed iter 45900/150000. Training loss: 41562.45.
#   Completed iter 46000/150000. Training loss: 41624.20.
#   Completed iter 46100/150000. Training loss: 41687.59.
#   Completed iter 46200/150000. Training loss: 41749.92.
#   Completed iter 46300/150000. Training loss: 41814.64.
#   Completed iter 46400/150000. Training loss: 41879.31.
#   Completed iter 46500/150000. Training loss: 41944.42.
#   Completed iter 46600/150000. Training loss: 42008.91.
#   Completed iter 46700/150000. Training loss: 42073.50.
#   Completed iter 46800/150000. Training loss: 42138.00.
#   Completed iter 46900/150000. Training loss: 42200.87.
#   Completed iter 47000/150000. Training loss: 42263.10.
#   Completed iter 47100/150000. Training loss: 42327.14.
#   Completed iter 47200/150000. Training loss: 42386.73.
#   Completed iter 47300/150000. Training loss: 42449.55.
#   Completed iter 47400/150000. Training loss: 42511.60.
#   Completed iter 47500/150000. Training loss: 42574.34.
#   Completed iter 47600/150000. Training loss: 42638.10.
#   Completed iter 47700/150000. Training loss: 42700.80.
#   Completed iter 47800/150000. Training loss: 42766.14.
#   Completed iter 47900/150000. Training loss: 42824.52.
#   Completed iter 48000/150000. Training loss: 42883.68.
#   Completed iter 48100/150000. Training loss: 42944.38.
#   Completed iter 48200/150000. Training loss: 43009.63.
#   Completed iter 48300/150000. Training loss: 43069.91.
#   Completed iter 48400/150000. Training loss: 43132.41.
#   Completed iter 48500/150000. Training loss: 43192.57.
#   Completed iter 48600/150000. Training loss: 43253.75.
#   Completed iter 48700/150000. Training loss: 43314.99.
#   Completed iter 48800/150000. Training loss: 43373.42.
#   Completed iter 48900/150000. Training loss: 43436.53.
#   Completed iter 49000/150000. Training loss: 43497.37.
#   Completed iter 49100/150000. Training loss: 43562.84.
#   Completed iter 49200/150000. Training loss: 43624.27.
#   Completed iter 49300/150000. Training loss: 43684.78.
#   Completed iter 49400/150000. Training loss: 43745.77.
#   Completed iter 49500/150000. Training loss: 43805.11.
#   Completed iter 49600/150000. Training loss: 43870.01.
#   Completed iter 49700/150000. Training loss: 43930.65.
#   Completed iter 49800/150000. Training loss: 43990.42.
#   Completed iter 49900/150000. Training loss: 44052.23.
#   Completed iter 50000/150000. Training loss: 44111.28.
#   Completed iter 50100/150000. Training loss: 44174.02.
#   Completed iter 50200/150000. Training loss: 44239.52.
#   Completed iter 50300/150000. Training loss: 44303.11.
#   Completed iter 50400/150000. Training loss: 44362.61.
#   Completed iter 50500/150000. Training loss: 44423.77.
#   Completed iter 50600/150000. Training loss: 44484.31.
#   Completed iter 50700/150000. Training loss: 44542.87.
#   Completed iter 50800/150000. Training loss: 44605.34.
#   Completed iter 50900/150000. Training loss: 44671.54.
#   Completed iter 51000/150000. Training loss: 44732.64.
#   Completed iter 51100/150000. Training loss: 44794.09.
#   Completed iter 51200/150000. Training loss: 44857.56.
#   Completed iter 51300/150000. Training loss: 44915.47.
#   Completed iter 51400/150000. Training loss: 44973.34.
#   Completed iter 51500/150000. Training loss: 45033.93.
#   Completed iter 51600/150000. Training loss: 45091.34.
#   Completed iter 51700/150000. Training loss: 45151.62.
#   Completed iter 51800/150000. Training loss: 45211.48.
#   Completed iter 51900/150000. Training loss: 45270.62.
#   Completed iter 52000/150000. Training loss: 45328.73.
#   Completed iter 52100/150000. Training loss: 45386.41.
#   Completed iter 52200/150000. Training loss: 45445.40.
#   Completed iter 52300/150000. Training loss: 45505.06.
#   Completed iter 52400/150000. Training loss: 45564.07.
#   Completed iter 52500/150000. Training loss: 45623.55.
#   Completed iter 52600/150000. Training loss: 45684.66.
#   Completed iter 52700/150000. Training loss: 45743.88.
#   Completed iter 52800/150000. Training loss: 45804.61.
#   Completed iter 52900/150000. Training loss: 45859.85.
#   Completed iter 53000/150000. Training loss: 45919.55.
#   Completed iter 53100/150000. Training loss: 45979.16.
#   Completed iter 53200/150000. Training loss: 46037.43.
#   Completed iter 53300/150000. Training loss: 46094.16.
#   Completed iter 53400/150000. Training loss: 46155.64.
#   Completed iter 53500/150000. Training loss: 46212.32.
#   Completed iter 53600/150000. Training loss: 46270.27.
#   Completed iter 53700/150000. Training loss: 46327.59.
#   Completed iter 53800/150000. Training loss: 46384.71.
#   Completed iter 53900/150000. Training loss: 46441.92.
#   Completed iter 54000/150000. Training loss: 46498.50.
#   Completed iter 54100/150000. Training loss: 46556.65.
#   Completed iter 54200/150000. Training loss: 46613.84.
#   Completed iter 54300/150000. Training loss: 46670.34.
#   Completed iter 54400/150000. Training loss: 46728.68.
#   Completed iter 54500/150000. Training loss: 46784.04.
#   Completed iter 54600/150000. Training loss: 46839.58.
#   Completed iter 54700/150000. Training loss: 46900.22.
#   Completed iter 54800/150000. Training loss: 46957.54.
#   Completed iter 54900/150000. Training loss: 47015.91.
#   Completed iter 55000/150000. Training loss: 47074.53.
#   Completed iter 55100/150000. Training loss: 47129.39.
#   Completed iter 55200/150000. Training loss: 47185.67.
#   Completed iter 55300/150000. Training loss: 47243.76.
#   Completed iter 55400/150000. Training loss: 47298.89.
#   Completed iter 55500/150000. Training loss: 47355.99.
#   Completed iter 55600/150000. Training loss: 47412.77.
#   Completed iter 55700/150000. Training loss: 47470.18.
#   Completed iter 55800/150000. Training loss: 47524.39.
#   Completed iter 55900/150000. Training loss: 47582.54.
#   Completed iter 56000/150000. Training loss: 47637.38.
#   Completed iter 56100/150000. Training loss: 47694.74.
#   Completed iter 56200/150000. Training loss: 47754.81.
#   Completed iter 56300/150000. Training loss: 47812.96.
#   Completed iter 56400/150000. Training loss: 47870.67.
#   Completed iter 56500/150000. Training loss: 47927.01.
#   Completed iter 56600/150000. Training loss: 47982.37.
#   Completed iter 56700/150000. Training loss: 48036.16.
#   Completed iter 56800/150000. Training loss: 48089.80.
#   Completed iter 56900/150000. Training loss: 48143.65.
#   Completed iter 57000/150000. Training loss: 48199.01.
#   Completed iter 57100/150000. Training loss: 48256.31.
#   Completed iter 57200/150000. Training loss: 48312.73.
#   Completed iter 57300/150000. Training loss: 48369.63.
#   Completed iter 57400/150000. Training loss: 48423.07.
#   Completed iter 57500/150000. Training loss: 48478.16.
#   Completed iter 57600/150000. Training loss: 48534.58.
#   Completed iter 57700/150000. Training loss: 48588.72.
#   Completed iter 57800/150000. Training loss: 48642.46.
#   Completed iter 57900/150000. Training loss: 48699.54.
#   Completed iter 58000/150000. Training loss: 48753.81.
#   Completed iter 58100/150000. Training loss: 48809.17.
#   Completed iter 58200/150000. Training loss: 48865.16.
#   Completed iter 58300/150000. Training loss: 48918.55.
#   Completed iter 58400/150000. Training loss: 48974.13.
#   Completed iter 58500/150000. Training loss: 49031.70.
#   Completed iter 58600/150000. Training loss: 49087.54.
#   Completed iter 58700/150000. Training loss: 49143.56.
#   Completed iter 58800/150000. Training loss: 49196.26.
#   Completed iter 58900/150000. Training loss: 49251.45.
#   Completed iter 59000/150000. Training loss: 49309.75.
#   Completed iter 59100/150000. Training loss: 49364.23.
#   Completed iter 59200/150000. Training loss: 49417.28.
#   Completed iter 59300/150000. Training loss: 49471.16.
#   Completed iter 59400/150000. Training loss: 49525.84.
#   Completed iter 59500/150000. Training loss: 49578.93.
#   Completed iter 59600/150000. Training loss: 49634.15.
#   Completed iter 59700/150000. Training loss: 49685.90.
#   Completed iter 59800/150000. Training loss: 49743.41.
#   Completed iter 59900/150000. Training loss: 49798.55.
#   Completed iter 60000/150000. Training loss: 49853.20.
#   Completed iter 60100/150000. Training loss: 49906.54.
#   Completed iter 60200/150000. Training loss: 49958.75.
#   Completed iter 60300/150000. Training loss: 50012.29.
#   Completed iter 60400/150000. Training loss: 50062.50.
#   Completed iter 60500/150000. Training loss: 50116.45.
#   Completed iter 60600/150000. Training loss: 50171.64.
#   Completed iter 60700/150000. Training loss: 50226.44.
#   Completed iter 60800/150000. Training loss: 50278.70.
#   Completed iter 60900/150000. Training loss: 50332.57.
#   Completed iter 61000/150000. Training loss: 50387.12.
#   Completed iter 61100/150000. Training loss: 50443.49.
#   Completed iter 61200/150000. Training loss: 50496.62.
#   Completed iter 61300/150000. Training loss: 50547.11.
#   Completed iter 61400/150000. Training loss: 50598.49.
#   Completed iter 61500/150000. Training loss: 50653.20.
#   Completed iter 61600/150000. Training loss: 50706.19.
#   Completed iter 61700/150000. Training loss: 50761.00.
#   Completed iter 61800/150000. Training loss: 50814.84.
#   Completed iter 61900/150000. Training loss: 50868.41.
#   Completed iter 62000/150000. Training loss: 50921.29.
#   Completed iter 62100/150000. Training loss: 50972.99.
#   Completed iter 62200/150000. Training loss: 51026.31.
#   Completed iter 62300/150000. Training loss: 51077.40.
#   Completed iter 62400/150000. Training loss: 51128.07.
#   Completed iter 62500/150000. Training loss: 51180.97.
#   Completed iter 62600/150000. Training loss: 51233.76.
#   Completed iter 62700/150000. Training loss: 51284.34.
#   Completed iter 62800/150000. Training loss: 51336.59.
#   Completed iter 62900/150000. Training loss: 51390.04.
#   Completed iter 63000/150000. Training loss: 51441.61.
#   Completed iter 63100/150000. Training loss: 51492.79.
#   Completed iter 63200/150000. Training loss: 51544.32.
#   Completed iter 63300/150000. Training loss: 51593.95.
#   Completed iter 63400/150000. Training loss: 51646.26.
#   Completed iter 63500/150000. Training loss: 51698.16.
#   Completed iter 63600/150000. Training loss: 51751.17.
#   Completed iter 63700/150000. Training loss: 51801.65.
#   Completed iter 63800/150000. Training loss: 51849.45.
#   Completed iter 63900/150000. Training loss: 51900.30.
#   Completed iter 64000/150000. Training loss: 51950.56.
#   Completed iter 64100/150000. Training loss: 52003.55.
#   Completed iter 64200/150000. Training loss: 52054.09.
#   Completed iter 64300/150000. Training loss: 52105.53.
#   Completed iter 64400/150000. Training loss: 52157.97.
#   Completed iter 64500/150000. Training loss: 52211.29.
#   Completed iter 64600/150000. Training loss: 52260.28.
#   Completed iter 64700/150000. Training loss: 52310.26.
#   Completed iter 64800/150000. Training loss: 52363.93.
#   Completed iter 64900/150000. Training loss: 52411.20.
#   Completed iter 65000/150000. Training loss: 52460.61.
#   Completed iter 65100/150000. Training loss: 52509.83.
#   Completed iter 65200/150000. Training loss: 52559.08.
#   Completed iter 65300/150000. Training loss: 52610.93.
#   Completed iter 65400/150000. Training loss: 52660.04.
#   Completed iter 65500/150000. Training loss: 52710.50.
#   Completed iter 65600/150000. Training loss: 52762.19.
#   Completed iter 65700/150000. Training loss: 52813.56.
#   Completed iter 65800/150000. Training loss: 52866.06.
#   Completed iter 65900/150000. Training loss: 52918.66.
#   Completed iter 66000/150000. Training loss: 52970.04.
#   Completed iter 66100/150000. Training loss: 53019.95.
#   Completed iter 66200/150000. Training loss: 53072.08.
#   Completed iter 66300/150000. Training loss: 53123.48.
#   Completed iter 66400/150000. Training loss: 53173.52.
#   Completed iter 66500/150000. Training loss: 53226.57.
#   Completed iter 66600/150000. Training loss: 53277.21.
#   Completed iter 66700/150000. Training loss: 53328.75.
#   Completed iter 66800/150000. Training loss: 53376.50.
#   Completed iter 66900/150000. Training loss: 53424.14.
#   Completed iter 67000/150000. Training loss: 53474.94.
#   Completed iter 67100/150000. Training loss: 53523.13.
#   Completed iter 67200/150000. Training loss: 53574.28.
#   Completed iter 67300/150000. Training loss: 53623.98.
#   Completed iter 67400/150000. Training loss: 53672.13.
#   Completed iter 67500/150000. Training loss: 53723.67.
#   Completed iter 67600/150000. Training loss: 53772.89.
#   Completed iter 67700/150000. Training loss: 53819.57.
#   Completed iter 67800/150000. Training loss: 53866.73.
#   Completed iter 67900/150000. Training loss: 53913.97.
#   Completed iter 68000/150000. Training loss: 53965.38.
#   Completed iter 68100/150000. Training loss: 54016.29.
#   Completed iter 68200/150000. Training loss: 54063.81.
#   Completed iter 68300/150000. Training loss: 54111.93.
#   Completed iter 68400/150000. Training loss: 54158.33.
#   Completed iter 68500/150000. Training loss: 54207.43.
#   Completed iter 68600/150000. Training loss: 54258.27.
#   Completed iter 68700/150000. Training loss: 54308.14.
#   Completed iter 68800/150000. Training loss: 54357.02.
#   Completed iter 68900/150000. Training loss: 54404.16.
#   Completed iter 69000/150000. Training loss: 54449.09.
#   Completed iter 69100/150000. Training loss: 54500.70.
#   Completed iter 69200/150000. Training loss: 54548.50.
#   Completed iter 69300/150000. Training loss: 54599.62.
#   Completed iter 69400/150000. Training loss: 54646.71.
#   Completed iter 69500/150000. Training loss: 54694.12.
#   Completed iter 69600/150000. Training loss: 54743.00.
#   Completed iter 69700/150000. Training loss: 54791.71.
#   Completed iter 69800/150000. Training loss: 54839.05.
#   Completed iter 69900/150000. Training loss: 54888.74.
#   Completed iter 70000/150000. Training loss: 54935.87.
#   Completed iter 70100/150000. Training loss: 54983.27.
#   Completed iter 70200/150000. Training loss: 55030.04.
#   Completed iter 70300/150000. Training loss: 55076.96.
#   Completed iter 70400/150000. Training loss: 55124.58.
#   Completed iter 70500/150000. Training loss: 55173.02.
#   Completed iter 70600/150000. Training loss: 55222.85.
#   Completed iter 70700/150000. Training loss: 55272.05.
#   Completed iter 70800/150000. Training loss: 55319.90.
#   Completed iter 70900/150000. Training loss: 55367.15.
#   Completed iter 71000/150000. Training loss: 55414.39.
#   Completed iter 71100/150000. Training loss: 55465.55.
#   Completed iter 71200/150000. Training loss: 55513.53.
#   Completed iter 71300/150000. Training loss: 55558.98.
#   Completed iter 71400/150000. Training loss: 55606.79.
#   Completed iter 71500/150000. Training loss: 55654.18.
#   Completed iter 71600/150000. Training loss: 55700.54.
#   Completed iter 71700/150000. Training loss: 55747.17.
#   Completed iter 71800/150000. Training loss: 55792.42.
#   Completed iter 71900/150000. Training loss: 55839.60.
#   Completed iter 72000/150000. Training loss: 55889.16.
#   Completed iter 72100/150000. Training loss: 55936.02.
#   Completed iter 72200/150000. Training loss: 55983.32.
#   Completed iter 72300/150000. Training loss: 56029.98.
#   Completed iter 72400/150000. Training loss: 56078.34.
#   Completed iter 72500/150000. Training loss: 56123.85.
#   Completed iter 72600/150000. Training loss: 56169.30.
#   Completed iter 72700/150000. Training loss: 56216.71.
#   Completed iter 72800/150000. Training loss: 56263.72.
#   Completed iter 72900/150000. Training loss: 56310.62.
#   Completed iter 73000/150000. Training loss: 56357.44.
#   Completed iter 73100/150000. Training loss: 56404.58.
#   Completed iter 73200/150000. Training loss: 56450.31.
#   Completed iter 73300/150000. Training loss: 56497.00.
#   Completed iter 73400/150000. Training loss: 56540.87.
#   Completed iter 73500/150000. Training loss: 56586.19.
#   Completed iter 73600/150000. Training loss: 56633.95.
#   Completed iter 73700/150000. Training loss: 56677.83.
#   Completed iter 73800/150000. Training loss: 56722.96.
#   Completed iter 73900/150000. Training loss: 56766.86.
#   Completed iter 74000/150000. Training loss: 56815.80.
#   Completed iter 74100/150000. Training loss: 56862.43.
#   Completed iter 74200/150000. Training loss: 56910.02.
#   Completed iter 74300/150000. Training loss: 56956.96.
#   Completed iter 74400/150000. Training loss: 57005.06.
#   Completed iter 74500/150000. Training loss: 57051.00.
#   Completed iter 74600/150000. Training loss: 57095.27.
#   Completed iter 74700/150000. Training loss: 57141.60.
#   Completed iter 74800/150000. Training loss: 57187.45.
#   Completed iter 74900/150000. Training loss: 57231.91.
#   Completed iter 75000/150000. Training loss: 57276.08.
#   Completed iter 75100/150000. Training loss: 57322.31.
#   Completed iter 75200/150000. Training loss: 57365.89.
#   Completed iter 75300/150000. Training loss: 57412.63.
#   Completed iter 75400/150000. Training loss: 57456.71.
#   Completed iter 75500/150000. Training loss: 57500.89.
#   Completed iter 75600/150000. Training loss: 57547.60.
#   Completed iter 75700/150000. Training loss: 57596.09.
#   Completed iter 75800/150000. Training loss: 57643.87.
#   Completed iter 75900/150000. Training loss: 57692.86.
#   Completed iter 76000/150000. Training loss: 57738.16.
#   Completed iter 76100/150000. Training loss: 57784.60.
#   Completed iter 76200/150000. Training loss: 57830.23.
#   Completed iter 76300/150000. Training loss: 57878.94.
#   Completed iter 76400/150000. Training loss: 57923.66.
#   Completed iter 76500/150000. Training loss: 57968.57.
#   Completed iter 76600/150000. Training loss: 58014.93.
#   Completed iter 76700/150000. Training loss: 58060.45.
#   Completed iter 76800/150000. Training loss: 58106.52.
#   Completed iter 76900/150000. Training loss: 58153.19.
#   Completed iter 77000/150000. Training loss: 58197.57.
#   Completed iter 77100/150000. Training loss: 58241.35.
#   Completed iter 77200/150000. Training loss: 58289.34.
#   Completed iter 77300/150000. Training loss: 58331.14.
#   Completed iter 77400/150000. Training loss: 58378.28.
#   Completed iter 77500/150000. Training loss: 58423.89.
#   Completed iter 77600/150000. Training loss: 58467.03.
#   Completed iter 77700/150000. Training loss: 58513.70.
#   Completed iter 77800/150000. Training loss: 58559.54.
#   Completed iter 77900/150000. Training loss: 58605.07.
#   Completed iter 78000/150000. Training loss: 58651.80.
#   Completed iter 78100/150000. Training loss: 58696.43.
#   Completed iter 78200/150000. Training loss: 58741.94.
#   Completed iter 78300/150000. Training loss: 58788.31.
#   Completed iter 78400/150000. Training loss: 58831.07.
#   Completed iter 78500/150000. Training loss: 58878.37.
#   Completed iter 78600/150000. Training loss: 58922.32.
#   Completed iter 78700/150000. Training loss: 58968.56.
#   Completed iter 78800/150000. Training loss: 59013.01.
#   Completed iter 78900/150000. Training loss: 59055.07.
#   Completed iter 79000/150000. Training loss: 59100.66.
#   Completed iter 79100/150000. Training loss: 59144.90.
#   Completed iter 79200/150000. Training loss: 59189.74.
#   Completed iter 79300/150000. Training loss: 59235.13.
#   Completed iter 79400/150000. Training loss: 59277.24.
#   Completed iter 79500/150000. Training loss: 59318.91.
#   Completed iter 79600/150000. Training loss: 59360.07.
#   Completed iter 79700/150000. Training loss: 59401.16.
#   Completed iter 79800/150000. Training loss: 59445.90.
#   Completed iter 79900/150000. Training loss: 59490.77.
#   Completed iter 80000/150000. Training loss: 59534.84.
#   Completed iter 80100/150000. Training loss: 59580.70.
#   Completed iter 80200/150000. Training loss: 59625.33.
#   Completed iter 80300/150000. Training loss: 59669.76.
#   Completed iter 80400/150000. Training loss: 59712.79.
#   Completed iter 80500/150000. Training loss: 59757.02.
#   Completed iter 80600/150000. Training loss: 59799.42.
#   Completed iter 80700/150000. Training loss: 59841.78.
#   Completed iter 80800/150000. Training loss: 59884.73.
#   Completed iter 80900/150000. Training loss: 59928.26.
#   Completed iter 81000/150000. Training loss: 59972.74.
#   Completed iter 81100/150000. Training loss: 60013.81.
#   Completed iter 81200/150000. Training loss: 60057.06.
#   Completed iter 81300/150000. Training loss: 60101.59.
#   Completed iter 81400/150000. Training loss: 60143.69.
#   Completed iter 81500/150000. Training loss: 60187.83.
#   Completed iter 81600/150000. Training loss: 60231.38.
#   Completed iter 81700/150000. Training loss: 60275.07.
#   Completed iter 81800/150000. Training loss: 60318.26.
#   Completed iter 81900/150000. Training loss: 60362.88.
#   Completed iter 82000/150000. Training loss: 60407.26.
#   Completed iter 82100/150000. Training loss: 60451.61.
#   Completed iter 82200/150000. Training loss: 60496.24.
#   Completed iter 82300/150000. Training loss: 60537.93.
#   Completed iter 82400/150000. Training loss: 60578.01.
#   Completed iter 82500/150000. Training loss: 60622.63.
#   Completed iter 82600/150000. Training loss: 60665.52.
#   Completed iter 82700/150000. Training loss: 60708.61.
#   Completed iter 82800/150000. Training loss: 60750.25.
#   Completed iter 82900/150000. Training loss: 60793.78.
#   Completed iter 83000/150000. Training loss: 60837.74.
#   Completed iter 83100/150000. Training loss: 60881.63.
#   Completed iter 83200/150000. Training loss: 60925.64.
#   Completed iter 83300/150000. Training loss: 60969.82.
#   Completed iter 83400/150000. Training loss: 61011.27.
#   Completed iter 83500/150000. Training loss: 61053.86.
#   Completed iter 83600/150000. Training loss: 61097.67.
#   Completed iter 83700/150000. Training loss: 61140.40.
#   Completed iter 83800/150000. Training loss: 61182.40.
#   Completed iter 83900/150000. Training loss: 61225.45.
#   Completed iter 84000/150000. Training loss: 61266.06.
#   Completed iter 84100/150000. Training loss: 61308.14.
#   Completed iter 84200/150000. Training loss: 61349.19.
#   Completed iter 84300/150000. Training loss: 61389.18.
#   Completed iter 84400/150000. Training loss: 61432.36.
#   Completed iter 84500/150000. Training loss: 61474.79.
#   Completed iter 84600/150000. Training loss: 61518.63.
#   Completed iter 84700/150000. Training loss: 61560.52.
#   Completed iter 84800/150000. Training loss: 61600.32.
#   Completed iter 84900/150000. Training loss: 61643.27.
#   Completed iter 85000/150000. Training loss: 61686.14.
#   Completed iter 85100/150000. Training loss: 61726.34.
#   Completed iter 85200/150000. Training loss: 61767.47.
#   Completed iter 85300/150000. Training loss: 61808.80.
#   Completed iter 85400/150000. Training loss: 61848.95.
#   Completed iter 85500/150000. Training loss: 61892.41.
#   Completed iter 85600/150000. Training loss: 61933.32.
#   Completed iter 85700/150000. Training loss: 61974.83.
#   Completed iter 85800/150000. Training loss: 62014.47.
# ...
#   Completed iter 122000/150000. Training loss: 75231.36.
#   Completed iter 122100/150000. Training loss: 75264.38.
#   Completed iter 122200/150000. Training loss: 75295.05.
#   Completed iter 122300/150000. Training loss: 75327.17.
#   Completed iter 122400/150000. Training loss: 75359.41.
#   Completed iter 122500/150000. Training loss: 75391.15.
#   Completed iter 122600/150000. Training loss: 75424.32.
#   Completed iter 122700/150000. Training loss: 75455.82.
#   Completed iter 122800/150000. Training loss: 75488.15.
#   Completed iter 122900/150000. Training loss: 75520.62.
#   Completed iter 123000/150000. Training loss: 75552.64.
#   Completed iter 123100/150000. Training loss: 75583.15.
#   Completed iter 123200/150000. Training loss: 75617.69.
#   Completed iter 123300/150000. Training loss: 75649.69.
#   Completed iter 123400/150000. Training loss: 75680.41.
#   Completed iter 123500/150000. Training loss: 75712.64.
#   Completed iter 123600/150000. Training loss: 75744.42.
#   Completed iter 123700/150000. Training loss: 75777.08.
#   Completed iter 123800/150000. Training loss: 75809.18.
#   Completed iter 123900/150000. Training loss: 75841.62.
#   Completed iter 124000/150000. Training loss: 75873.17.
#   Completed iter 124100/150000. Training loss: 75905.93.
#   Completed iter 124200/150000. Training loss: 75938.99.
#   Completed iter 124300/150000. Training loss: 75970.91.
#   Completed iter 124400/150000. Training loss: 76001.95.
#   Completed iter 124500/150000. Training loss: 76032.56.
#   Completed iter 124600/150000. Training loss: 76065.12.
#   Completed iter 124700/150000. Training loss: 76098.45.
#   Completed iter 124800/150000. Training loss: 76130.72.
#   Completed iter 124900/150000. Training loss: 76162.10.
#   Completed iter 125000/150000. Training loss: 76193.91.
#   Completed iter 125100/150000. Training loss: 76225.12.
#   Completed iter 125200/150000. Training loss: 76257.30.
#   Completed iter 125300/150000. Training loss: 76288.63.
#   Completed iter 125400/150000. Training loss: 76320.56.
#   Completed iter 125500/150000. Training loss: 76350.37.
#   Completed iter 125600/150000. Training loss: 76380.90.
#   Completed iter 125700/150000. Training loss: 76414.02.
#   Completed iter 125800/150000. Training loss: 76445.48.
#   Completed iter 125900/150000. Training loss: 76476.41.
#   Completed iter 126000/150000. Training loss: 76507.29.
#   Completed iter 126100/150000. Training loss: 76540.00.
#   Completed iter 126200/150000. Training loss: 76570.47.
#   Completed iter 126300/150000. Training loss: 76602.12.
#   Completed iter 126400/150000. Training loss: 76632.85.
#   Completed iter 126500/150000. Training loss: 76662.76.
#   Completed iter 126600/150000. Training loss: 76694.13.
#   Completed iter 126700/150000. Training loss: 76725.07.
#   Completed iter 126800/150000. Training loss: 76756.54.
#   Completed iter 126900/150000. Training loss: 76788.39.
#   Completed iter 127000/150000. Training loss: 76819.51.
#   Completed iter 127100/150000. Training loss: 76851.22.
#   Completed iter 127200/150000. Training loss: 76883.00.
#   Completed iter 127300/150000. Training loss: 76914.69.
#   Completed iter 127400/150000. Training loss: 76947.59.
#   Completed iter 127500/150000. Training loss: 76979.78.
#   Completed iter 127600/150000. Training loss: 77011.53.
#   Completed iter 127700/150000. Training loss: 77042.11.
#   Completed iter 127800/150000. Training loss: 77072.07.
#   Completed iter 127900/150000. Training loss: 77103.37.
#   Completed iter 128000/150000. Training loss: 77134.37.
#   Completed iter 128100/150000. Training loss: 77164.86.
#   Completed iter 128200/150000. Training loss: 77195.95.
#   Completed iter 128300/150000. Training loss: 77225.78.
#   Completed iter 128400/150000. Training loss: 77257.46.
#   Completed iter 128500/150000. Training loss: 77290.54.
#   Completed iter 128600/150000. Training loss: 77322.27.
#   Completed iter 128700/150000. Training loss: 77353.01.
#   Completed iter 128800/150000. Training loss: 77384.38.
#   Completed iter 128900/150000. Training loss: 77414.54.
#   Completed iter 129000/150000. Training loss: 77443.92.
#   Completed iter 129100/150000. Training loss: 77474.62.
#   Completed iter 129200/150000. Training loss: 77506.20.
#   Completed iter 129300/150000. Training loss: 77538.21.
#   Completed iter 129400/150000. Training loss: 77567.89.
#   Completed iter 129500/150000. Training loss: 77598.37.
#   Completed iter 129600/150000. Training loss: 77630.94.
#   Completed iter 129700/150000. Training loss: 77661.51.
#   Completed iter 129800/150000. Training loss: 77692.91.
#   Completed iter 129900/150000. Training loss: 77723.21.
#   Completed iter 130000/150000. Training loss: 77755.86.
#   Completed iter 130100/150000. Training loss: 77787.29.
#   Completed iter 130200/150000. Training loss: 77818.82.
#   Completed iter 130300/150000. Training loss: 77849.24.
#   Completed iter 130400/150000. Training loss: 77878.68.
#   Completed iter 130500/150000. Training loss: 77908.69.
#   Completed iter 130600/150000. Training loss: 77939.13.
#   Completed iter 130700/150000. Training loss: 77971.31.
#   Completed iter 130800/150000. Training loss: 78001.94.
#   Completed iter 130900/150000. Training loss: 78032.85.
#   Completed iter 131000/150000. Training loss: 78061.79.
#   Completed iter 131100/150000. Training loss: 78091.83.
#   Completed iter 131200/150000. Training loss: 78123.21.
#   Completed iter 131300/150000. Training loss: 78152.56.
#   Completed iter 131400/150000. Training loss: 78182.54.
#   Completed iter 131500/150000. Training loss: 78213.97.
#   Completed iter 131600/150000. Training loss: 78244.07.
#   Completed iter 131700/150000. Training loss: 78273.90.
#   Completed iter 131800/150000. Training loss: 78303.76.
#   Completed iter 131900/150000. Training loss: 78333.42.
#   Completed iter 132000/150000. Training loss: 78361.33.
#   Completed iter 132100/150000. Training loss: 78392.36.
#   Completed iter 132200/150000. Training loss: 78423.72.
#   Completed iter 132300/150000. Training loss: 78452.51.
#   Completed iter 132400/150000. Training loss: 78484.63.
#   Completed iter 132500/150000. Training loss: 78515.17.
#   Completed iter 132600/150000. Training loss: 78546.00.
#   Completed iter 132700/150000. Training loss: 78575.15.
#   Completed iter 132800/150000. Training loss: 78605.68.
#   Completed iter 132900/150000. Training loss: 78634.90.
#   Completed iter 133000/150000. Training loss: 78666.85.
#   Completed iter 133100/150000. Training loss: 78696.72.
#   Completed iter 133200/150000. Training loss: 78726.65.
#   Completed iter 133300/150000. Training loss: 78756.30.
#   Completed iter 133400/150000. Training loss: 78786.35.
#   Completed iter 133500/150000. Training loss: 78815.47.
#   Completed iter 133600/150000. Training loss: 78845.35.
#   Completed iter 133700/150000. Training loss: 78874.60.
#   Completed iter 133800/150000. Training loss: 78903.77.
#   Completed iter 133900/150000. Training loss: 78933.03.
#   Completed iter 134000/150000. Training loss: 78962.46.
#   Completed iter 134100/150000. Training loss: 78991.93.
#   Completed iter 134200/150000. Training loss: 79022.31.
#   Completed iter 134300/150000. Training loss: 79051.07.
#   Completed iter 134400/150000. Training loss: 79078.93.
#   Completed iter 134500/150000. Training loss: 79108.10.
#   Completed iter 134600/150000. Training loss: 79136.70.
#   Completed iter 134700/150000. Training loss: 79167.31.
#   Completed iter 134800/150000. Training loss: 79197.22.
#   Completed iter 134900/150000. Training loss: 79227.06.
#   Completed iter 135000/150000. Training loss: 79258.28.
#   Completed iter 135100/150000. Training loss: 79289.80.
#   Completed iter 135200/150000. Training loss: 79319.42.
#   Completed iter 135300/150000. Training loss: 79349.21.
#   Completed iter 135400/150000. Training loss: 79377.33.
#   Completed iter 135500/150000. Training loss: 79407.90.
#   Completed iter 135600/150000. Training loss: 79436.72.
#   Completed iter 135700/150000. Training loss: 79464.91.
#   Completed iter 135800/150000. Training loss: 79494.00.
#   Completed iter 135900/150000. Training loss: 79523.46.
#   Completed iter 136000/150000. Training loss: 79553.12.
#   Completed iter 136100/150000. Training loss: 79583.63.
#   Completed iter 136200/150000. Training loss: 79614.18.
#   Completed iter 136300/150000. Training loss: 79642.95.
#   Completed iter 136400/150000. Training loss: 79671.50.
#   Completed iter 136500/150000. Training loss: 79700.18.
#   Completed iter 136600/150000. Training loss: 79730.68.
#   Completed iter 136700/150000. Training loss: 79762.09.
#   Completed iter 136800/150000. Training loss: 79791.03.
#   Completed iter 136900/150000. Training loss: 79819.85.
#   Completed iter 137000/150000. Training loss: 79850.65.
#   Completed iter 137100/150000. Training loss: 79879.33.
#   Completed iter 137200/150000. Training loss: 79909.47.
#   Completed iter 137300/150000. Training loss: 79939.56.
#   Completed iter 137400/150000. Training loss: 79970.65.
#   Completed iter 137500/150000. Training loss: 80000.85.
#   Completed iter 137600/150000. Training loss: 80030.03.
#   Completed iter 137700/150000. Training loss: 80060.42.
#   Completed iter 137800/150000. Training loss: 80089.81.
#   Completed iter 137900/150000. Training loss: 80117.57.
#   Completed iter 138000/150000. Training loss: 80147.15.
#   Completed iter 138100/150000. Training loss: 80176.13.
#   Completed iter 138200/150000. Training loss: 80203.18.
#   Completed iter 138300/150000. Training loss: 80233.44.
#   Completed iter 138400/150000. Training loss: 80262.13.
#   Completed iter 138500/150000. Training loss: 80291.44.
#   Completed iter 138600/150000. Training loss: 80321.67.
#   Completed iter 138700/150000. Training loss: 80350.91.
#   Completed iter 138800/150000. Training loss: 80379.82.
#   Completed iter 138900/150000. Training loss: 80408.55.
#   Completed iter 139000/150000. Training loss: 80436.95.
#   Completed iter 139100/150000. Training loss: 80466.53.
#   Completed iter 139200/150000. Training loss: 80493.93.
#   Completed iter 139300/150000. Training loss: 80521.94.
#   Completed iter 139400/150000. Training loss: 80550.43.
#   Completed iter 139500/150000. Training loss: 80580.22.
#   Completed iter 139600/150000. Training loss: 80609.60.
#   Completed iter 139700/150000. Training loss: 80637.43.
#   Completed iter 139800/150000. Training loss: 80667.16.
#   Completed iter 139900/150000. Training loss: 80696.65.
#   Completed iter 140000/150000. Training loss: 80727.48.
#   Completed iter 140100/150000. Training loss: 80755.99.
#   Completed iter 140200/150000. Training loss: 80785.40.
#   Completed iter 140300/150000. Training loss: 80816.35.
#   Completed iter 140400/150000. Training loss: 80844.13.
#   Completed iter 140500/150000. Training loss: 80873.73.
#   Completed iter 140600/150000. Training loss: 80903.38.
#   Completed iter 140700/150000. Training loss: 80933.89.
#   Completed iter 140800/150000. Training loss: 80961.81.
#   Completed iter 140900/150000. Training loss: 80991.79.
#   Completed iter 141000/150000. Training loss: 81019.55.
#   Completed iter 141100/150000. Training loss: 81047.99.
#   Completed iter 141200/150000. Training loss: 81078.12.
#   Completed iter 141300/150000. Training loss: 81106.44.
#   Completed iter 141400/150000. Training loss: 81135.59.
#   Completed iter 141500/150000. Training loss: 81164.67.
#   Completed iter 141600/150000. Training loss: 81192.72.
#   Completed iter 141700/150000. Training loss: 81220.38.
#   Completed iter 141800/150000. Training loss: 81250.03.
#   Completed iter 141900/150000. Training loss: 81279.88.
#   Completed iter 142000/150000. Training loss: 81308.30.
#   Completed iter 142100/150000. Training loss: 81335.96.
#   Completed iter 142200/150000. Training loss: 81364.84.
#   Completed iter 142300/150000. Training loss: 81395.90.
#   Completed iter 142400/150000. Training loss: 81423.54.
#   Completed iter 142500/150000. Training loss: 81452.17.
#   Completed iter 142600/150000. Training loss: 81483.24.
#   Completed iter 142700/150000. Training loss: 81514.10.
#   Completed iter 142800/150000. Training loss: 81543.27.
#   Completed iter 142900/150000. Training loss: 81570.71.
#   Completed iter 143000/150000. Training loss: 81600.11.
#   Completed iter 143100/150000. Training loss: 81628.42.
#   Completed iter 143200/150000. Training loss: 81656.61.
#   Completed iter 143300/150000. Training loss: 81684.38.
#   Completed iter 143400/150000. Training loss: 81711.76.
#   Completed iter 143500/150000. Training loss: 81741.54.
#   Completed iter 143600/150000. Training loss: 81770.99.
#   Completed iter 143700/150000. Training loss: 81798.45.
#   Completed iter 143800/150000. Training loss: 81827.87.
#   Completed iter 143900/150000. Training loss: 81858.04.
#   Completed iter 144000/150000. Training loss: 81886.84.
#   Completed iter 144100/150000. Training loss: 81915.30.
#   Completed iter 144200/150000. Training loss: 81943.42.
#   Completed iter 144300/150000. Training loss: 81972.01.
#   Completed iter 144400/150000. Training loss: 81998.24.
#   Completed iter 144500/150000. Training loss: 82024.91.
#   Completed iter 144600/150000. Training loss: 82053.61.
#   Completed iter 144700/150000. Training loss: 82082.22.
#   Completed iter 144800/150000. Training loss: 82109.44.
#   Completed iter 144900/150000. Training loss: 82138.03.
#   Completed iter 145000/150000. Training loss: 82166.39.
#   Completed iter 145100/150000. Training loss: 82193.57.
#   Completed iter 145200/150000. Training loss: 82221.18.
#   Completed iter 145300/150000. Training loss: 82249.29.
#   Completed iter 145400/150000. Training loss: 82277.54.
#   Completed iter 145500/150000. Training loss: 82305.39.
#   Completed iter 145600/150000. Training loss: 82332.84.
#   Completed iter 145700/150000. Training loss: 82361.47.
#   Completed iter 145800/150000. Training loss: 82389.88.
#   Completed iter 145900/150000. Training loss: 82417.67.
#   Completed iter 146000/150000. Training loss: 82444.54.
#   Completed iter 146100/150000. Training loss: 82474.24.
#   Completed iter 146200/150000. Training loss: 82501.16.
#   Completed iter 146300/150000. Training loss: 82530.71.
#   Completed iter 146400/150000. Training loss: 82558.99.
#   Completed iter 146500/150000. Training loss: 82587.84.
#   Completed iter 146600/150000. Training loss: 82614.52.
#   Completed iter 146700/150000. Training loss: 82643.03.
#   Completed iter 146800/150000. Training loss: 82670.84.
#   Completed iter 146900/150000. Training loss: 82699.81.
#   Completed iter 147000/150000. Training loss: 82729.02.
#   Completed iter 147100/150000. Training loss: 82757.86.
#   Completed iter 147200/150000. Training loss: 82785.85.
#   Completed iter 147300/150000. Training loss: 82815.42.
#   Completed iter 147400/150000. Training loss: 82844.14.
#   Completed iter 147500/150000. Training loss: 82871.68.
#   Completed iter 147600/150000. Training loss: 82899.80.
#   Completed iter 147700/150000. Training loss: 82928.41.
#   Completed iter 147800/150000. Training loss: 82956.93.
#   Completed iter 147900/150000. Training loss: 82985.23.
#   Completed iter 148000/150000. Training loss: 83014.08.
#   Completed iter 148100/150000. Training loss: 83043.05.
#   Completed iter 148200/150000. Training loss: 83071.52.
#   Completed iter 148300/150000. Training loss: 83098.95.
#   Completed iter 148400/150000. Training loss: 83125.85.
#   Completed iter 148500/150000. Training loss: 83154.58.
#   Completed iter 148600/150000. Training loss: 83183.75.
#   Completed iter 148700/150000. Training loss: 83211.90.
#   Completed iter 148800/150000. Training loss: 83240.13.
#   Completed iter 148900/150000. Training loss: 83269.05.
#   Completed iter 149000/150000. Training loss: 83296.39.
#   Completed iter 149100/150000. Training loss: 83323.78.
#   Completed iter 149200/150000. Training loss: 83351.96.
#   Completed iter 149300/150000. Training loss: 83379.73.
#   Completed iter 149400/150000. Training loss: 83407.92.
#   Completed iter 149500/150000. Training loss: 83435.24.
#   Completed iter 149600/150000. Training loss: 83462.24.
#   Completed iter 149700/150000. Training loss: 83490.80.
#   Completed iter 149800/150000. Training loss: 83518.52.
#   Completed iter 149900/150000. Training loss: 83546.56.
# Finished training!
# Test accuracy 0.268

# %% [markdown]
# ### d. Visualize learned weights
#
# **TODO:** Run the following code that plots the network weights going to each output neuron. If all goes well, you should see something really cool! Include the plot in your submitted project to show me what you got!
#
# **Note:** the quality of your visualizations will depend on:
# - The quality of the hyperparameters that you got via grid search.
# - How many epochs that you trained the network before plotting the weights
#
# One extension idea: is to find the combination of the above that result in the best visualizations.

# %%
# We don't care about the bias wt
wts = bestNet.wts
# Reshape the wt vectors into spatial 'image' configurations to visualization
wts = wts.reshape(32, 32, 3, 10)

# Make a large new empty figure/plot
plt.figure(figsize=(20, 8))

# Loop through each output neuron
for i in range(10):
  # Make a 2x5 grid of images
  plt.subplot(2, 5, i+1)
  
  # Rescale the weights to be between 0 and 255
  currImg = 255.0 * (wts[:, :, :, i].squeeze() - np.min(wts)) / (np.max(wts) - np.min(wts))
  
  plt.imshow(currImg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
